# %% [markdown]
# # EA

# %%
setwd("C:/Users/jmarks/OneDrive - Research Triangle Institute/Projects/heroin/ngc/uhs4/qc/troubleshoot/ea")
df <- read.table("genotypes_for_relatedness_ld_prune_filter.genome", header=TRUE)
head(df)

mycol = "green"
title <- "UHS4 EA IBS Filtering"
hist(df$DST, main = title, col = mycol)
# Out:
#   FID1                                  IID1
# 1 AS00-00584_8002022306_HHG10079_12_A07 AS00-00584_8002022306_HHG10079_12_A07
# 2 AS00-00584_8002022306_HHG10079_12_A07 AS00-00584_8002022306_HHG10079_12_A07
# 3 AS00-00584_8002022306_HHG10079_12_A07 AS00-00584_8002022306_HHG10079_12_A07
# 4 AS00-00584_8002022306_HHG10079_12_A07 AS00-00584_8002022306_HHG10079_12_A07
# 5 AS00-00584_8002022306_HHG10079_12_A07 AS00-00584_8002022306_HHG10079_12_A07
# 6 AS00-00584_8002022306_HHG10079_12_A07 AS00-00584_8002022306_HHG10079_12_A07
#   FID2                                  IID2
# 1 AS00-00619_8002160856_HHG0001_10_G01  AS00-00619_8002160856_HHG0001_10_G01
# 2 AS00-00636_8002022330_HHG10081_12_B07 AS00-00636_8002022330_HHG10081_12_B07
# 3 AS00-00672_8002022247_HHG10082_11_E10 AS00-00672_8002022247_HHG10082_11_E10
# 4 AS00-00675_8002022259_HHG10083_37_D08 AS00-00675_8002022259_HHG10083_37_D08
# 5 AS00-01816_8002220311_HHG6186_36_D04  AS00-01816_8002220311_HHG6186_36_D04
# 6 AS00-01826_8002022319_HHG10088_14_C07 AS00-01826_8002022319_HHG10088_14_C07
#   RT EZ Z0 Z1 Z2 PI_HAT PHE DST      PPC    RATIO
# 1 UN NA 1  0  0  0      -1  0.896113 0.0071 1.8537
# 2 UN NA 1  0  0  0      -1  0.894567 0.0982 1.9214
# 3 UN NA 1  0  0  0      -1  0.898468 0.1068 1.9240
# 4 UN NA 1  0  0  0      -1  0.897873 0.7672 2.0463
# 5 UN NA 1  0  0  0      -1  0.898326 0.1054 1.9237
# 6 UN NA 1  0  0  0      -1  0.892674 0.0123 1.8658
# Plot with title "UHS4 EA IBS Filtering"

# %% [markdown]
# # AA

# %%
setwd("C:/Users/jmarks/OneDrive - Research Triangle Institute/Projects/heroin/ngc/uhs4/qc/troubleshoot/aa")
df <- read.table("genotypes_for_relatedness_ld_prune_filter.genome", header=TRUE)
head(df)

mycol = "red"
title <- "UHS4 AA IBS Filtering"
hist(df$DST, main = title, col = mycol)
# Out:
#   FID1                                  IID1
# 1 AS00-00347_8002022294_HHG10078_12_H06 AS00-00347_8002022294_HHG10078_12_H06
# 2 AS00-00347_8002022294_HHG10078_12_H06 AS00-00347_8002022294_HHG10078_12_H06
# 3 AS00-00347_8002022294_HHG10078_12_H06 AS00-00347_8002022294_HHG10078_12_H06
# 4 AS00-00347_8002022294_HHG10078_12_H06 AS00-00347_8002022294_HHG10078_12_H06
# 5 AS00-00347_8002022294_HHG10078_12_H06 AS00-00347_8002022294_HHG10078_12_H06
# 6 AS00-00347_8002022294_HHG10078_12_H06 AS00-00347_8002022294_HHG10078_12_H06
#   FID2                                 IID2                                 RT
# 1 AS00-00351_8002220319_HHG6146_36_C02 AS00-00351_8002220319_HHG6146_36_C02 UN
# 2 AS00-00437_8002220343_HHG6150_36_D02 AS00-00437_8002220343_HHG6150_36_D02 UN
# 3 AS00-00459_8002220355_HHG6152_36_E02 AS00-00459_8002220355_HHG6152_36_E02 UN
# 4 AS00-00583_8002220296_HHG6155_36_F02 AS00-00583_8002220296_HHG6155_36_F02 UN
# 5 AS00-00585_8002220308_HHG6156_36_G02 AS00-00585_8002220308_HHG6156_36_G02 UN
# 6 AS00-00586_8002694993_HHG0616_1_E01  AS00-00586_8002694993_HHG0616_1_E01  UN
#   EZ Z0 Z1 Z2 PI_HAT PHE DST      PPC    RATIO
# 1 NA 1  0  0  0      -1  0.837428 0.3999 1.9846
# 2 NA 1  0  0  0      -1  0.837694 0.2301 1.9558
# 3 NA 1  0  0  0      -1  0.839655 0.4919 1.9988
# 4 NA 1  0  0  0      -1  0.838738 0.0007 1.8170
# 5 NA 1  0  0  0      -1  0.841063 0.0000 1.7724
# 6 NA 1  0  0  0      -1  0.839356 0.0000 1.7509
# Plot with title "UHS4 AA IBS Filtering"

# %% [markdown]
# # 1000G MAF comparison
# ## EA

# %%
setwd("C:/Users/jmarks/OneDrive - Research Triangle Institute/Projects/heroin/ngc/uhs4/qc/troubleshoot/ea/maf")
df_thou <- read.table("1000g_maf.frq")
df_ea <- read.table("ea_maf.frq")
head(df_thou)
head(df_ea)

plot(df_thou$V2, df_ea$V2, main="UHS4 vs 1000G:\nchr22 MAF",
    ylab="UHS4 MAF", xlab="1000G MAF")
# Out:
#   V1          V2
# 1 rs4911642   0.1359
# 2 rs114025703 0.0000
# 3 rs35416799  0.0594
# 4 rs117445191 0.0303
# 5 rs2379852   0.0646
# 6 rs139847840 0.0778
#   V1          V2
# 1 rs4911642   0.0061810
# 2 rs114025703 0.0000000
# 3 rs35416799  0.0533600
# 4 rs117445191 0.0508400
# 5 rs2379852   0.0796200
# 6 rs139847840 0.0006098
# Plot with title "UHS4 vs 1000G:
# chr22 MAF"

# %% [markdown]
# ## AA

# %%
setwd("C:/Users/jmarks/OneDrive - Research Triangle Institute/Projects/heroin/ngc/uhs4/qc/troubleshoot/aa/maf")
df_thou <- read.table("1000g_maf.frq")
df_aa <- read.table("aa_maf.frq", header=TRUE)
head(df_thou)
head(df_aa)

plot(df_thou$V2, df_aa$MAF, main="UHS4 vs 1000G:\nchr22 MAF",
    ylab="UHS4 MAF", xlab="1000G MAF")
# Out:
#   V1          V2
# 1 rs114025703 0.0000
# 2 rs35416799  0.0594
# 3 rs117445191 0.0303
# 4 rs2379852   0.0646
# 5 rs139847840 0.0778
# 6 rs7291672   0.0620
#   SNP         MAF
# 1 rs114025703 0.003660
# 2 rs35416799  0.021280
# 3 rs117445191 0.019250
# 4 rs2379852   0.025160
# 5 rs139847840 0.006146
# 6 rs7291672   0.004071
# Plot with title "UHS4 vs 1000G:
# chr22 MAF"
