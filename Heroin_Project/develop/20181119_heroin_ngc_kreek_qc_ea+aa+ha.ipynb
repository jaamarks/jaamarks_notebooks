# %% [markdown]
# # Kreek Data Set GWAS
# **Author:** Jesse Marks
# **Date:** November 15, 2018
#
# This notebook documents the quality-control of the Kreek data set. We are reprocessing these data in an attempt to clean up the EA cohort group which produced an inflated lambda value when the GWAS was performed.
#
# ___
#
# As a component of an opioid GWAS meta-analysis in progress referred to as the "UHS-Nelson" study, we need to show replication in an independent cohort. We will take advantage of a data set released by Mary-Jeanne Kreek's research group, which we refer to as the "Kreek" data set, to assess whether the UHS-Nelson study findings are replicable with the Kreek data. The three types of opioid GWAS we will run are:
#
# * Opioid cases vs. clean controls (no abuse or dependence of any drug)
# * Opioid cases vs. all controls with no covariates adjusting for other drugs
# * Opioid cases vs. all controls with covariates adjusting for cocaine and alcohol
#
# These three GWAS will be run separately for 3 different ancestry groups:
#
# * European (EA)
# * African (AA)
# * Hispanic (HA)
#
# **Note**: It was decided that we would not proceed with the the Hispanic ancestry group.

# %% [markdown]
# # Download Data
# Create the directory structure and download from S3 to EC2.

# %%
### EC2 console ###
genD=/shared/data/studies/heroin/kreek/genotype/observed/processing
phenD=/shared/data/studies/heroin/kreek/phenotype/processing
study=kreek

mkdir -p /shared/data/studies/heroin/kreek/genotype/observed/{final,processing,unprocessed}
cd /shared/data/studies/heroin/kreek/genotype/observed/unprocessed
aws s3 sync s3://rti-midas-data/studies/kreek/observed/unprocessed/ . --quiet &

#mv files to respective directories
mv /shared/data/studies/heroin/kreek/genotype/observed/unprocessed/PhenotypeFiles/* \
    /shared/data/studies/heroin/kreek/phenotype/processing/

mv /shared/data/studies/heroin/kreek/genotype/observed/unprocessed/GenotypeFiles \
    /shared/data/studies/heroin/kreek/genotype/observed/processing/

# %% [markdown]
# ## Data Description
# * Kreek phenotype and genotype data dbGaP accession ID phs001109.v1.p1.
# * Genotypes are from the Biorealm Smokescreen array based on the Affymetrix Axiom platform.
# * Genotypes are annotated using dbSNP build 137 and NCBI human genome build 37 (hg19).
# * 1000 Genomes Phase 3 reference panel (05/2013 release)

# %% [markdown]
# ### Genotype files
# The genotype data are in BED, BIM, and FAM formats. These are detailed [here](https://www.cog-genomics.org/plink2/formats). There are also Axiom array annotation information provided in a CSV file and miscellaneous QC files.
#
# ### Phenotype files
# The phenotype files are tab-delimited text files containing data attributes and information that maps between subject and sample IDs. The main file of interest contains the expression `Subject_Phenotypes` in the file name. This file contains the covariates and outcome variables that we will use to further filter the data.

# %% [markdown]
# ## The software and tools needed for this analysis are
#
# * Aspera Connect
# * Michigan Imputation Server
# * PLINK v1.9
# * ProbeAbel (R package)
# * RTI computing clusters (MIDAS and ESN)
# * SRA toolkit
# * STRUCTURE
# * KING

# %% [markdown]
# # Phenotype processing
# There are several initial filters and processing steps to be applied to the subject data
#
# * Remove the age outlier (age 111) individual and 5 individuals with missing age data
# * Remove phenotype data for all drugs except cocaine, opioids, and alcohol
# * Combine dependence and abuse variables into one outcome variable per drug (opioid_abdp, cocaine_abdp, alcohol_abdp). Using the NGC protocol coding (Cases=2 and Controls=1)
#
#     * Abuse and dependence = 2
#     * Abuse or dependence = 2
#     * No abuse and no dependence = 1
#     * Note: In the original data True=1 and False=0
# * Stratify data by ancestry and retain only the 2 ancestry groups with sufficient sample size
#
#     * European (EA) - coded as White
#     * African (AA) - coded as African_American
#
# * Note that we decided to not include Hispanic group.

# %%
# rename phenotype files
for i in $phenD/*txt; do mv $i $(echo $i | perl -pi -e s/phs001109.v1.pht.+Diseases_//g); done

# %%
## R console ##
# Load data
setwd("/shared/data/studies/heroin/kreek/phenotype/processing")
pheno.data <- read.delim("Subject_Phenotypes.DS-ADX-IRB-NPU.txt", 
                         header=T, stringsAsFactors=F, skip=10)

# Remove extra column data
pheno.data <- pheno.data[,-1*c(6,7,8,12,13,14,15,16,20,21,22,23)]

# Remove age outlier and NAs
pheno.data <- pheno.data[-1*which(is.na(pheno.data$age)),]
pheno.data <- pheno.data[-1*which(pheno.data$age==111),]

# Combine dependence and abuse variables
opioid.abdp <- as.logical(pheno.data$opioid_dep) | as.logical(pheno.data$opioid_abuse)
cocaine.abdp <- as.logical(pheno.data$cocaine_dep) | as.logical(pheno.data$cocaine_abuse)
alcohol.abdp <- as.logical(pheno.data$alcohol_dep) | as.logical(pheno.data$alcohol_abuse)

opioid_abdp <- c()
opioid_abdp[opioid.abdp] <- 2
opioid_abdp[!opioid.abdp] <- 1

cocaine_abdp <- c()
cocaine_abdp[cocaine.abdp] <- 2
cocaine_abdp[!cocaine.abdp] <- 1

alcohol_abdp <- c()
alcohol_abdp[alcohol.abdp] <- 2
alcohol_abdp[!alcohol.abdp] <- 1

pheno.data <- cbind(pheno.data, opioid_abdp, cocaine_abdp, alcohol_abdp)
pheno.data <- subset(pheno.data, select=-c(opioid_dep, opioid_abuse, cocaine_dep, cocaine_abuse, alcohol_dep, alcohol_abuse))

# Partition by ancestry
ea.data <- pheno.data[pheno.data$family_race=="White",]
aa.data <- pheno.data[pheno.data$family_race=="African_American",]
ha.data <- pheno.data[pheno.data$family_race=="Hispanic",]

write.table(x = ea.data, file = "ea.phenotype.data", quote = F, row.names = F)
write.table(x = aa.data, file = "aa.phenotype.data", quote = F, row.names = F)
write.table(x = ha.data, file = "ha.phenotype.data", quote = F, row.names = F)

# %% [markdown]
# # Genotype Processing
# The genotype processing workflow on the `observed` genotypes is as follows:
#
# 1) Remove probe sets that do not have a dbSNP rsID annotation and convert Affymetrix probe IDs to rsIDs. Remove subjects that do not pass initial phenotype filtering
#
# 2) Update genome build and dbSNP build
#
# 3) Partition data by ancestry. Subsequent steps are performed by ancestry
#
# 4) Remove subjects with data missing for whole autosomes. Subsequent steps up to 16 are performed using autosomes only.
#
# 5) Remove duplicates for rsIDs
#
# 6) Set genotypes to positive strand orientation
#
# 7) Run STRUCTURE to detect and remove subjects that are ancestral outliers
#
# 8) Calculate genotype missing call rate. Filter variants with high missing call rates
#
# 9) Calculate Hardy-Weinberg (HW) equilibrium for each variant. Filter variants by HW p-values
#
# 10) Remove subjects with high missing genotype call rates (as pre-processing for LD pruning)
#
# 11) Apply linkage disequilibrium pruning (as pre-processing for steps 12 and 13)
#
# 12) Check for sample duplications and monozygotic twins using identical-by-state estimates
#
# 13) Check relatedness using identical-by-descent estimates
#
# 14) Use KING for calculating IBD for African ancestry subjects
#
# 15) Repeat steps 4, 5, 6, 7 (use pre-calculated remove list), 8, and 9 for chrX. Merge autosomes with chrX
#
# 16) Remove subjects that meet relatedness filtering criteria
#
# 17) Repeat step 10 with all chromosomes
#
# 18) Apply linkage disequilibrium pruning (as pre-processing for steps 18 and 19)
#
# 19) Remove subjects exhibiting sex discordance
#
# 20) Remove subjects exhibiting excessive homozygosity
#
# 21) Recode variants in relation to 1000 Genomes phase 3 reference panel. Remove discordant alleles
#
# Many of these steps are done using PLINK commands that update the binary filesets. Generally, each time a new binary fileset is created, text files containing identifiers for what to include or exclude are provided. Consequently, much of the data processing emphasizes creating these text files to be used with PLINK. Note: PLINK has a specific order of operations. Be sure to note this when combining commands and filtering steps.

# %% [markdown]
# ## Pre-ancestry partitioning quality control sample tracking
# The table below provides statistics on variants and subjects filtered during each step of the QC process before partitioning into ancestry groups
#
# **Note**: Initial subject counts are determined by considering only subjects with both genotype and phenotype data available. Consequently, initial numbers may not match between the .fam files and the phenotype files.

# %% [markdown]
# | QC procedure                                  | Variants removed | Variants retained | Subjects removed | Subjects retained |
# |-----------------------------------------------|------------------|-------------------|------------------|-------------------|
# | Initial dbGaP dataset                         | 0                | 580,154           | 0                | 1,661             |
# | Remove subjects with problematic age variable | 0                | 580,154           | 6                | 1,655             |
# | Remove variants missing rsIDs                 | 12,423           | 567,731           | 0                | 1,655             |
# | Duplicate rsID filtereing                     | 0                | 567,731           | 0                | 1,655             |
# | Genome build 37 and dbGaP 138 update          | 1,940            | 565,791           | 0                | 1,655             |

# %% [markdown]
# ## European Ancestry
# The table below provides statistics on variants and subjects filtered during each step of the QC process.
#
# **Note**: Initial subject counts are determined by considering only subjects with both genotype and phenotype data available. Consequently, initial numbers may not match between the .fam files and the phenotype files
#
# ### Autosome statistics
# This table includes filtering statistics prior to merging with chrX.
#
# | QC procedure                                     | Variants removed | Variants retained | Subjects removed | Subjects added | Subjects retained |
# |--------------------------------------------------|------------------|-------------------|------------------|----------------|-------------------|
# |* EA subject filter w/initial procedures (all chr) | 0               | 565,791           | 1,004            | 0              | 651               |
# |* Partitioning to only autosomes                   | 13,926          | 551,865           | 0                | 0              | 651               |
# |* Remove subjects missing whole autosome data      | 0               | 551,865           | 0                | 0              | 651               |
# |* Duplicate rsID filtering                         | 0               | 551,865           | 0                | 0              | 651               |
# |* Strand flipping and polymorphic SNP filter       | 7,173           | 544,692           |0                 |0               | 651                |
# |* Remove ancestral outliers                        | 0               | 544,692           | 35               | 18              | 634               |
# |* Add reassigned subjects based on STRUCTURE       | 0               | 544,692           | 0                | 6              |                |
# |* Remove variants with missing call rate > 3%      |                 |                   | 0                | 0              |              |
# |* Remove variants with HWE p < 0.0001              |                 |                   | 0                | 0              |              |
#
#
#
# ### ChrX statistics
# This table includes filtering statistics prior to merging with autosomes.
#
# | QC procedure                                      | Variants removed | Variants retained | Subjects removed | Subjects added | Subjects retained |
# |---------------------------------------------------|------------------|-------------------|------------------|----------------|-----------------|
# |* EA subject filter w/initial procedures (all chr) | 0                | 565,791           | 1,004            | 0             | 651               |
# |* Partitioning to only chrX                        | 551,865          | 13,926            | 0                | 0             | 651               |
# |* Remove subjects missing whole chrX data          | 0                |                   | 0                | 0             | 651               |
# |* Duplicate rsID filtering                         | 0                |                   | 0                | 0             | 651               |
# |* Remove/Reassign ancestral outliers               | 0                |                   | 13               | 6             | 634               |
# |* Remove variants with missing call rate > 3%      | 199              |                   | 0                | 0             | 634               |
# |* Remove variants with HWE p < 0.0001              | 1                |                   | 0                | 0             | 634               |
#
# ### Merged autosome and chrX statistics
#
# | QC procedure                                     | Variants removed | Variants retained | Subjects removed | Subjects added | Subjects retained |
# |--------------------------------------------------|------------------|-------------------|------------------|----------------|-------------------|
# |* Merge autosomes and chrX                        | 0                | 546,113           | 0                | 0              | 634             |
# |* Remove subjects with IBD > 0.4 or IBS > 0.9      | 0                | 546,113           | 17                | 0              |              |
# |* Remove subjects with missing call rate > 3%      | 0                | 546,113           | 3                | 0              |              |
# |* Sex discordance filter                           | 0                | 546,113           | 0                | 0              |              |
# |* Excessive homozygosity filter                    | 0                | 546,113           | 0                | 0              |              |
# |* Duplicate variant ID filter after 1000G renaming  | 1                | 546,112           | 0                | 0              |             |
# |* Remove ambiguous SNPs                             | 36,493           | 509,619           | 0                | 0              |             |

# %% [markdown]
# ## African Ancestry
# The table below provides statistics on variants and subjects filtered during each step of the QC process.
#
# **Note**: Initial subject counts are determined by considering only subjects with both genotype and phenotype data available. Consequently, initial numbers may not match between the .fam files and the phenotype files
#
# ### Autosome statistics
# This table includes filtering statistics prior to merging with chrX.
#
# | QC procedure                                     | Variants removed | Variants retained | Subjects removed | Subjects added | Subjects retained |
# |--------------------------------------------------|------------------|-------------------|------------------|----------------|-------------------|
# |* AA subject filter w/initial procedures (all chr) | 0                | 565,791           | 1,057           | 0              | 598               |
# |* Partitioning to only autosomes                   | 13,926           | 551,865           | 0               | 0              | 598               |
# |* Remove subjects missing whole autosome data      | 0                | 551,865           | 0               | 0              | 598               |
# |* Duplicate rsID filtering                         | 0                | 551,865           | 0               | 0              | 598               |
# |* Strand flipping and polymorphic SNP filter       | 7,173            | 544,692           |0                |0               | 598              |
# |* Remove ancestral outliers                        | 0                | 544,692           | 7               | 0              | 591               |
# |* Add reassigned subjects based on STRUCTURE       | 0                 | 544,692           | 0               | 8              | 599               |
# |* Remove variants with missing call rate > 3%      | 19,469            | 525,223           | 0               | 0              | 599             |
# |* Remove variants with HWE p < 0.0001               | 1,825                | 523,398            | 0               | 0              | 599             |
#
#
# ### ChrX statistics
# This table includes filtering statistics prior to merging with autosomes.
#
# | QC procedure                                     | Variants removed | Variants retained | Subjects removed | Subjects added | Subjects retained |
# |--------------------------------------------------|------------------|-------------------|------------------|----------------|-------------------|
# |* AA subject filter w/initial procedures (all chr) | 0                | 565,791           | 1,057            | 0              | 598               |
# |* Partitioning to only chrX                        | 551,865          | 13,926            | 0                | 0              | 598               |
# |* Remove subjects missing whole chrX data      | 0                | 13,926            | 0                | 0              | 598             |
# |* Duplicate rsID filtering                         | 0                | 13,926            | 0                | 0              | 598             |
# |* Remove/reassign ancestral outliers                        | 0                | 13,926            | 7                | 8              | 599             |
# |* Remove variants with missing call rate > 3%      | 394               | 13,532            | 0                | 0              | 599             |
# |* Remove variants with HWE p < 0.0001              | 22                | 13,510            | 0                | 0              | 599             |
#
# ### Merged autosome and chrX statistics
#
# | QC procedure                                     | Variants removed | Variants retained | Subjects removed | Subjects added | Subjects retained |
# |--------------------------------------------------|------------------|-------------------|------------------|----------------|-------------------|
# |* Merge autosomes and chrX                         | 0                | 536,908           | 0                | 0              | 599               |
# |* Remove subjects with IBD > 0.4 or IBS > 0.9       | 0                | 536,908           | 20                | 0            | 579               |
# |* Remove subjects with missing call rate > 3%      | 0                | 536,908           | 3                | 0              | 576             |
# |* Sex discordance filter                           | 0                | 536,908           | 0                | 0              | 576             |
# |* Excessive homozygosity filter                    | 0                | 536,908            | 0                | 0              | 576             |
# |* Duplicate variant ID filter after 1000G renaming  | 1                | 536,907           | 0                | 0              |  576            |
# |* Remove ambiguous SNPs                             |35,412            | 501,495           | 0                | 0              | 576            |

# %% [markdown]
# ## Hispanic Ancestry
# The table below provides statistics on variants and subjects filtered during each step of the QC process.
#
# **Note**: Initial subject counts are determined by considering only subjects with both genotype and phenotype data available. Consequently, initial numbers may not match between the .fam files and the phenotype files
#
# ### Autosome statistics
# This table includes filtering statistics prior to merging with chrX.
#
# | QC procedure                                     | Variants removed | Variants retained | Subjects removed | Subjects added | Subjects retained |
# |--------------------------------------------------|------------------|-------------------|------------------|----------------|-------------------|
# |* HA subject filter w/initial procedures (all chr) | 0                | 565,791           | 1,359           | 0              | 302               |
# |* Partitioning to only autosomes                   | 13,926           | 551,865           | 0               | 0              | 302              |
# |* Remove subjects missing whole autosome data      | 0                | 551,865           | 0               | 0              | 302              |
# |* Duplicate rsID filtering                         | 0                | 551,865           | 0               | 0              | 302              |
# |* Strand flipping and polymorphic SNP filter       | 7,173            | 544,692           |0                |0               | 302             |
# |* Remove ancestral outliers                        | 0                | 544,692           | 7               | 0              | 302              |
# |* Add reassigned subjects based on STRUCTURE       | 0                 | 544,692           | 0               | 8              |302               |
# |* Remove variants with missing call rate > 3%      | 19,469            | 525,223           | 0               | 0              |302             |
# |* Remove variants with HWE p < 0.0001               | 1,825                | 523,398            | 0               | 0              | 302             |
#
#
# ### ChrX statistics
# This table includes filtering statistics prior to merging with autosomes.
#
# | QC procedure                                     | Variants removed | Variants retained | Subjects removed | Subjects added | Subjects retained |
# |--------------------------------------------------|------------------|-------------------|------------------|----------------|-------------------|
# |* HA subject filter w/initial procedures (all chr) | 0                | 565,791           | 1,057            | 0              | 302               |
# |* Partitioning to only chrX                        | 551,865          | 13,926            | 0                | 0              | 302               |
# |* Remove subjects missing whole chrX data      | 0                | 13,926            | 0                | 0              |              |
# |* Duplicate rsID filtering                         | 0                | 13,926            | 0                | 0              |              |
# |* Remove/reassign ancestral outliers                        | 0                | 13,926            | 7                | 8              |              |
# |* Remove variants with missing call rate > 3%      | 394               | 13,532            | 0                | 0              |              |
# |* Remove variants with HWE p < 0.0001              | 22                | 13,510            | 0                | 0              |              |
#
# ### Merged autosome and chrX statistics
#
# | QC procedure                                     | Variants removed | Variants retained | Subjects removed | Subjects added | Subjects retained |
# |--------------------------------------------------|------------------|-------------------|------------------|----------------|-------------------|
# |* Merge autosomes and chrX                         | 0                | 536,908           | 0                | 0              |                |
# |* Remove subjects with IBD > 0.4 or IBS > 0.9       | 0                | 536,908           | 20                | 0            |                |
# |* Remove subjects with missing call rate > 3%      | 0                | 536,908           | 3                | 0              |              |
# |* Sex discordance filter                           | 0                | 536,908           | 0                | 0              |              |
# |* Excessive homozygosity filter                    | 0                | 536,908            | 0                | 0              |              |
# |* Duplicate variant ID filter after 1000G renaming  | 1                | 536,907           | 0                | 0              |              |
# |* Remove ambiguous SNPs                             |35,412            | 501,495           | 0                | 0              |             |

# %% [markdown]
# ## Exclusion of subjects without phenotype data
# I check if the `.fam` file contains more subject IDs than the phenotype file. The subjects without phenotype data are excluded as they provide no benefit for GWA.

# %%
# rename genotype files
for i in $genD/phg*;
    do mv $i $(echo $i | perl -pi -e s/phg00.+Diseases.//g);
done

# %%
## EC2 console ##

# Get subject IDs from phenotype data
tail -n +12 $phenD/Subject_Phenotypes.DS-ADX-IRB-NPU.txt  | \
    cut -f 2,2 | \
    sort > $phenD/subject_ids.txt

# Add family IDs
grep -f $phenD/subject_ids.txt $genD/genotype-calls-matrixfmt.Axiom.c1.DS-ADX-IRB-NPU/Smokescreen_NIDA_Study5_Kreek.fam | \
    cut -d ' ' -f 1,2 \
    > $phenD/subject_ids.keep

# Create filtered PLINK fileset 
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --memory 2048 \
    --bfile $genD/genotype-calls-matrixfmt.Axiom.c1.DS-ADX-IRB-NPU/Smokescreen_NIDA_Study5_Kreek \
    --keep $phenD/subject_ids.keep \
    --make-bed \
    --out $genD/genotype-calls-matrixfmt.Axiom.c1.DS-ADX-IRB-NPU/Smokescreen_NIDA_Study5_Kreek_subject_filter

# %% [markdown]
# ```
# wc -l *fam
#  1661 Smokescreen_NIDA_Study5_Kreek.fam
#  1661 Smokescreen_NIDA_Study5_Kreek_subject_filter.fam
# ```

# %% [markdown]
# ## Remove subjects with problematic age data

# %%
## EC2 console ##

# Construct a subject ID list of subjects to remove due to outlier or missing age

# remove subject with age=111
tail -n +12 $phenD/Subject_Phenotypes.DS-ADX-IRB-NPU.txt | \
    awk '{ FS="\t"; OFS="\t" } { if($3==111){print 0,$2} }' > $phenD/age_id_filter.remove

"""
more $phenD/age_id_filter.remove
0       106962
"""

# missing age data
tail -n +12 $phenD/Subject_Phenotypes.DS-ADX-IRB-NPU.txt | \
    awk '{ FS="\t"; OFS="\t" } { if($3==""){print 0,$2} }' >> $phenD/age_id_filter.remove
"""
more $phenD/age_id_filter.remove                                         
0       106962
0       101465
0       102648
0       106607
0       106646
0       107543
"""

# Remove age outliers
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --memory 2048 \
    --bfile $genD/genotype-calls-matrixfmt.Axiom.c1.DS-ADX-IRB-NPU/Smokescreen_NIDA_Study5_Kreek_subject_filter \
    --remove $phenD/age_id_filter.remove \
    --make-bed \
    --out $genD/genotype-calls-matrixfmt.Axiom.c1.DS-ADX-IRB-NPU/Smokescreen_NIDA_Study5_Kreek_subject_age_filter

# %% [markdown]
# ```
# wc -l *fam
#  1661 Smokescreen_NIDA_Study5_Kreek.fam
#  1655 Smokescreen_NIDA_Study5_Kreek_subject_age_filter.fam
#  1661 Smokescreen_NIDA_Study5_Kreek_subject_filter.fam
# ```

# %% [markdown]
# ## Convert Affymetrix probe set IDs
# The original data has Affymetrix probe IDs in the `.bim` files instead of rsIDs. To convert the Affymetrix probe IDs to rsIDs, we use PLINK `--update-name`. PLINK `--exclude` removes the probe sets that do not have corresponding rsIDs. PLINK `--remove` will remove genotypes for specified subjects. Each of these options require a text file of IDs and are used in conjunction with PLINK `--make-bed` to create updated PLINK binary filesets.

# %%
## EC2 console ##

# view annotation file
awk 'FS="," {print $2,$3}' $genD/marker-info.MULTI/Axiom_Smokesc1.na34.annot.csv | head 100

# Construct list of probe sets missing rsIDs
tail -n +21 $genD/marker-info.MULTI/Axiom_Smokesc1.na34.annot.csv | \
    awk 'BEGIN { FS = "," } ; { if($3=="\"---\""){print $1} }' | \
    perl -pi -e "s/\"//g" > $genD/marker-info.MULTI/missing_dbsnp_id.remove

# Construct Affymetrix probe set ID to rsID mapping
tail -n +21 $genD/marker-info.MULTI/Axiom_Smokesc1.na34.annot.csv | \
    awk 'BEGIN { FS = "," ; OFS = "\t" } ; { if($3!="\"---\""){print $1,$3} }' | \
    perl -pi -e "s/\"//g" > $genD/marker-info.MULTI/affy_to_dbsnp_id_map.txt

# Remove genotypes with missing dbSNP IDs
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --bfile $genD/genotype-calls-matrixfmt.Axiom.c1.DS-ADX-IRB-NPU/Smokescreen_NIDA_Study5_Kreek_subject_age_filter \
    --exclude $genD/marker-info.MULTI/missing_dbsnp_id.remove \
    --make-bed \
    --out $genD/genotype-calls-matrixfmt.Axiom.c1.DS-ADX-IRB-NPU/Smokescreen_NIDA_Study5_Kreek_subject_age_missing_rsID_filter

# Update probe IDs to rsIDs
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --bfile $genD/genotype-calls-matrixfmt.Axiom.c1.DS-ADX-IRB-NPU/Smokescreen_NIDA_Study5_Kreek_subject_age_missing_rsID_filter \
    --update-name $genD/marker-info.MULTI/affy_to_dbsnp_id_map.txt \
    --make-bed \
    --out $genD/genotypes_affyID2rsID

# %% [markdown]
# ## Remove duplicate rsIDs

# %%
## EC2 console ##

# Append _X (where X is a number) to the end of the rs IDs for all but 1st occurrence of duplicates
perl -lane 'BEGIN { %idCounts = (); }
                    if (exists($idCounts{$F[1]})) {
                        $idCounts{$F[1]}++;
                        print join("\t",$F[0],$F[1]."_".$idCounts{$F[1]},$F[2],$F[3],$F[4],$F[5]);
                    } else {
                        $idCounts{$F[1]} = 1;
                        print;
                    } ' $genD/genotypes_affyID2rsID.bim > $genD/genotypes_affyID2rsID_renamed.bim

# create a list of the duplicate snps
grep -P "_\d" $genD/genotypes_affyID2rsID_renamed.bim | \
    perl -lane 'print substr($F[1], 0, index($F[1],"_"))."\n".$F[1];' \
    > $genD/genotypes_affyID2rsID_renamed.duplicate_snps

# Get call rates for duplicate SNPs
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --bed $genD/genotypes_affyID2rsID.bed \
            --bim $genD/genotypes_affyID2rsID_renamed.bim \
            --fam $genD/genotypes_affyID2rsID.fam \
            --extract $genD/genotypes_affyID2rsID_renamed.duplicate_snps \
            --missing \
            --allow-no-vars \
            --out $genD/genotypes_affyID2rsID.duplicate_snps.missing
"--extract: 0 variants remaining."

## note that no variants had duplicate ids so we don't need to run the following code

# Create remove list for duplicates containing duplicate with higher missing rate
#tail -n +2 genotypes_affyID2rsID.duplicate_snps.missing.lmiss |\
#perl -lane 'BEGIN { %missingness = (); }
#                        if ($F[1] =~ /^(\S+)_/) {
#                            $duplicateName = $1
#                        } else {
#                            $duplicateName = $F[1]."_2";
#                        }
#                        if (exists($missingness{$duplicateName})) {
#                            if ($missingness{$duplicateName} > $F[4]) {
#                                print $duplicateName;
#                            } else {
#                                print $F[1];
#                            }
#                        } else {
#                            $missingness{$F[1]} = $F[4];
#                        }' > genotypes_affyID2rsID.duplicate_snps.remove

# Remove duplicates with higher missing rate
#/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
#   --bed genotypes_affyID2rsID.bed \
#   --bim genotypes_affyID2rsID_renamed.bim \
#   --fam genotypes_affyID2rsID.fam \
#   --exclude genotypes_affyID2rsID.duplicate_snps.remove \
#   --allow-no-vars \
#   --make-bed \
#   --out genotypes_affyID2rsID_duplicates_removed
#
## Remove "_X" from rs IDs
#perl -i.bak -lne 's/_\d\t/\t/; print;'  genotypes_affyID2rsID_duplicates_removed.bim

# %% [markdown]
# ## Update dbSNP and genome build
# To ensure that all of the variant and genomic data are in dbSNP 138 and genome build 37 format, ID and position mappers are used to make data updates.

# %%
## EC2 console ##

# Update variant chr
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --memory 2048 \
    --bfile $genD/genotypes_affyID2rsID \
    --update-chr /shared/common/build_conversion/b37/dbsnp_b138/uniquely_mapped_snps.chromosomes \
    --make-bed \
    --out $genD/genotypes_chr_b37
" 567731 variants and 1655 people pass filters and QC."

# Update variant chr coordinate
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $genD/genotypes_chr_b37 \
        --update-map /shared/common/build_conversion/b37/dbsnp_b138/uniquely_mapped_snps.positions \
        --make-bed \
        --out $genD/genotypes_chr_position_b37

# Filter to only build 37 uniquely mapped variants
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $genD/genotypes_chr_position_b37 \
        --extract /shared/common/build_conversion/b37/dbsnp_b138/uniquely_mapped_snps.ids \
        --make-bed \
        --out $genD/genotypes_b37_dbsnp138
"565791 variants and 1655 people pass filters and QC."

# %% [markdown]
# ## Ancestry partitioning
# The data will be processed separately by ancestry type. For this analysis we will be working with 3 ancestry types
#
# * European (EA)
# * African (AA)
# * Hispanic (HA)
# As such, the next step will be to create separate subdirectory structures and binary filesets for subjects from each ancestry group. Like before, the assumption here is that famID is 0.

# %%
## EC2 console ##

# Construct a subject ID list for each ancestry group
tail -n +12 $phenD/Subject_Phenotypes.DS-ADX-IRB-NPU.txt | \
    awk '{ FS="\t"; OFS="\t" } { if($5=="African_American"){print 0,$2} }' >  $phenD/aa_subject_ids.txt

tail -n +12 $phenD/Subject_Phenotypes.DS-ADX-IRB-NPU.txt | \
    awk '{ FS="\t"; OFS="\t" } { if($5=="White"){print 0,$2} }' > $phenD/ea_subject_ids.txt

tail -n +12 $phenD/Subject_Phenotypes.DS-ADX-IRB-NPU.txt | \
    awk '{ FS="\t"; OFS="\t" } { if($5=="Hispanic"){print 0,$2} }' > $phenD/ha_subject_ids.txt

# Make new binary filesets for each ancestry group
for ancestry in {aa,ea,ha}; do
    echo -e "\n\n ================ ${ancestry} ================\n\n"
    mkdir ${ancestry}
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
      --bfile $genD/genotypes_b37_dbsnp138 \
      --keep $phenD/${ancestry}_subject_ids.txt \
      --make-bed \
      --out ${ancestry}/genotypes_b37_dbsnp138
done

# %% [markdown]
# ## Partition into autosome and chrX groups
# I apply QC to autosomes and chrX separately, so separate subdirectories are created for the processing of each set.

# %%
## EC2 console ##

# Make autosome and chrX binary filesets for each ancestry group
for ancestry in {aa,ea,ha}; do
    echo -e "\n\n ================ ${ancestry} ================\n\n"
    mkdir $genD/${ancestry}/{autosomes,chrX}

    # Autosomes
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138 \
        --autosome \
        --make-bed \
        --out $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138

    # ChrX
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138 \
        --chr 23 \
        --make-bed \
        --out $genD/${ancestry}/chrX/genotypes_b37_dbsnp138
done

# %% [markdown]
# ```
# wc -l */auto*/*bim
#   551865 aa/autosomes/genotypes_b37_dbsnp138.bim
#   551865 ea/autosomes/genotypes_b37_dbsnp138.bim
#   551865 ha/autosomes/genotypes_b37_dbsnp138.bim
#
# wc -l */auto*/*fam
#   598 aa/autosomes/genotypes_b37_dbsnp138.fam
#   651 ea/autosomes/genotypes_b37_dbsnp138.fam
#   302 ea/autosomes/genotypes_b37_dbsnp138.fam
#
# wc -l */ch*/*bim
#  12389 aa/chrX/genotypes_b37_dbsnp138.bim
#  12389 ea/chrX/genotypes_b37_dbsnp138.bim
#  12389 ha/chrX/genotypes_b37_dbsnp138.bim
# ```

# %% [markdown]
# ## Missing autosome data subject filtering
# We calculate the proportion of missing genotype calls per chromosome using PLINK to assess whether any subjects have data missing for whole autosomes.

# %%
## EC2 console ##

for ancestry in {aa,ea,ha}; do
    echo -e "\n\n ================ ${ancestry} ================\n\n"
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr} \
            --script_prefix $genD/${ancestry}/autosomes/chr${chr}_missing_call_rate \
            --mem 3.8 \
            --priority 0 \
            --program /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138 \
                --missing \
                --chr $chr \
                --out $genD/${ancestry}/autosomes/chr${chr}_missing_call_rate
    done
done

# if the missing call rate is 1 (i.e. all data was missing for that chromosome)
# Find subjects that have data missing for whole autosomes
for ancestry in {aa,ea,ha}; do
    echo -e "\n\n ================ ${ancestry} ================\n\n"
    for chr in {1..22}; do
        tail -n +2 $genD/${ancestry}/autosomes/chr${chr}_missing_call_rate.imiss | \
            awk '{ OFS="\t" } { if($6==1){ print $1,$2 } }' >> $genD/${ancestry}/autosomes/missing_whole_autosome.remove
    done
done

rm {aa,ea,ha}/autosomes/chr*missing_call_rate*

# %% [markdown]
# For this case none of the ancestry groups had subjects with missing autosome data. If subjects ever show up as having missing autosome data then further discussions need to be had on whether these subjects should be removed completely or whether they should only be excluded for the missing chromosomes.

# %% [markdown]
# ## Remove duplicate SNPs
# If multiple rsIDs are present then the one with the better genotype call rate across subjects should be retained. Obtaining the genotype call rates across subjects would need to be calculated using PLINK `--missing``.

# %%
## EC2 console ##

# Find duplicate rsIDs
for ancestry in {aa,ea,ha}; do
    cut -f2,2 $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138.bim | sort | uniq -D >\
        $genD/${ancestry}/autosomes/snp_duplicates.txt
        echo $ancestry
        head $genD/${ancestry}/autosomes/snp_duplicates.txt
done

# %% [markdown]
# For this case there are no duplicated rsIDs.

# %% [markdown]
# ## Strand orientation conversion & polymorphic SNP removal
# To determine if strand flipping is an issue, I perform a merge between chr1 of the study data and 1000 Genomes Phase 3 data. Doing this will produce a log of problematic variants that may be attributable to strand flipping. These results can be compared to chr1 data with flipped variants to see if strand orientation is truly the issue.
#
# As of 05/04/2018, the binary filesets per chromosome in PLINK format for 1000G Phase 3 can be found in `/shared/data/ref_panels/1000G/2013.05/plink` on AWS.

# %% [markdown]
# #### Flip test

# %%
## EC2 console ##

ancestry=ea
# Check flipping issues using chr1
echo -e "\n\n================ ${ancestry} ================\n\n"
echo -e "\n>>>>>>>> UNFLIPPED TEST\n"

# Extract chr1 unflipped variants
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138 \
    --chr 1 \
    --make-bed \
    --out $genD/${ancestry}/chr1_unflipped
"46392 variants and 651 people pass filters and QC."

# Attempt merge with 1000G chr1 data
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --bfile $genD/${ancestry}/chr1_unflipped \
    --bmerge /shared/data/ref_panels/1000G/2013.05/plink/ALL.chr1 \
    --make-bed \
    --out $genD/${ancestry}/chr1_unflipped_test
"Error: 838 variants with 3+ alleles present."

echo -e "\n>>>>>>>> FLIPPED TEST\n"
# Extract chr1 flipped variants
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138 \
    --chr 1 \
    --flip $genD/${ancestry}/chr1_unflipped_test-merge.missnp \
    --make-bed \
    --out $genD/${ancestry}/chr1_flipped
"46392 variants and 651 people pass filters and QC."

# Attempt merge with 1000G chr1 data
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --bfile $genD/${ancestry}/chr1_flipped \
    --bmerge /shared/data/ref_panels/1000G/2013.05/plink/ALL.chr1 \
    --make-bed \
    --out $genD/${ancestry}/chr1_flipped_test
"Error: 838 variants with 3+ alleles present."

# Clean up
rm $genD/${ancestry}/chr1_*

# %% [markdown]
# The merging issues persisted despite flipping. No issues were resolved or added by flipping, suggesting that the issues are all related to true polymorphic sites. With this being the case, we will get a list of all problematic variants and remove them.
#
# **Note**: The chip type used was Axiom_Smokesc1. We do not have a reference panel which suggest which variants to flip. From the file named `Axiom_Smokesc1.na34.annot.csv` in the marker-info directory:
#
# `/shared/data/studies/phs001109_kreek/genotype/original/processing/marker-info.MULTI`
#
# I learned that the strand orientation of all of the variants is "+".

# %% [markdown]
# #### Remove all polymorphic SNPs and flip when necessary

# %%
## EC2 console ##

# Get flip lists

# Extract unflipped variants
for ancestry in {aa,ea,ha}; do
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr} \
            --script_prefix $genD/${ancestry}/autosomes/chr${chr}_flip_tests \
            --mem 6 \
            --priority 0 \
            --program  /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --memory 6000 \
                --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138 \
                --chr ${chr} \
                --make-bed \
                --out $genD/${ancestry}/chr${chr}_unflipped
    done
done

# Attempt merge with 1000G data
for ancestry in {aa,ea,ha}; do
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr} \
            --script_prefix $genD/${ancestry}/autosomes/chr${chr}_flip_tests \
            --mem 6 \
            --priority 0 \
            --program  /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --memory 6000 \
                --bfile $genD/${ancestry}/chr${chr}_unflipped \
                --bmerge /shared/data/ref_panels/1000G/2013.05/plink/ALL.chr${chr} \
                --merge-mode 7 \
                --out $genD/${ancestry}/chr${chr}_unflipped_test
    done
done

# Flip problematic variants
for ancestry in {aa,ea,ha}; do
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr} \
            --script_prefix $genD/${ancestry}/autosomes/chr${chr}_flip_tests \
            --mem 6 \
            --priority 0 \
            --program  /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --memory 6000 \
                --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138 \
                --chr ${chr} \
                --flip $genD/${ancestry}/chr${chr}_unflipped_test.missnp \
                --make-bed \
                --out $genD/${ancestry}/chr${chr}_flipped
    done
done

# Attempt merge with 1000G data
for ancestry in {aa,ea,ha}; do
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr} \
            --script_prefix $genD/${ancestry}/autosomes/chr${chr}_flip_tests \
            --mem 6 \
            --priority 0 \
            --program  /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --memory 6000 \
                --bfile $genD/${ancestry}/chr${chr}_flipped \
                --bmerge /shared/data/ref_panels/1000G/2013.05/plink/ALL.chr${chr} \
                --merge-mode 7 \
                --out $genD/${ancestry}/chr${chr}_flipped_test
    done
done
    
# Combine flip lists
for ancestry in {aa,ea,ha}; do
    echo -e "\n\n======== ${ancestry} ========\n\n"
    cat $genD/${ancestry}/chr*_unflipped_test.missnp | sort -u > $genD/${ancestry}/chr_all_unflipped_test.missnp
    cat $genD/${ancestry}/chr*_flipped_test.missnp | sort -u > $genD/${ancestry}/chr_all_flipped_test.missnp
    comm -23 $genD/${ancestry}/chr_all_unflipped_test.missnp $genD/${ancestry}/chr_all_flipped_test.missnp \
        > $genD/${ancestry}/autosomes/chr_all.flip
    
    # Perform final flip
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138 \
        --flip $genD/${ancestry}/autosomes/chr_all.flip \
        --exclude $genD/${ancestry}/chr_all_flipped_test.missnp \
        --make-bed \
        --out $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped
done
wc -l {aa,ea,ha}/autosomes/genotypes_b37_dbsnp138_flipped.bim
"""
  544692 aa/autosomes/genotypes_b37_dbsnp138_flipped.bim
  544692 ea/autosomes/genotypes_b37_dbsnp138_flipped.bim
  544692 ha/autosomes/genotypes_b37_dbsnp138_flipped.bim
"""
wc -l {ea,aa,ha}/autosomes/chr_all.flip
"""wc -l {ea,aa}/autosomes/chr_all.flip
  88 ea/autosomes/chr_all.flip
  88 aa/autosomes/chr_all.flip
  88 ha/autosomes/chr_all.flip
"""

# Clean up
rm $genD/{aa,ea,ha}/chr*flipped*
rm $genD/{aa,ea,ha}/autosomes/chr*flip*

# %% [markdown]
# ## Detecting ancestral outliears with STRUCTURE
# [STRUCTURE](https://web.stanford.edu/group/pritchardlab/structure.html) is a software tool that can be used to identify admixed individuals, among other uses. By comparing the Kreek subjects with reference panel populations such as HapMap or 1000 Genomes, we can estimate the composition of an individual's ancestry to determine any discrepancies between self-reporting and genetic information. For the Kreek data, I will be comparing the individuals to 3 different superpopulations from the 1000 Genomes Phase 3 reference panel
#
# * AFR (African)
# * EAS (East Asian)
# * EUR (European)
#
# **SNP subset selection**
# For computational efficiency 10,000 SNPs are randomly chosen from the intersection of SNPs in the Kreek data with the 3 1000 Genomes superpopulations of interest. As of 10/09/2017 the binary filesets per chromosome in PLINK format for 1000G Phase 3 can be found in
# `/shared/data/ref_panels/1000G/2013.05/plink`. According to the [1000 Genomes paper](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4750478/).
#
# **NOTE:** The location `/shared/data/ref_panels/1000G/2014.10/1000GP_Phase3` also contatins 1000G phase 3 data derived from the May 2013 release. The difference is that it was downloaded from the [IMPUTE2 website](https://mathgen.stats.ox.ac.uk/impute/1000GP_Phase3.html) and reformatted to be directly compatible with IMPUTE2.

# %%
## EC2 console ##
mkdir $genD/structure

# Get lists of non-A/T and non-C/G SNPs
for ancestry in {aa,ea,ha}; do
    perl -lane 'if (($F[4] eq "A" && $F[5] ne "T") || ($F[4] eq "T" && $F[5] ne "A") || ($F[4] eq "C" && $F[5] ne "G") || ($F[4] eq "G" && $F[5] ne "C")) { print $F[1]; }' \
        $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped.bim |\
    sort -u | \
    grep "rs" \
    > $genD/structure/${ancestry}_no_at_cg_snps.txt
done

# Get rsID overlap between Kreek data ancestry groups
comm -12 <(comm -12 structure/aa_no_at_cg_snps.txt structure/ea_no_at_cg_snps.txt) structure/ha_no_at_cg_snps.txt | \
sort > structure/aa_ea_ha_shared_snps.txt

wc -l structure/aa_ea_ha_shared_snps.txt
"""476061 structure/aa_ea_shared_snps.txt"""


# Get list of variants from 1000G
mkdir $genD/structure/1000g_data
/shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name merge_1000g_snps \
    --script_prefix $genD/structure/1000g_data/merge_1000g_snps \
    --mem 3 \
    --priority 0 \
    --program "cut -f2,2 /shared/data/ref_panels/1000G/2013.05/plink/ALL.chr{1..22}.bim | \
        grep \"rs\" | \
        sort -u > $genD/structure/1000g_data/1000g_phase3_snps.txt"

wc -l $genD/structure/1000g_data/1000g_phase3_snps.txt
"""
79873045 structure/1000g_data/1000g_phase3_snps.txt
"""

# Get SNP overlap between Kreek data and 1000G
comm -12 $genD/structure/aa_ea_ha_shared_snps.txt $genD/structure/1000g_data/1000g_phase3_snps.txt >\
    $genD/structure/${study}_1000g_shared_snps.txt

wc -l $genD/structure/${study}_1000g_shared_snps.txt 
"""
462637 structure/kreek_1000g_shared_snps.txt
"""

# Select 10,000 random SNPs from Kreek and 1000G overlap
perl -ne 'print rand()."\t".$_' $genD/structure/${study}_1000g_shared_snps.txt | \
    sort -k1,1 | \
    head -10000 | \
    cut -f2,2 \
    > $genD/structure/10k_snp_random_sample.txt

# %% [markdown]
# #### Extract SNP subset PLINK binary filesets for Kreek data

# %%
## EC2 console ##

# Create ped and map files for study genotype data for SNP subset
for ancestry in {ea,aa,ha}; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped \
        --extract $genD/structure/10k_snp_random_sample.txt \
        --snps-only just-acgt \
        --recode \
        --out $genD/structure/${ancestry}_10k_snp_random_sample
done

# %% [markdown]
# #### Extract SNP subset PLINK binary filesets for 1000G data
#
# The 05/2013 release of the 1000 Genomes data have been previously processed and converted to PLINK binary fileset format, but the files include all the 1000G individuals. We are interested in only four superpopulations, so we create filesets specifically for each of these groups. It was brought to my attention that 1000G Phase 3 rsIDs may be duplicated across chromosomes potentially causing chromosome merging issues. For that reason, it is typically recommended to process the chromosomes separately initially, then combine post SNP subsetting. Subject IDs with superpopulation classifications are available at:
#
# `/shared/data/ref_panels/1000G/igsr_samples.tsv`

# %%
## EC2 console ##

# Ancestry specific directories
for pop in {AFR,EAS,EUR,AMR}; do
    mkdir $genD/structure/1000g_data/${pop}
done

# Get subject IDs by ancestry
awk 'BEGIN { FS="\t"; OFS="\t" } { if($7=="African"){print $1,$1} }' /shared/data/ref_panels/1000G/2013.05/igsr_samples.tsv \
    > $genD/structure/1000g_data/AFR/AFR_subject_ids.txt
awk 'BEGIN { FS="\t"; OFS="\t" } { if($7=="East Asian"){print $1,$1} }' /shared/data/ref_panels/1000G/2013.05/igsr_samples.tsv \
    > $genD/structure/1000g_data/EAS/EAS_subject_ids.txt
awk 'BEGIN { FS="\t"; OFS="\t" } { if($7=="European"){print $1,$1} }' /shared/data/ref_panels/1000G/2013.05/igsr_samples.tsv \
    > $genD/structure/1000g_data/EUR/EUR_subject_ids.txt
awk 'BEGIN { FS="\t"; OFS="\t" } { if($7=="American"){print $1,$1} }' /shared/data/ref_panels/1000G/2013.05/igsr_samples.tsv \
    > $genD/structure/1000g_data/AMR/AMR_subject_ids.txt

# Make new binary filesets for each 1000G group
# only keeping the data from individuals which are from 1 of the three super populations
for pop in {AFR,EAS,EUR,AMR}; do
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${pop}_${chr}_filter \
            --script_prefix $genD/structure/1000g_data/${pop}/ancestry_partition_chr${chr} \
            --mem 15.5 \
            --priority 0 \
            --program /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink  \
                --noweb \
                --memory 10000 \
                --bfile /shared/data/ref_panels/1000G/2013.05/plink/ALL.chr${chr} \
                --keep $genD/structure/1000g_data/${pop}/${pop}_subject_ids.txt \
                --extract $genD/structure/10k_snp_random_sample.txt \
                --make-bed \
                --out $genD/structure/1000g_data/${pop}/${pop}_chr${chr}_10k_snp_random_sample
    done
done


# Create merge lists and merge autosomes for each 1000G population
dataD=$genD/structure/1000g_data
for pop in {AFR,EAS,EUR,AMR}; do
    echo "${dataD}/${pop}/${pop}_chr1_10k_snp_random_sample" > ${dataD}/${pop}/${pop}_autosome_merge_list.txt
    for chr in {2..22}; do
        echo "${dataD}/${pop}/${pop}_chr${chr}_10k_snp_random_sample" \
        >> ${dataD}/${pop}/${pop}_autosome_merge_list.txt
    done
done

for pop in {AFR,EAS,EUR,AMR}; do
    /shared/bioinformatics/software/scripts/qsub_job.sh \
        --job_name ${pop}_merge_plink_filesets \
        --script_prefix $dataD/${pop}/merge_plink_filesets \
        --mem 4 \
        --priority 0 \
        --program /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --memory 4000 \
            --merge-list $dataD/${pop}/${pop}_autosome_merge_list.txt \
            --snps-only just-acgt \
            --make-bed \
            --out $dataD/${pop}/${pop}_all_autosomes_10k_snp_random_sample
done

# %% [markdown]
# #### Discrepancy assessment between Kreek and 1000G data
# As a quality check that the SNP data subsampled from the Kreek and 1000 Genomes data are the same, I will attempt to merge an arbitrarily selected group from each data set using PLINK. If any errors are found, PLINK will generate an error file. Likely causes of errors would be:
#
# * SNP genomic coordinates not matching
# * SNP duplicates found
# * SNP strand orientation flipped
#
# If errors are found the two options for moving forward are
#
# 1. Re-run the 10,000 SNP subsampling and hope the SNPs chosen do not raise issues
# 2. Remove the problematic SNPs
# Option #2 is the prefered approach and the one I will be taking.

# %%
## EC2 console ##
ancestry="aa"
# Merge EA and EUR genotype files
# --merge-mode 7 (no merge) Report mismatching nonmissing calls.
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --file $genD/structure/${ancestry}_10k_snp_random_sample \
    --bmerge $genD/structure/1000g_data/AFR/AFR_all_autosomes_10k_snp_random_sample \
    --merge-mode 7 \
    --out $genD/structure/1000g_AFR_${study}_${ancestry}_10k_snp_random_sample

ancestry="ea"
# Merge EA and EUR genotype files
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --file $genD/structure/${ancestry}_10k_snp_random_sample \
    --bmerge $genD/structure/1000g_data/EUR/EUR_all_autosomes_10k_snp_random_sample \
    --merge-mode 7 \
    --out $genD/structure/1000g_EUR_${study}_${ancestry}_10k_snp_random_sample

ancestry="ha"
# Merge HA and AMR genotype files
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --file $genD/structure/${ancestry}_10k_snp_random_sample \
    --bmerge $genD/structure/1000g_data/AMR/AMR_all_autosomes_10k_snp_random_sample \
    --merge-mode 7 \
    --out $genD/structure/1000g_AMR_${study}_${ancestry}_10k_snp_random_sample


wc -l $genD/structure/*diff
"""
  1 /shared/data/studies/heroin/kreek/genotype/observed/processing/structure/1000g_AFR_kreek_aa_10k_snp_random_sample.diff
  1 /shared/data/studies/heroin/kreek/genotype/observed/processing/structure/1000g_EUR_kreek_ea_10k_snp_random_sample.diff
  1 /shared/data/studies/heroin/kreek/genotype/observed/processing/structure/1000g_AMR_kreek_ea_10k_snp_random_sample.diff
"""

# %% [markdown]
# No diff, only header is in the \*.diff files

# %% [markdown]
# #### STRUCTURE input file construction
# Because our initial merge was successful, I proceed without applying a blacklist filtering.

# %%
## EC2 console ##

# Create final ped and map files for Kreek genotype data for SNP subset
for ancestry in {aa,ea,ha}; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 3000 \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped \
        --extract $genD/structure/10k_snp_random_sample.txt \
        --snps-only just-acgt \
        --recode \
        --out $genD/structure/${ancestry}_10k_snp_random_sample.final
done

# Create ped and map files for each 1000G population
for pop in {AFR,EAS,EUR,AMR}; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 1024 \
        --bfile $genD/structure/1000g_data/${pop}/${pop}_all_autosomes_10k_snp_random_sample \
        --recode \
        --out $genD/structure/1000g_data/${pop}_10k_snp_random_sample.final
done


# Final check for SNP discrepancies
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --file $genD/structure/aa_10k_snp_random_sample.final \
    --merge $genD/structure/1000g_data/AFR_10k_snp_random_sample.final \
    --recode \
    --out $genD/structure_input_test


/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --file $genD/structure/ea_10k_snp_random_sample.final \
    --merge $genD/structure/1000g_data/EUR_10k_snp_random_sample.final \
    --recode \
    --out $genD/structure_input_test2

/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --file $genD/structure/ha_10k_snp_random_sample.final \
    --merge $genD/structure/1000g_data/AMR_10k_snp_random_sample.final \
    --recode \
    --out $genD/structure_input_test3


wc -l  $genD/structure_input_test*.map
"""
 10000 structure_input_test3.map
 10000 structure_input_test2.map
 10000 structure_input_test.map
"""

# %% [markdown]
# No merging issues were identified in the final check, so I will use the script ped2structure.pl to convert the PED file into a STRUCTURE input file format. This script takes two inputs. The first is an integer that serves as an ID to distinguish between a reference panel population or a study data set group. The second input is an integer that is unique to each group/population regardless of whether it's from the study or 1000G data.
#
# The goal of the conversion script is to generate a single STRUCTURE input file containing genotype information for the ~10,000 (post-filtered) subsampled SNPs and the individuals from the study and 1000G data sets. Documentation on the format can be found [here](https://web.stanford.edu/group/pritchardlab/structure_software/release_versions/v2.3.4/structure_doc.pdf). The first three columns contatin the following information respectively
#
# 1. Subject identifier
# 2. Group/population identifier. Distinct for each ancestry group or superpopulation
# 3. Boolean indicator (1=True, 0=False) specifying reference panel populations. This is used by STRUCTURE to define the ancestry groups
#
# We will be running structure assuming that the study subjects descended from three populations. The traditional approach would be to use AFR, EAS, and EUR. I will run STRUCTURE using these 1000G superpopulations.
#
# Note: for $K$ reference panel populations used for ancestry comparisons, the reference panel populations must be given group IDs between 1 and $K$.

# %%
## EC2 console ##
mkdir $genD/structure/input_files

groupID=1 #distinguish between all groups

# Append 1000G populations to STRUCTURE file
truncate -s 0 $genD/structure/input_files/input_afr_eas_eur
for pop in {AFR,EAS,EUR}; do
    cat $genD/structure/1000g_data/${pop}_10k_snp_random_sample.final.ped | \
    /shared/bioinformatics/software/perl/file_conversion/ped2structure.pl 1 ${groupID} \
    >> $genD/structure/input_files/input_afr_eas_eur
    groupID=`echo ${groupID} + 1 | bc`
done

# Append remaining ancestry groups to STRUCTURE file
for ancestry in {aa,ea,ha}; do
    cat $genD/structure/${ancestry}_10k_snp_random_sample.final.ped | \
    /shared/bioinformatics/software/perl/file_conversion/ped2structure.pl 0 ${groupID} \
    >> $genD/structure/input_files/input_afr_eas_eur
    groupID=`echo ${groupID} + 1 | bc` 
done

# %% [markdown]
# #### Run STRUCUTRE
# For running STRUCTURE, the following command line parameters are explicitly specified
#
# * m - Main parameter file
# * e - Additional parameter file
# * i - Input data file
# * o - Output file
# * L - Number of loci in data file
# * N - Number of subjects
# * K - Maximum number of populations
#
# The remaining parameters are specified in the mainparams and extraparams files. Any values specified on the command-line override the values in the configuration files. Documentation on the parameter options can be found [here](https://web.stanford.edu/group/pritchardlab/structure_software/release_versions/v2.3.4/structure_doc.pdf).
#
# Because I am using combinations of three from the four 1000G superpopulations, I will run STRUCTURE for each of these combinations.

# %%
## EC2 console ##

mkdir $genD/structure/output_files

# Run Structure using AFR, EAS, and EUR
# Why add the random number generator flag?
L=$(wc -l $genD/structure/${ancestry}_10k_snp_random_sample.final.map | perl -lane 'print $F[0];')
N=$(wc -l $genD/structure/input_files/input_afr_eas_eur | perl -lane 'print $F[0]/2;')
sh /shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name structure_afr_eas_eur \
    --script_prefix $genD/structure/output_files/structure_afr_eas_eur \
    --mem 15 \
    --nslots 4 \
    --priority 0 \
    --program /shared/bioinformatics/software/third_party/structure_v2.3.4/console/structure \
         -m /shared/bioinformatics/software/third_party/structure_v2.3.4/console/mainparams \
         -e /shared/bioinformatics/software/third_party/structure_v2.3.4/console/extraparams \
         -i $genD/structure/input_files/input_afr_eas_eur \
         -o $genD/structure/output_files/output_afr_eas_eur \
         -L $L \
         -N $N \
         -K 3 \
         -D 1523031945

# %% [markdown]
# #### Producing triangle plots
# [Triangle or ternary plots](https://en.wikipedia.org/wiki/Ternary_plot) provide a means to visualize membership strength. For the purposes of the Kreek data, the triangle plots are used to determine how similar self-reports of individuals from a Kreek ancestry group are to three disparate reference populations. The visualizations allow for the identification of potential outliers that would be removed from downstream processing and analysis.
#
# **Note**: The command line Perl script below assumes a specific order of the STRUCTURE output data in regards to the group IDs. Modifications should be made as necessary to ensure that the labels match with the ID. Additionally, `triangle_plot.R` does not check that the cluster specifications match the given 1000G superpopulation labels. Be sure to assign the right label to the right group ID from previous processing steps.

# %%
## EC2 console ##

mkdir $genD/structure/triangle_plots

#### AFR, EAS, and EUR ####

# Prepare results for triangle plot
perl -ne 'if (/%Miss/) {
              $in=1;
              print "num\tID\tpop\tcluster1\tcluster2\tcluster3\n";
          }
          if ($in==1 && !/Label/ && !/^\s+$/) {
              @datasets=("AFR","EAS","EUR","Kreek_AA","Kreek_EA", "Kreek_HA");
              s/^\s+//g;
              @F=split /\s+/;
              # Grab only Kreek groups by ID
              if ($F[3] > 3) {
                  print $F[0]."\t".$F[1]."\t".$datasets[$F[3]-1]."\t".$F[5]."\t".$F[6]."\t".$F[7]."\n";
              }
          } 
          s/\s+//g;
          if ($_ eq "") { $in=0; }' $genD/structure/output_files/output_afr_eas_eur_f > \
    $genD/structure/triangle_plots/afr_eas_eur.triangle_input

# Prepare id xref file
perl -ne 'if ($count==0) { print "num\tID\n"; }
          if (!defined $even) { print STDERR "LALALA\n";} 
          if ($even==0) {/^(\S+)/; print $count+1; print "\t".$1."\n"; $count++; $even=1}
          else {$even=0}' $genD/structure/input_files/input_afr_eas_eur > \
    $genD/structure/triangle_plots/afr_eas_eur_id_xref

# Generate triangle plot
Rscript /shared/bioinformatics/software/R/triangle_plot.R \
    --data $genD/structure/triangle_plots/afr_eas_eur.triangle_input \
    --prefix $genD/structure/triangle_plots/afr_eas_eur \
    --cluster1 African \
    --cluster2 Asian \
    --cluster3 European \
    --xref $genD/structure/triangle_plots/afr_eas_eur_id_xref

# %%
## local console ##
cd /cygdrive/c/Users/jmarks/Desktop/Projects/heroin/ngc/kreek/20181124/structure
scp -i ~/.ssh/gwas_rsa ec2-user@54.90.227.178:/shared/data/studies/heroin/kreek/genotype/observed/processing/structure/triangle_plots/*g .

# %% [markdown]
# #### View Plots
# ##### Self-report used
# The plots below are segregated by self-reported ancestry data. Next we will produce the plots again except without relying on any self-report information.

# %%
## R console ##
library("IRdisplay")
display_png(file="C:/Users/jmarks/Desktop/Projects//heroin//ngc//kreek//20181124/aa/afr_eas_eur_Kreek_AA.jpg", width=800, height=800)
display_png(file="C:/Users/jmarks/Desktop/Projects//heroin//ngc//kreek//20181124/ea/afr_eas_eur_Kreek_EA.jpg", width=800, height=800)
display_png(file="C:/Users/jmarks/Desktop/Projects//heroin//ngc//kreek//20181124/ha/afr_eas_eur_Kreek_HA.jpg", width=800, height=800)

# %% [markdown]
# #### Reassigning and removing outliers
# Based on the triangle plots and discussions with Bryan Quach,re how to handle ancestral outliers, the following retainment thresholds should be implemented:
#
#
# | Action Description | Thresholding Criteria      |
# |--------------------|----------------------------|
# | For EA retainment | (AFR < 25%)$ \wedge $(EAS < 25%) |
# | For AA retainment | (AFR > 25%)$ \wedge $(EAS < 25%) |
# | For HA retainment | (AFR < 25%)$ \wedge $(EAS > 25%) |
#
#
# For the Hispanics we are essentially keeping anyone that's not too similar to AFR or EUR ancestry.
#
# **Note**: we decided to ignore self report data, so this next section we do not run.

# %%
## EC2 command line ##
#
## Create triangle plot input with potential outliers filtered
#head -1 structure/triangle_plots/afr_eas_eur.triangle_input >\
#    structure/triangle_plots/afr_eas_eur_filtered_aa.triangle_input
#
## AA retained
#tail -n +2 structure/triangle_plots/afr_eas_eur.triangle_input | \
#    perl -lane 'if ($F[2] eq "Kreek_AA" && ($F[3] > 0.25 && $F[4] < 0.25)) { print $_; }' \
#    >> structure/triangle_plots/afr_eas_eur_filtered_aa.triangle_input
#
## Create triangle plot input with potential outliers filtered
#head -1 structure/triangle_plots/afr_eas_eur.triangle_input >\
#    structure/triangle_plots/afr_eas_eur_filtered_ea.triangle_input
#
## EA retained
#tail -n +2 structure/triangle_plots/afr_eas_eur.triangle_input |\
#    perl -lane 'if ($F[2] eq "Kreek_EA" && ($F[5] > 0.75 && $F[4] < 0.25)) { print $_; }' \
#    >> structure/triangle_plots/afr_eas_eur_filtered_ea.triangle_input
#
#
## Generate triangle plot
#Rscript /shared/bioinformatics/software/R/triangle_plot.R \
#    --data structure/triangle_plots/afr_eas_eur_filtered_aa.triangle_input \
#    --prefix structure/triangle_plots/afr_eas_eur_filtered_aa \
#    --cluster1 African \
#    --cluster2 Asian \
#    --cluster3 European
#
#Rscript /shared/bioinformatics/software/R/triangle_plot.R \
#    --data structure/triangle_plots/afr_eas_eur_filtered_ea.triangle_input \
#    --prefix structure/triangle_plots/afr_eas_eur_filtered_ea \
#    --cluster1 African \
#    --cluster2 Asian \
#    --cluster3 European

# %% [markdown]
# #### Reassigning (Part 2)
# We are going to keep the same filters as before, namely:
#
# | Action Description | Thresholding Criteria     |
# |--------------------|---------------------------|
# | For EA retainment  | (AFR < 25%) ∧ (EAS < 25%) |
# | For AA retainment  | (AFR > 25%) ∧ (EAS < 25%) |
# | For HA retainment  | (AFR < 25%) ∧ (EAS > 25%) |
#
#
# This time, we are going to ignore the self-reported data though.

# %%
### get details on which subjects are reassigned ###

plots=$genD/structure/triangle_plots/ignore_self
mkdir $plots

cp $genD/structure/triangle_plots/afr_eas_eur.triangle_input $plots/

# create two files based on the filtering criteria in the table above.

# AA retained
#--------------------------------------------------------------------------------
# Create triangle plot input with potential outliers filtered
head -1 $plots/afr_eas_eur.triangle_input > $plots/afr_eas_eur_filtered_aa.triangle_input

tail -n +2 $plots/afr_eas_eur.triangle_input | \
    perl -lane 'if (($F[3] > 0.25 && $F[4] < 0.25)) { print $_; }' \
    >> $plots/afr_eas_eur_filtered_aa.triangle_input

# Number of AA without pre-filtered
awk ' $3=="Kreek_AA"' $plots/afr_eas_eur.triangle_input | wc -l 
"""598"""

# Number of AA remaining post-filtered
awk ' $3=="Kreek_AA"' $plots/afr_eas_eur_filtered_aa.triangle_input | wc -l 
"""591"""

# Number of non-AA subjects added
awk 'NR>=2{ if($3!="Kreek_AA") {print $0}}' $plots/afr_eas_eur_filtered_aa.triangle_input | wc -l 
"""125"""

# Total number of subjects clasified as AA (don't forget to account for the header)
wc -l $plots/afr_eas_eur_filtered_aa.triangle_input
"""717""" # so actually 716 


# EA retained
#--------------------------------------------------------------------------------
# Create triangle plot input with potential outliers filtered
head -1 $plots/afr_eas_eur.triangle_input > $plots/afr_eas_eur_filtered_ea.triangle_input

tail -n +2 $plots/afr_eas_eur.triangle_input |\
    perl -lane 'if (($F[3] < 0.25 && $F[4] < 0.25)) { print $_; }' \
    >> $plots/afr_eas_eur_filtered_ea.triangle_input

# Number of EA without pre-filtered
awk ' $3=="Kreek_EA"' $plots/afr_eas_eur.triangle_input | wc -l 
"""651"""

# Number of EA remaining post-filtered
awk ' $3=="Kreek_EA"' $plots/afr_eas_eur_filtered_ea.triangle_input | wc -l 
"""638"""

# Number of non-EA subjects added
awk 'NR>=2{ if($3!="Kreek_EA") {print $0}}' $plots/afr_eas_eur_filtered_ea.triangle_input | wc -l 
"""165"""

# Total number of subjects clasified as EA (don't forget to account for the header)
wc -l $plots/afr_eas_eur_filtered_ea.triangle_input
"""804""" # so actually 803 


# HA retained
#--------------------------------------------------------------------------------
# Create triangle plot input with potential outliers filtered
head -1 $plots/afr_eas_eur.triangle_input > $plots/afr_eas_eur_filtered_ha.triangle_input

tail -n +2 $plots/afr_eas_eur.triangle_input |\
    perl -lane 'if (($F[3] < 0.25 && $F[4] > 0.25)) { print $_; }' \
    >> afr_eas_eur_filtered_ha.triangle_input

# Number of HA without pre-filtered
awk ' $3=="Kreek_HA"' $plots/afr_eas_eur.triangle_input | wc -l 
"""302"""

# Number of HA remaining post-filtered
awk ' $3=="Kreek_HA"' $plots/afr_eas_eur_filtered_ha.triangle_input | wc -l 
"""23"""

# Number of non-HA subjects added
awk 'NR>=2{ if($3!="Kreek_HA") {print $0}}' $plots/afr_eas_eur_filtered_ha.triangle_input | wc -l 
"""6"""

# Total number of subjects clasified as HA (don't forget to account for the header)
wc -l $plots/afr_eas_eur_filtered_ha.triangle_input
"""30""" # so actually 29

# %% [markdown]
# Create input for triangle plots.
#
# **Note** we are not going to use HA group now.

# %%
# AA retained
#--------------------------------------------------------------------------------
# Create triangle plot input with potential outliers filtered
head -1 $genD/structure/triangle_plots/afr_eas_eur.triangle_input > \
    $plots/afr_eas_eur_filtered.triangle_input

tail -n +2 $plots/afr_eas_eur.triangle_input | \
    perl -lane 'if (($F[3] > 0.25 && $F[4] < 0.25)) { print $_ }' \
    > $plots/aa_filtered
awk 'BEGIN{OFS="\t"} {$3="Kreek_AA";print $0}' $plots/aa_filtered >> $plots/afr_eas_eur_filtered.triangle_input


# EA retained
#--------------------------------------------------------------------------------
# Create triangle plot input with potential outliers filtered

tail -n +2 $plots/afr_eas_eur.triangle_input |\
    perl -lane 'if (($F[3] < 0.25 && $F[4] < 0.25)) { print $_; }' \
    > $plots/ea_filtered
awk 'BEGIN{OFS="\t"} {$3="Kreek_EA";print $0}' $plots/ea_filtered >> $plots/afr_eas_eur_filtered.triangle_input
--------------------------------------------------------------------------------


# Generate triangle plot
Rscript /shared/bioinformatics/software/R/triangle_plot.R \
    --data $plots/afr_eas_eur_filtered.triangle_input \
    --prefix $plots/afr_eas_eur_filtered \
    --cluster1 African \
    --cluster2 Asian \
    --cluster3 European

# %%
# local #
cd /cygdrive/c/Users/jmarks/Desktop/Projects/heroin/ngc/kreek/20181113/structure/ignore_self
$ scp -i ~/.ssh/gwas_rsa ec2-user@54.90.227.178:/shared/data/studies/heroin/kreek/genotype/observed/processing/structure/triangle_plots/igno*/*g .

# %% [markdown]
# | Action Description | Thresholding Criteria     |
# |--------------------|---------------------------|
# | For AA retainment  | (AFR > 25%) ∧ (EAS < 25%) |
# | For EA retainment  | (AFR < 25%) ∧ (EAS < 25%) |

# %%
library("IRdisplay")
display_png(file="C:/Users/jmarks/Desktop/Projects//heroin/ngc/kreek/20181124/aa/afr_eas_eur_filtered_Kreek_AA.jpg", width=800, height=800)
display_png(file="C:/Users/jmarks/Desktop/Projects//heroin/ngc/kreek/20181124/ea/afr_eas_eur_filtered_Kreek_EA.jpg", width=800, height=800)

# %% [markdown]
# #### Stringent EA Filter
#
# We are going to try a more stringent filter for the EAs to hopefully reduce the inflation in the lambda when performing the GWAS.
#
# | Action Description | Thresholding Criteria     |
# |--------------------|---------------------------|
# | For AA retainment  | (AFR > 25%) ∧ (EAS < 25%) |
# | For EA retainment  | (AFR < 10%) ∧ (EAS < 10%) |

# %%
# AA retained
#--------------------------------------------------------------------------------
# Create triangle plot input with potential outliers filtered
head -1 $genD/structure/triangle_plots/afr_eas_eur.triangle_input > \
    $plots/afr_eas_eur_filtered2.triangle_input

tail -n +2 $plots/afr_eas_eur.triangle_input | \
    perl -lane 'if (($F[3] > 0.25 && $F[4] < 0.25)) { print $_ }' \
    > $plots/aa_filtered2
awk 'BEGIN{OFS="\t"} {$3="Kreek_AA";print $0}' $plots/aa_filtered2 >> $plots/afr_eas_eur_filtered2.triangle_input


# EA retained
#--------------------------------------------------------------------------------
# Create triangle plot input with potential outliers filtered

tail -n +2 $plots/afr_eas_eur.triangle_input |\
    perl -lane 'if (($F[3] < 0.10 && $F[4] < 0.10)) { print $_; }' \
    > $plots/ea_filtered2
awk 'BEGIN{OFS="\t"} {$3="Kreek_EA";print $0}' $plots/ea_filtered2 >> $plots/afr_eas_eur_filtered2.triangle_input
#--------------------------------------------------------------------------------

# Generate triangle plot
Rscript /shared/bioinformatics/software/R/triangle_plot.R \
    --data $plots/afr_eas_eur_filtered2.triangle_input \
    --prefix $plots/afr_eas_eur_filtered2 \
    --cluster1 African \
    --cluster2 Asian \
    --cluster3 European

# %%
cd /cygdrive/c/Users/jmarks/Desktop/Projects/heroin/ngc/kreek/20181113/structure/ignore_self
$ scp -i ~/.ssh/gwas_rsa ec2-user@54.90.227.178:/shared/data/studies/heroin/kreek/genotype/observed/processing/structure/triangle_plots/igno*/*g .

# %% [markdown]
# | Action Description | Thresholding Criteria     |
# |--------------------|---------------------------|
# | For AA retainment  | (AFR > 25%) ∧ (EAS < 25%) |
# | For EA retainment  | (AFR < 10%) ∧ (EAS < 10%) |

# %%
library("IRdisplay")
display_png(file="C:/Users/jmarks/Desktop/Projects//heroin/ngc/kreek/20181124/aa/afr_eas_eur_filtered2_Kreek_AA.jpg", width=800, height=800)
display_png(file="C:/Users/jmarks/Desktop/Projects//heroin/ngc/kreek/20181124/ea/afr_eas_eur_filtered2_Kreek_EA.jpg", width=800, height=800)

# %% [markdown]
# #### Create reassignment and remove lists
# Here is a breakdown of the filtering results. These results are based on filtering exclusively by the ancestral thresholds - disregarding self-report information.
#
# | Ancestry | Subjects Pre-Filtering | Subjects Removed | Subjects Added | Subjects Post-Filtering |
# |----------|------------------------|------------------|----------------|-------------------------|
# | EA       |  651                   |  35              |  18            | 634                     |
# | AA       | 598                    | 7                | 125            | 716                     |
#
# * I will proceed with the the retainment and reassignment of the EAs and AAs

# %%
## EC2 command line

### AA ###
################################################################################
# total post-filtered AAs (disreguarding self-report)
tail -n +2 $genD/structure/triangle_plots/afr_eas_eur.triangle_input | \
    perl -lane 'if ($F[3] > 0.25 && $F[4] < 0.25) { $F[1] =~ /(\S+)_(\S+)/; print $1." ".$2; }' \
        > $genD/aa/autosomes/structure.keep
    wc -l $genD/aa/autosomes/structure.keep
"""716"""

# initial number of AAs
tail -n +2 $genD/structure/triangle_plots/afr_eas_eur.triangle_input | \
    perl -lane 'if ($F[2] eq "Kreek_AA" ) { $F[1] =~ /(\S+)_(\S+)/; print $1." ".$2; }' \
        | wc -l 
"""598"""

# Self report AAs retained (converse of removed)
## AFR > 25% and EAS < 25% ##
tail -n +2 $genD/structure/triangle_plots/afr_eas_eur.triangle_input | \
    perl -lane 'if ($F[2] eq "Kreek_AA" && ($F[3] > 0.25 && $F[4] < 0.25)) { $F[1] =~ /(\S+)_(\S+)/; print $1." ".$2; }' \
        | wc -l 
"""591"""

# Subjects added (EAs that got reassigned to AA)
tail -n +2 $genD/structure/triangle_plots/afr_eas_eur.triangle_input | \
    perl -lane 'if ($F[2] eq "Kreek_EA" && ($F[3] > 0.25 && $F[4] < 0.25)) { $F[1] =~ /(\S+)_(\S+)/; print $1." ".$2; }' \
        | wc -l 
"""7"""
################################################################################

### EA ###
# total post-filtered EAs (disreguarding self-report)
## AFR<10% and EAS<10% ##
tail -n +2 $genD/structure/triangle_plots/afr_eas_eur.triangle_input | \
    perl -lane 'if ($F[3] < 0.10 && $F[4] < 0.10) { $F[1] =~ /(\S+)_(\S+)/; print $1." ".$2; }' \
    > $genD/ea/autosomes/structure.keep
wc -l $genD/ea/autosomes/structure.keep
"""634"""

# initial number of EAs
tail -n +2 $genD/structure/triangle_plots/afr_eas_eur.triangle_input | \
    perl -lane 'if ($F[2] eq "Kreek_EA" ) { $F[1] =~ /(\S+)_(\S+)/; print $1." ".$2; }' \
        | wc -l 
"""651"""

# Self reported EAs retained (converse of removed)
tail -n +2 $genD/structure/triangle_plots/afr_eas_eur.triangle_input | \
    perl -lane 'if ($F[2] eq "Kreek_EA" && ($F[3] < 0.10 && $F[4] < 0.10)) { $F[1] =~ /(\S+)_(\S+)/; print $1." ".$2; }'  | wc -l
"""616"""

# Subjects added (AAs that got reassigned to EA)
tail -n +2 $genD/structure/triangle_plots/afr_eas_eur.triangle_input | \
    perl -lane 'if ($F[2] eq "Kreek_AA" && ($F[3] < 0.10 && $F[4] < 0.10)) { $F[1] =~ /(\S+)_(\S+)/; print $1." ".$2; }' \
        | wc -l 
"""4"""
################################################################################

# Create master subject lists
cat $genD/aa/autosomes/structure.keep | sort > $genD/aa/updated_subject_ids.keep
cat $genD/ea/autosomes/structure.keep | sort > $genD/ea/updated_subject_ids.keep

# %% [markdown]
# ```
# wc -l $genD/*/update*
#   716 /shared/data/studies/heroin/kreek/genotype/observed/processing/aa/updated_subject_ids.keep
#   634 /shared/data/studies/heroin/kreek/genotype/observed/processing/ea/updated_subject_ids.keep
# ```

# %% [markdown]
# ## Create updated PLINK filesets

# %%
## EC2 command line

# clean up previous processing 
rm -rf $genD/{aa,ea}/{autosomes,chrX}
rm $genD/{aa,ea}/chr*flipped*

for ancestry in {aa,ea}; do
    echo -e "\n\n======== ${ancestry} ========\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 5000 \
        --bfile genotypes_b37_dbsnp138 \
        --keep ${ancestry}/updated_subject_ids.keep \
        --make-bed \
        --out ${ancestry}/genotypes_b37_dbsnp138
done

# %%
## EC2 command line

# Create autosome and chrX file sets
for ancestry in {aa,ea}; do
    echo -e "\n\n======== ${ancestry} ========\n\n"
    mkdir $genD/${ancestry}/{chrX,autosomes}

    # Autosomes
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 5000 \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138 \
        --autosome \
        --make-bed \
        --out $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138

    # ChrX (include split PARs)
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 5000 \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138 \
        --chr 23,25 \
        --make-bed \
        --out $genD/${ancestry}/chrX/genotypes_b37_dbsnp138_unmerged

    # Combine split chrX and PARs
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 5000 \
        --bfile $genD/${ancestry}/chrX/genotypes_b37_dbsnp138_unmerged \
        --merge-x \
        --make-bed \
        --out $genD/${ancestry}/chrX/genotypes_b37_dbsnp138
done

# %%
## EC2 command line

# Get flip lists

# Extract unflipped variants
for ancestry in {aa,ea}; do
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr} \
            --script_prefix $genD/${ancestry}/autosomes/chr${chr}_flip_tests \
            --mem 6 \
            --priority 0 \
            --program  /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --memory 6000 \
                --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138 \
                --chr ${chr} \
                --make-bed \
                --out $genD/${ancestry}/chr${chr}_unflipped
    done
done


# Attempt merge with 1000G data
for ancestry in {aa,ea}; do
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr} \
            --script_prefix $genD/${ancestry}/autosomes/chr${chr}_flip_tests \
            --mem 6 \
            --priority 0 \
            --program  /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --memory 6000 \
                --bfile $genD/${ancestry}/chr${chr}_unflipped \
                --bmerge /shared/data/ref_panels/1000G/2013.05/plink/ALL.chr${chr} \
                --merge-mode 7 \
                --out $genD/${ancestry}/chr${chr}_unflipped_test
    done
done

# Flip problematic variants
for ancestry in {aa,ea}; do
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr} \
            --script_prefix $genD/${ancestry}/autosomes/chr${chr}_flip_tests \
            --mem 6 \
            --priority 0 \
            --program  /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --memory 6000 \
                --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138 \
                --chr ${chr} \
                --flip $genD/${ancestry}/chr${chr}_unflipped_test.missnp \
                --make-bed \
                --out $genD/${ancestry}/chr${chr}_flipped
    done
done

# Attempt merge with 1000G data
for ancestry in {aa,ea}; do
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr} \
            --script_prefix $genD/${ancestry}/autosomes/chr${chr}_flip_tests \
            --mem 6 \
            --priority 0 \
            --program  /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --memory 6000 \
                --bfile $genD/${ancestry}/chr${chr}_flipped \
                --bmerge /shared/data/ref_panels/1000G/2013.05/plink/ALL.chr${chr} \
                --merge-mode 7 \
                --out $genD/${ancestry}/chr${chr}_flipped_test
    done
done

# Combine flip lists
for ancestry in {aa,ea}; do
    echo -e "\n\n======== ${ancestry} ========\n\n"
    cat $genD/${ancestry}/chr*_unflipped_test.missnp | sort -u > $genD/${ancestry}/chr_all_unflipped_test.missnp
    cat $genD/${ancestry}/chr*_flipped_test.missnp | sort -u > $genD/${ancestry}/chr_all_flipped_test.missnp
    comm -23 $genD/${ancestry}/chr_all_unflipped_test.missnp $genD/${ancestry}/chr_all_flipped_test.missnp \
        > $genD/${ancestry}/autosomes/chr_all.flip
    
    # Perform final flip
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138 \
        --flip $genD/${ancestry}/autosomes/chr_all.flip \
        --exclude $genD/${ancestry}/chr_all_flipped_test.missnp \
        --make-bed \
        --out $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped
done

# Clean up
rm $genD/{aa,ea}/chr*flipped*
rm $genD/{aa,ea}/autosomes/chr*flip*

# %% [markdown]
# ## Genotype call rate variant filter
# I calculate the genotype missing call rate and remove any variants with a rate >3%.

# %%
## EC2 command line

# Get missing call rate
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 5000 \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped \
        --geno 0.03 \
        --make-bed \
        --out $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped_structure_variant_missing_lte_0.03_filter
done

# %% [markdown]
# ## Hardy-Weinberg equilibrium filtering
# Extensive deviation from Hardy-Weinberg equilibrium (HWE) can be indicative of a genotyping or genotype calling error. Using PLINK --hardy, I calculate goodness of fit test p-values for allele frequencies compared to HWE. Any variant with p < 0.0001 is removed.

# %%
## EC2 command line

# Calculate HW p-values for each ancestry group
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped_structure_variant_missing_lte_0.03_filter \
        --hwe 0.0001 \
        --make-bed \
        --out $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_filter
done

# %%
/shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name sleep \
            --script_prefix ~/sleep.test \
            --mem 7.5 \
            --priority 0 \
            --nslots 1 \
            --program bash ~/sleep.sh

# %% [markdown]
# ## Genotype call rate subject filter
# **Note**: The genotype call rate subject filtereing and the subsequent LD pruning are specifically for relatedness filtering calculations. Autosomes and chrX merging will be done using the PLINK file sets generated in the preceding step (HWE filtering).
#
# I calculate the genotype missing call rate and remove any subjects with a rate > $3\%$.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Remove variants
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_filter \
        --mind 0.03 \
        --make-bed \
        --out $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_lte_0.03_filter
done

# %% [markdown]
# ## Linkage disequilibrium pruning
# Linkage disequilibrium (LD) pruning eliminates a large degree of redundancy in the data and reduces the influence of chromosomal artifacts. The objective of LD pruning is to select a subset of variants based off of LD such that the variants in the subset are independent. This filtering will not carry forward to the final processed results, but this step improves the quality of identity-by-state (IBS) and identity-by-descent (IBD) calculations. Consequently, the LD pruned data will be used as input into IBS and IBD calculations.
#
# LD pruning is implemented using [PLINK --indep-pairwise](https://www.cog-genomics.org/plink/1.9/ld#indep).

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Run per chromosome LD pruning 
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr}_ld_prune \
            --script_prefix $genD/${ancestry}/autosomes/${ancestry}_${chr}_ld_prune \
            --mem 7.5 \
            --priority 0 \
            --nslots 1 \
            --program /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_lte_0.03_filter \
                --indep-pairwise 50 5 0.5 \
                --chr ${chr} \
                --out $genD/${ancestry}/autosomes/genotypes_for_relatedness_filtering.ld_prune_chr${chr}
    done
done


for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    # Merge *prune.in files
    cat $genD/${ancestry}/autosomes/genotypes_for_relatedness_filtering.ld_prune_chr*.prune.in \
        > $genD/${ancestry}/autosomes/genotypes_for_relatedness_filtering.ld_prune_autosomes.prune.in

    # Create new PLINK filesets with only lD pruned variants
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_lte_0.03_filter \
        --extract $genD/${ancestry}/autosomes/genotypes_for_relatedness_filtering.ld_prune_autosomes.prune.in \
        --make-bed \
        --out $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_filter
done

# %% [markdown]
# ## Identical-by-state and identical-by-descent filtering
# Identical-by-state or identity-by-state (IBS) filtering provides a means to identify duplicate subjects or monozygotic twins. Identical-by-descent or identity-by-descent allows for detection of high relatedness. For computational efficiency and memory usage limitations, ibd_pipeline.v4.sh is used to perform IBS/IBD calculations on data chunks that are used as input for IBS and IBD filtering. If the study contains AA subjects, then for AA subjects only, [KING](http://people.virginia.edu/~wc9c/KING/manual.html) is used as an additional relationship inference tool for filtering.
#
# For these filtering steps, a list of individuals is identified separately for each filtering type then combined into a final list for exclusion. Following IBS filtering, if any individuals are identified for removal, a graph analysis needs to be done to account for an individual being related/identical to multiple individuals. Removal criteria is based on genotype calling rate. These individuals would need to be removed before running IBD filtering and KING. Graph analysis would need to be run after IBD calculations/KING if individuals were selected for removal.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

 Calculate allele frequencies in data chunks
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/scripts/ibd_pipeline.sh \
        --in_prefix $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_filter \
        --out_dir $genD/${ancestry}/autosomes/
    sleep 5s
done


# Aggregate data
    for ancestry in {ea,aa}; do
        outfile=$genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_filter.genome
        head -1 `ls $genD/${ancestry}/autosomes/data.sub.genome* | head -1` > ${outfile}
        cat $genD/${ancestry}/autosomes/data.sub.genome* | \
            grep -v FID1 >> ${outfile}

        # Remove temporary files
        rm $genD/${ancestry}/autosomes/data.sub.*
        rm $genD/${ancestry}/autosomes/tmp_sh*.sh
    done

# %% [markdown]
# ### IBS filtering
# For individual pairs with greater than 0.9 IBS score, only the individual with the lower genotype missing call rate is retained. I create a list of individuals to remove that will be combined with the IBD list for final filtering but removed from the LD pruned data before running IBD filtering.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Calculate missingness
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_filter \
        --missing \
        --out $genD/${ancestry}/autosomes/autosome_missing_call_rate
done

# Get list of individuals with IBS > 0.9
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    Rscript /shared/bioinformatics/software/R/merge_genome_missing.R \
        --genome $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_filter.genome \
        --imiss $genD/${ancestry}/autosomes/autosome_missing_call_rate.imiss \
        --type IBS \
        --out $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter
done


"""
================ ea ================


[1] "Reading genome file /shared/data/studies/heroin/kreek/genotype/observed/processing/ea/autosomes/genotypes_for_relatedness_ld_prune_filter.genome"
[1] "Reading missing file /shared/data/studies/heroin/kreek/genotype/observed/processing/ea/autosomes/autosome_missing_call_rate.imiss"
[1] "Filtering"
[1] "IBS"
[1] "3 rows meet filtering criteria"
[1] "Merging files"
[1] "Printing output"


================ aa ================


[1] "Reading genome file aa/autosomes/genotypes_for_relatedness_ld_prune_filter.genome"
[1] "Reading missing file aa/autosomes/autosome_missing_call_rate.imiss"
[1] "Filtering"
[1] "IBS"
[1] "6 rows meet filtering criteria"
[1] "Merging files"
[1] "Printing output"
"""

# %% [markdown]
# There are 3 individuals that are problematic for the EAs and 6 for the AA subjects.
#
# ```
# ================ ea ================
# FID1    IID1
# 0       106893
# 0       101564
# 0       103734
#
# ================ aa ================
# FID1    IID1
# 0       103857
# 0       108616
# 0       102526
# 0       104023
# 0       106563
# 0       108082
# ```

# %% [markdown]
# ### Graph Analysis for IBS
# In graph analysis a network of related individuals is created. Genotype call rate is calculated within this network to determine which individuals to remove. The purpose of using a network-based filtering is to prevent too many individuals from being unnecessarily removed when relationships extend beyond pairwise relatedness.

# %%
# R console #
# Graph analysis to determine minimum # of subjects to remove
library(igraph)
setwd("/shared/data/studies/heroin/kreek/genotype/observed/processing")
for(ancestry in c("ea","aa")){
    stats = read.table(paste0(ancestry, "/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.stats"), header = TRUE, colClasses="character")
    ibdPairs = as.data.frame(cbind(paste(stats$FID2, stats$IID2, sep="__"), paste(stats$FID1, stats$IID1, sep="__")), stringsAsFactors = FALSE)
    colnames(ibdPairs) = c("fid_iid_1","fid_iid_2")
    ibdGraph = graph.data.frame(ibdPairs, directed = FALSE)
    vertexDegrees = sort(degree(ibdGraph), decreasing = TRUE)
    removeList = vector()
    while (length(vertexDegrees) > 0 && vertexDegrees[1] > 1) {
        if (exists("removeList")) {
            removeList = c(removeList, names(vertexDegrees[1]))
        } else {
            removeList = names(vertexDegrees[1])
        }
        ibdGraph = ibdGraph - names(vertexDegrees[1])
        vertexDegrees = sort(degree(ibdGraph), decreasing = TRUE)
    }
    ibdPairs = ibdPairs[!(ibdPairs[,1] %in% removeList) & !(ibdPairs[,2] %in% removeList),]
    imiss = read.table(paste0(ancestry, "/autosomes/autosome_missing_call_rate.imiss"), header = TRUE, colClasses = "character")
    imiss = as.data.frame(cbind(paste(imiss$FID, imiss$IID, sep="__"), as.numeric(imiss$F_MISS)), stringsAsFactors = FALSE)
    colnames(imiss) = c("fid_iid_1","f_miss_1")
    ibdPairs = merge(ibdPairs, imiss, by="fid_iid_1", sort = FALSE)
    colnames(imiss) = c("fid_iid_2","f_miss_2")
    ibdPairs = merge(ibdPairs, imiss, by="fid_iid_2", sort = FALSE)
    removeList = c(removeList, ibdPairs[ibdPairs["f_miss_1"] < ibdPairs["f_miss_2"],"fid_iid_2"])
    removeList = c(removeList, ibdPairs[ibdPairs["f_miss_1"] >= ibdPairs["f_miss_2"],"fid_iid_1"])
    removeList = cbind(lapply(strsplit(removeList,"__"), function(x) x[1]),lapply(strsplit(removeList,"__"), function(x) x[2]))
    write.table(removeList, file=paste0(ancestry, "/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_igraph.remove"), row.names = FALSE, col.names = FALSE, quote = FALSE)
    rm(removeList)
}

# %% [markdown]
# ```
# cat ea/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_igraph.remove
# 0 106893
# 0 101564
# 0 103734
#
# cat aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_igraph.remove
# 0 103857
# 0 108616
# 0 102526
# 0 104023
# 0 106563
# 0 108082
# ```

# %% [markdown]
# ### Remove IBS problematic subjects
# Before proceeding with IBD filtering, the problematic subjects need to be removed.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing


# Make new PLINK file set
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_filter \
        --remove $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_igraph.remove \
        --make-bed \
        --out $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter
done

# Calculate allele frequencies in data chunks
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/scripts/ibd_pipeline.sh \
        --in_prefix $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter \
        --out_dir $genD/${ancestry}/autosomes/
    sleep 5s
done

# Aggregate data
for ancestry in {ea,aa}; do
    outfile=$genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.genome
    head -1 `ls $genD/${ancestry}/autosomes/data.sub.genome* | head -1` > ${outfile}
    cat $genD/${ancestry}/autosomes/data.sub.genome* | \
        grep -v FID1 >> ${outfile}

    # Remove temporary files
    rm $genD/${ancestry}/autosomes/data.sub.*
    rm $genD/${ancestry}/autosomes/tmp_sh*.sh
done

# %% [markdown]
# ### IBD filtering
# For individual pairs with greater than 0.4 IBD score, only the individual with the lower genotype missing call rate is retained. I create a list of individuals to remove that will be combined with the IBS list.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Get list of individuals with IBD > 0.4
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    Rscript /shared/bioinformatics/software/R/merge_genome_missing.R \
        --genome $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.genome \
        --imiss $genD/${ancestry}/autosomes/autosome_missing_call_rate.imiss \
        --type IBD \
        --pi_hat_threshold 0.4 \
        --out $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibd_gt_0.4_filter
done

# %% [markdown]
# ```
# ================ ea ================
#
#
# [1] "Reading genome file ea/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.genome"
# [1] "Reading missing file ea/autosomes/autosome_missing_call_rate.imiss"
# [1] "Filtering"
# [1] "IBD > 0.4"
# [1] "17 rows meet filtering criteria"
# [1] "Merging files"
# [1] "Printing output"
#
#
# ================ aa ================
#
#
# [1] "Reading genome file aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.genome"
# [1] "Reading missing file aa/autosomes/autosome_missing_call_rate.imiss"
# [1] "Filtering"
# [1] "IBD > 0.4"
# [1] "18 rows meet filtering criteria"
# [1] "Merging files"
# [1] "Printing output"
# ```

# %% [markdown]
# ### Relationship inference using KING
# For subjects with African ancestry, KING provides a better estimation of relatedness. I use this software to further identify subjects for removal.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Run KING
/shared/bioinformatics/software/third_party/king_v2.1.2/king \
    -b $genD/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.bed \
    --kinship \
    --cpus 1 \
    --prefix $genD/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.king

"""
Within-family kinship data saved in file /shared/data/studies/heroin/kreek/genotype/observed/processing/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.king.kin

Relationship summary (total relatives: 0 by pedigree, 45 by inference)
  Source        MZ      PO      FS      2nd     3rd     OTHER
  ===========================================================
  Pedigree      0       0       0       0       0       249571
  Inference     0       13      5       6       21      249526


WARNING -
All individuals with family ID 0 are considered as relatives.

There is only one family.
"""

# Extract PLINK IBD calculations for subject pairs
outFile=$genD/aa/autosomes/genotypes_for_relatedness.genome_lite
echo -e "PAIR_ID\tPI_HAT" > $outFile
tail -n +2 $genD/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.genome | \
    perl -lane '$pairId = "";
        if ($F[0] < $F[2] || ($F[0] == $F[2] && $F[1] < $F[3])) {
            $pairId = join("_",$F[0],$F[1],$F[2],$F[3]);
        } else {
            $pairId = join("_",$F[2],$F[3],$F[0],$F[1]);
        }
        print $pairId."\t".$F[9];' >> $outFile

# Extract KING kinship calculations for subject pairs
outFile=$genD/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.king.king_lite
echo -e "PAIR_ID\tKINSHIP" > $outFile
tail -n +2 $genD/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.king.kin | \

    perl -lane '$pairId = "";
        if ($F[0] < $F[2] || ($F[0] == $F[2] && $F[1] < $F[3])) {
            $pairId = join("_",$F[0],$F[1],$F[2],$F[3]);
        } else {
            $pairId = join("_",$F[2],$F[3],$F[0],$F[1]);
        }
        print $pairId."\t".$F[7];' >> $outFile

tail -n +2 $genD/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.king.kin | \
    perl -lane '$pairId = "";
        if ($F[1] < $F[2]) {
            $pairId = join("_",$F[0],$F[1],$F[0],$F[2]);
        } else {
            $pairId = join("_",$F[0],$F[2],$F[0],$F[1]);
        }
        print $pairId."\t".$F[8];' >> $outFile

# Combine IBD and kinship results
Rscript /shared/bioinformatics/software/R/merge_datasets.R \
    --in_1 $genD/aa/autosomes/genotypes_for_relatedness.genome_lite \
    --in_1_column PAIR_ID \
    --in_1_header \
    --in_2 $genD/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.king.king_lite \
    --in_2_column PAIR_ID \
    --in_2_header \
    --out $genD/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.genome+king \
    --out_header

# Identify discrepancies between PLINK IBD and KING kinship values
perl -lane 'if ($F[2] > 0.177 && $F[1] > 0.4) { print "AGREE\t".$_; } elsif ($F[2] > 0.177 || $F[1] > 0.4) { print "DISAGREE\t".$_; }' aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.genome+king \
    > $genD/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.genome+king.ibd_comparison

# %% [markdown]
# ```
# cat $genD/aa/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_filter.genome+king.ibd_comparison
# AGREE   0_108050_0_108372 0.5120 0.2626
# AGREE   0_103910_0_105095 0.5107 0.2484
# AGREE   0_103038_0_109686 0.4999 0.2430
# AGREE   0_101774_0_102990 0.5091 0.2505
# AGREE   0_104758_0_106083 0.4873 0.2308
# AGREE   0_100452_0_101265 0.5183 0.2485
# AGREE   0_105868_0_109736 0.5007 0.2480
# AGREE   0_102770_0_108529 0.4525 0.2243
# AGREE   0_102770_0_103484 0.5550 0.2741
# AGREE   0_103484_0_108529 0.5220 0.2574
# AGREE   0_100010_0_109206 0.4988 0.2492
# AGREE   0_105649_0_106470 0.5000 0.2524
# AGREE   0_106305_0_109379 0.5093 0.2494
# AGREE   0_102444_0_106035 0.4998 0.2499
# AGREE   0_100290_0_102214 0.5053 0.2522
# AGREE   0_104217_0_109656 0.4961 0.2451
# AGREE   0_104185_0_108012 0.5586 0.2811
# AGREE   0_101311_0_102368 0.5274 0.2668
# ```

# %% [markdown]
# ### Graph Analysis for IBD
# In graph analysis a network of related individuals is created. Genotype call rate is calculated within this network to determine which individuals to remove. The purpose of using a network-based filtering is to prevent too many individuals from being unnecessarily removed when relationships extend beyond pairwise relatedness.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Get genotype missing call rate for graph analysis
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_lte_0.03_filter \
        --missing \
        --out $genD/${ancestry}/autosomes/genotypes_for_relatedness
done

# %%
# R console #
# Graph analysis to determine minimum # of subjects to remove
library(igraph)
setwd("/shared/data/studies/heroin/kreek/genotype/observed/processing")
for(ancestry in c("aa","ea")){
    stats = read.table(paste0(ancestry, "/autosomes/genotypes_for_relatedness_ld_prune_ibd_gt_0.4_filter.stats"), header = TRUE, colClasses="character")
    ibdPairs = as.data.frame(cbind(paste(stats$FID2, stats$IID2, sep="__"), paste(stats$FID1, stats$IID1, sep="__")), stringsAsFactors = FALSE)
    colnames(ibdPairs) = c("fid_iid_1","fid_iid_2")
    ibdGraph = graph.data.frame(ibdPairs, directed = FALSE)
    vertexDegrees = sort(degree(ibdGraph), decreasing = TRUE)
    removeList = vector()
    while (length(vertexDegrees) > 0 && vertexDegrees[1] > 1) {
        if (exists("removeList")) {
            removeList = c(removeList, names(vertexDegrees[1]))
        } else {
            removeList = names(vertexDegrees[1])
        }
        ibdGraph = ibdGraph - names(vertexDegrees[1])
        vertexDegrees = sort(degree(ibdGraph), decreasing = TRUE)
    }
    ibdPairs = ibdPairs[!(ibdPairs[,1] %in% removeList) & !(ibdPairs[,2] %in% removeList),]
    imiss = read.table(paste0(ancestry, "/autosomes/autosome_missing_call_rate.imiss"), header = TRUE, colClasses = "character")
    imiss = as.data.frame(cbind(paste(imiss$FID, imiss$IID, sep="__"), as.numeric(imiss$F_MISS)), stringsAsFactors = FALSE)
    colnames(imiss) = c("fid_iid_1","f_miss_1")
    ibdPairs = merge(ibdPairs, imiss, by="fid_iid_1", sort = FALSE)
    colnames(imiss) = c("fid_iid_2","f_miss_2")
    ibdPairs = merge(ibdPairs, imiss, by="fid_iid_2", sort = FALSE)
    removeList = c(removeList, ibdPairs[ibdPairs["f_miss_1"] < ibdPairs["f_miss_2"],"fid_iid_2"])
    removeList = c(removeList, ibdPairs[ibdPairs["f_miss_1"] >= ibdPairs["f_miss_2"],"fid_iid_1"])
    removeList = cbind(lapply(strsplit(removeList,"__"), function(x) x[1]),lapply(strsplit(removeList,"__"), function(x) x[2]))
    write.table(removeList, file=paste0(ancestry, "/autosomes/genotypes_for_relatedness_ld_prune_ibd_gt_0.4_igraph.remove"), row.names = FALSE, col.names = FALSE, quote = FALSE)
    rm(removeList)
}

# %% [markdown]
# ```
# wc -l $genD/*/autosomes/genotypes_for_relatedness_ld_prune_ibd_gt_0.4_igraph.remove
#  17 /shared/data/studies/heroin/kreek/genotype/observed/processing/aa/autosomes/genotypes_for_relatedness_ld_prune_ibd_gt_0.4_igraph.remove
#  14 /shared/data/studies/heroin/kreek/genotype/observed/processing/ea/autosomes/genotypes_for_relatedness_ld_prune_ibd_gt_0.4_igraph.remove
# ```

# %% [markdown]
# ### Constructing relatedness filtering lists
# The output of the IBS filtering and the IBD filtering are combined into a single remove list.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Get list of individuals from IBD and IBS filter lists
ancestry=aa
cat $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibd_gt_0.4_igraph.remove \
    $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_igraph.remove | \
    sort -u > $genD/${ancestry}/autosomes/ibs_gt_0.9_ibd_gt_0.4.remove

ancestry=ea
cat $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibd_gt_0.4_igraph.remove \
    $genD/${ancestry}/autosomes/genotypes_for_relatedness_ld_prune_ibs_gt_0.9_igraph.remove | \
    sort -u > $genD/${ancestry}/autosomes/ibs_gt_0.9_ibd_gt_0.4.remove

# %% [markdown]
# The list of subjecs marked for will be retained as a filtering list for the merged autosome and chrX PLINK file sets.
#
# ```
#  wc -l */autosomes/ibs_gt_0.9_ibd_gt_0.4.remove
#  23 aa/autosomes/ibs_gt_0.9_ibd_gt_0.4.remove
#  17 ea/autosomes/ibs_gt_0.9_ibd_gt_0.4.remove
# ```

# %% [markdown]
# ## ChrX Processing
# ### Missing data subject filtering
# We calculate the proportion of missing genotype calls on chrX using PLINK to assess whether any subjects have data missing for the whole chromosome.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Get missing call rate for chrX
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --memory 3000 \
            --bfile $genD/${ancestry}/chrX/genotypes_b37_dbsnp138 \
            --missing \
            --chr 23 \
            --out $genD/${ancestry}/chrX/chrX_missing_call_rate

    # Find subjects that have data missing for whole chrX
    tail -n +2 $genD/${ancestry}/chrX/chrX_missing_call_rate.imiss | \
        awk '{ OFS="\t" } { if($6==1){ print $1,$2 } }' >> $genD/${ancestry}/chrX/missing_whole_chrX.remove
    echo -e "\n\nNumber of ${ancestry} subjects with missing whole chromosome: $(wc -l $genD/${ancestry}/chrX/missing_whole_chrX.remove)\n\n"
done

# %% [markdown]
# ```
# Number of ea subjects with missing whole chromosome: 0 ea/chrX/missing_whole_chrX.remove
# Number of aa subjects with missing whole chromosome: 0 aa/chrX/missing_whole_chrX.remove
# ```
# **Note:** If subjects ever show up as having missing data then further discussions need to be had on whether these subjects should be removed completely or whether they should only be excluded for the missing chromosome.

# %%
##EC2 command line ##
rm $genD/{ea,aa}/chrX/chr*missing_call_rate*

# %% [markdown]
# ### Remove duplicate SNPs
#
# If multiple rsIDs are present then the one with the better genotype call rate across subjects should be retained. Obtaining the genotype call rates across subjects would need to be calculated using PLINK --missing.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Find duplicate rsIDs
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    cut -f2,2 $genD/${ancestry}/chrX/genotypes_b37_dbsnp138.bim | \
    sort | \
    uniq -D \
    > $genD/${ancestry}/chrX/snp_duplicates.txt
    echo -e "\n\nNumber of ${ancestry} variant duplicates: $(wc -l $genD/${ancestry}/chrX/snp_duplicates.txt)\n\n"
done

# %% [markdown]
# For this case, there are no duplicated rsIDs.

# %% [markdown]
# ### Strand flipping
# If strand flipping was an issue for the autosomes, it would also be an issue for chrX. Unfortunateley the May 2013 release for the 1000 Genomes Phase 3 data lacks IDs for chrX, so strand flipping for chrX will need to be done after converting IDs to 1000 Genomes Phase 3 IMPUTE2 format in a subsequent step. If complete data were available, strand flipping would be executed at this point.
#
# ### Genotype call rate variant filter
#
# I calculate the genotype missing call rate and remove any variants with a rate $> 3\%$.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Get missing call rate
# note that I added the "subject_missing_chrx" filter at the end just for 
# convenience even though no subjects were filtered during that stage
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/chrX/genotypes_b37_dbsnp138 \
        --geno 0.03 \
        --make-bed \
        --out $genD/${ancestry}/chrX/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_filter_subject_missing_chrx
done

# %% [markdown]
# ```
# wc -l $genD/*/chrX/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_filter_subject_missing_chrx.bim
#  13576 /shared/data/studies/heroin/kreek/genotype/observed/processing/aa/chrX/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_filter_subject_missing_chrx.bim
#  13732 /shared/data/studies/heroin/kreek/genotype/observed/processing/ea/chrX/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_filter_subject_missing_chrx.bim
#
#  ```

# %% [markdown]
# ### Hardy-Weinberg equilibrium filtering
#
# Extensive deviation from Hardy-Weinberg equilibrium (HWE) can be indicative of a genotyping or genotype calling error. Using PLINK `--hardy`, I calculate goodness of fit test p-values for allele frequencies compared to HWE. Any variant with p < 0.0001 is removed.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Calculate HW p-values for each ancestry group
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --memory 3800 \
        --noweb \
        --bfile $genD/${ancestry}/chrX/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_filter_subject_missing_chrx \
        --hwe 0.0001 \
        --make-bed \
        --out $genD/${ancestry}/chrX/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_filter_subject_missing_chrx
done

# %% [markdown]
# ```
# wc -l */chrX//genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_filter_subject_missing_chrx.bim
#  13553 aa/chrX/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_filter_subject_missing_chrx.bim
#  13731 ea/chrX/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_filter_subject_missing_chrx.bim
# ```

# %% [markdown]
# ## Merge autosomes and chrX
# The data processed through to HWE filtering for both the autosomes and chrX are merged before applying the final subject filtering steps.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# note that for convenience, we include in the title "subject missing_chrx_filter" 
# even though no subjects were filtered during that step.
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/autosomes/genotypes_b37_dbsnp138_flipped_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_filter \
        --bmerge $genD/${ancestry}/chrX/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_filter_subject_missing_chrx \
        --make-bed \
        --out $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_filter.all_chr
done

# %% [markdown]
# ```
# wc -l $genD/*/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_filter.all_chr.{fam,bim}
# 716 aa/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_filter.all_chr.fam
# 634 ea/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_filter.all_chr.fam
# 538663 aa/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_filter.all_chr.bim
# 546602 ea/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_filter.all_chr.bim
# ```

# %% [markdown]
# ## Relatedness filter
# From relatedness calculations on the autosomal data, I remove subjects that are closely related or seemingly identical.

# %%
# EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Remove variants
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_filter.all_chr \
        --remove $genD/${ancestry}/autosomes/ibs_gt_0.9_ibd_gt_0.4.remove \
        --make-bed \
        --out $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_filter.all_chr
    echo -e "\nNumber of ${ancestry} subjects removed: $(wc -l  ${ancestry}/autosomes/ibs_gt_0.9_ibd_gt_0.4.remove)\n\n"
done

"""
Number of ea subjects removed: 17 ea/autosomes/ibs_gt_0.9_ibd_gt_0.4.remove
Number of aa subjects removed: 23 aa/autosomes/ibs_gt_0.9_ibd_gt_0.4.remove
"""

# %% [markdown]
# ## Genotype call rate subject filter
#
# I calculate the genotype missing call rate and remove any subjects with a rate $> 3\%$.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Remove variants
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_filter.all_chr \
        --mind 0.03 \
        --make-bed \
        --out $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_filter.all_chr
done

"""
wc -l aa/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_filter.all_chr.fam
690

wc -l ea/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_filter.all_chr.fam
614
"""

# %% [markdown]
# ## Linkage disequilibrium pruning
# Linkage disequilibrium (LD) pruning eliminates a large degree of redundancy in the data and reduces the influence of chromosomal artifacts. The objective of LD pruning is to select a subset of variants based off of LD such that the variants in the subset are indepdendent. This filtering will not carry forward to the final processed results, but this step improves the quality of sex check and excessive homozygosity calculations. Consequently, the LD pruned data will be used as input for those calculations.
#
# LD pruning is implemented using [PLINK --indep-pairwise](https://www.cog-genomics.org/plink/1.9/ld#indep).

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Run per chromosome LD pruning for each chr
for ancestry in {ea,aa}; do
    for chr in {1..23}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${chr}_ld_prune \
            --script_prefix $genD/${ancestry}/${ancestry}_${chr}_ld_prune \
            --mem 7.5 \
            --nslots 1 \
            --priority 0 \
            --program /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
                --noweb \
                --bfile $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_filter.all_chr \
                --indep-pairwise 50 5 0.5 \
                --chr ${chr} \
                --out $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_chr${chr}_filter
    done
done

# Merge *prune.in files
for ancestry in {ea,aa}; do
    cat $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_chr*_filter.prune.in \
        > $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_chr_all_filter.prune.in

    # Create new PLINK filesets with only lD pruned variants
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_filter.all_chr \
        --extract $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_chr_all_filter.prune.in \
        --make-bed \
        --out $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_chr_all_filter
done

# %% [markdown]
# ## Sex Check
# To verify that self-reported gender status matches with the genetic information, I use PLINK `--split-x` followed by `--check-sex` to confirm the data agree. Our discrepancy criteria are
#
# * Reported as male (coded as 1) but F < 0.2
# * Reported as female (coded as 2) but F > 0.8

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Break out the pseudo-autosomal region on chrX (will be stored as chr 25)
for ancestry in {ea,aa}; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_chr_all_filter \
        --split-x b37 \
        --make-bed \
        --out $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_split_chrX_filter.all_chr

    # Run sex check
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_split_chrX_filter.all_chr \
        --check-sex \
        --out $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_split_chrX_filter.all_chr

    # Get subjects that do not meet inbreeding coefficient thresholds
    perl -lane 'if ($F[2]==1 && $F[5]<0.2) { print $_; } elsif ($F[2]==2 && $F[5]>0.8) { print $F[0]."\t".$F[1]; }' $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_split_chrX_filter.all_chr.sexcheck \
        > $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_split_chrX_filter.all_chr.sexcheck.threshold_fail

    # Get subjects that are problematic due to no inbreeding coefficient value
    perl -lane 'if ($F[4] eq "PROBLEM" && $F[5] eq "nan") { print $F[0]."\t".$F[1]; }' $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_split_chrX_filter.all_chr.sexcheck \
        > $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_split_chrX_filter.all_chr.sexcheck.nan_fail

    # Combine discordant subjects into one remove list
    cat $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_split_chrX_filter.all_chr.sexcheck.*_fail | \
        sort -u \
        > $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_split_chrX_filter.all_chr.sexcheck.remove
done

# Print number of discrepancies
wc -l $genD/{ea,aa}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_split_chrX_filter.all_chr.sexcheck.remove
"0"

# %% [markdown]
# For these data the sex check yielded **0 discrepancies** for the EA subjects and **0 discrepancies** for the AA subjects under our criteria. If any individuals failed the check then they would be removed before subsequent steps using the file set generated after gentoype call rate subject filtering (before removing the pseudo-autosomal chrX region).

# %% [markdown]
# ## Excessive homozygosity filter
# Excessive homozygosity checks for inbreeding and population substructure. This check is implemented using PLINK. According to their documentation, the statistics used for this filtering are not LD-sensitive, i.e., an LD pruned dataset is recommended as input. Additionally, the documentation states that only autosomal data are used, so concerns of chrX biasing results are irrelevant.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Get homozygosity stats
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_chr_all_filter \
        --het \
        --out $genD/{ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_chr_all_filter

   # Identify problematic subjects
    perl -lane 'if ($F[5] < -0.2 || $F[5] > 0.5) { print $F[0]." ".$F[1]; }' $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_chr_all_filter.het \
    > $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_homozygosity_check_chr_all_filter.remove

    # Remove problematic subjects
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_filter.all_chr \
        --remove $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_homozygosity_check_chr_all_filter.remove \
        --make-bed \
        --out $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_failed_sex_check_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_homozygosity_check_filter.all_chr

    echo -e "\nNumber of ${ancestry} subjects removed: $(wc -l  $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_ld_prune_homozygosity_check_chr_all_filter.remove)\n\n"
done

"""
Number of ea subjects removed: 0
Number of aa subjects removed: 0
"""

# %% [markdown]
# ## Recoding variants for 1000G phase 3
# RefSeq IDs (rsIDs) for variants can vary depending on the dbSNP build used and variant IDs do not all use RefSeq nomenclature. To provide a common nomenclature that will make comparisons across data sets feasible, I use a script that recodes all variant names to match 1000G phase 3 variants by position and alleles. The 1000G Phase 3 data I used for STRUCTURE are from /share/nas03/bioinformatics_group/data/ref_panels/1000G/2013.05/plink on MIDAS, but from correspondence with Nathan Gaddis I learned that /share/nas03/bioinformatics_group/data/ref_panels/1000G/2014.10/ also contains 1000G Phase 3 data derived from the May 2013 release. The difference is that it was downloaded from the IMPUTE2 website and reformatted to be directly compatible with IMPUTE2.
#
# The data in /share/nas03/bioinformatics_group/data/ref_panels/1000G/2014.10/ is used for variant name recoding, but the 1000G genotype information is acquired from /share/nas03/bioinformatics_group/data/ref_panels/1000G/2013.05/plink

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

mkdir $genD/1000g_name_recoding

for ancestry in {ea,aa}; do
    for ext in {bed,bim,fam}; do
        cp  $genD/${ancestry}/genotypes_b37_dbsnp138_structure_variant_missing_lte_0.03_hwe_p_gte_0.0001_subject_missing_chrx_failed_sex_check_ibs_gt_0.9_ibd_gt_0.4_subject_missing_lte_0.03_homozygosity_check_filter.all_chr.${ext} 1000g_name_recoding/${ancestry}_chr_all.${ext}
    done
done

# %% [markdown]
# ### Variant ID updating
# Because the 1000G data and the study data have RefSeq IDs (rsIDs) from different dbSNP builds, I standardize them using convert_to_1000g_ids.pl. In the study data set, certain indels may be represented as two variants, a monomorphic variant and an indel with the - symbol for one of the alleles. For example:
#
# 1   rs201826967  0.809   57873968   0   G
# 1   rs11284630   0.809   57873969   -   A
#
# These two variants represent a G:GA indel and is coded as such in the 1000 Genomes data. The script to update the names to 1000 Genomes IMPUTE2 format will assign the same ID to these two variants. The duplicated IDs will cause problems for PLINK filtering, so I will remove the variant from a set of duplicate IDs that has the lower genotype call rate. Duplicates may arise for other reasons, and they will be filtered based on the same criterion.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding
thouD=$genD/1000g_name_recoding

mkdir $thouD/1000g_data

# Break out data by chr
for ancestry in {ea,aa}; do
    for chr in {1..23}; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --memory 2048 \
            --bfile $thouD/${ancestry}_chr_all \
            --chr ${chr} \
            --make-bed \
            --out $thouD/${ancestry}_chr${chr}
    done
done


# Rename study autosome variant IDs
for ancestry in {ea,aa}; do
    for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name recode_to_1000g_${chr} \
            --script_prefix $thouD/${ancestry}_chr${chr}_id_rename \
            --mem 6 \
            --nslots 1 \
            --priority 0 \
            --program perl /shared/bioinformatics/software/perl/id_conversion/convert_to_1000g_p3_ids.pl \
                --file_in $thouD/${ancestry}_chr${chr}.bim \
                --file_out $thouD/${ancestry}_chr${chr}_renamed.bim \
                --legend /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chr$chr.legend.gz \
                --file_in_header 0 \
                --file_in_id_col 1 \
                --file_in_chr_col 0 \
                --file_in_pos_col 3 \
                --file_in_a1_col 4 \
                --file_in_a2_col 5 \
                --chr ${chr}
    done
done


# Rename study chrX variant IDs
chr=23
for ancestry in {ea,aa}; do
    /shared/bioinformatics/software/scripts/qsub_job.sh \
        --job_name recode_to_1000g_${chr} \
        --script_prefix $thouD/${ancestry}_chr${chr}_id_rename \
        --mem 6 \
        --nslots 1 \
        --priority 0 \
        --program perl /shared/bioinformatics/software/perl/id_conversion/convert_to_1000g_p3_ids.pl \
            --file_in $thouD/${ancestry}_chr${chr}.bim \
            --file_out $thouD/${ancestry}_chr${chr}_renamed.bim \
            --legend /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chrX_NONPAR.legend.gz \
            --file_in_header 0 \
            --file_in_id_col 1 \
            --file_in_chr_col 0 \
            --file_in_pos_col 3 \
            --file_in_a1_col 4 \
            --file_in_a2_col 5 \
            --chr ${chr}
done


# Rename 1000G autosome variant IDs
for chr in {1..22}; do
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name recode_to_1000g_${chr} \
            --script_prefix $thouD/${ancestry}_chr${chr}_id_rename \
            --mem 8 \
            --nslots 1 \
            --priority 0 \
            --program perl /shared/bioinformatics/software/perl/id_conversion/convert_to_1000g_p3_ids.pl \
                --file_in /shared/data/ref_panels/1000G/2013.05/plink/ALL.chr${chr}.bim \
                --file_out $thouD/1000g_data/chr${chr}_renamed.bim \
                --legend /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chr$chr.legend.gz \
                --file_in_header 0 \
                --file_in_id_col 1 \
                --file_in_chr_col 0 \
                --file_in_pos_col 3 \
                --file_in_a1_col 4 \
                --file_in_a2_col 5 \
                --chr ${chr}
    done
done


# Rename 1000G chrX variant IDs
chr=23
/shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name recode_to_1000g_${chr} \
    --script_prefix $thouD/${ancestry}_chr${chr}_id_rename \
    --mem 8 \
    --priority 0 \
    --program perl /shared/bioinformatics/software/perl/id_conversion/convert_to_1000g_p3_ids.pl \
        --file_in /shared/data/ref_panels/1000G/2013.05/plink/ALL.chrX.bim \
        --file_out $thouD/1000g_data/chr${chr}_renamed.bim \
        --legend /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chrX_NONPAR.legend.gz \
        --file_in_header 0 \
        --file_in_id_col 1 \
        --file_in_chr_col 0 \
        --file_in_pos_col 3 \
        --file_in_a1_col 4 \
        --file_in_a2_col 5 \
        --chr ${chr}

# %% [markdown]
# ### Remove duplicate variant ID
# Many of the functions in PLINK will throw errors when duplicate variant IDs are found.To resolve this, duplicate variant IDs are identified, and only the duplicate variant with the best genotype call rate is retained.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding

for ancestry in {ea,aa}; do
    for chr in {1..23}; do
        echo -e "\n ==== ${ancestry} - chr${chr} ==== \n"
        # Append _X (where X is a number) to the end of the variant IDs for all but 1st occurrence of duplicates
        perl -lane 'BEGIN { %idCounts = (); }
                    if (exists($idCounts{$F[1]})) {
                        $idCounts{$F[1]}++;
                        print join("\t",$F[0],$F[1]."_".$idCounts{$F[1]},$F[2],$F[3],$F[4],$F[5]);
                    } else {
                        $idCounts{$F[1]} = 1;
                        print;
                    }' $thouD/${ancestry}_chr${chr}_renamed.bim > \
            $thouD/${ancestry}_chr${chr}_renamed_dups.bim

        # Generate list of duplicate SNPs
        grep -P "_[1-9]" $thouD/${ancestry}_chr${chr}_renamed_dups.bim |
            perl -lane 'print substr($F[1], 0, index($F[1],"_"))."\n".$F[1];' > \
            $thouD/${ancestry}_chr${chr}_renamed_dups.dupvar_list
    done
done

# Check if any duplicates were found
wc -l $thouD/*.dupvar_list

for ancestry in {ea,aa}; do
    for chr in $(wc -l $thouD/*.dupvar_list | perl -lane 'if ($F[0] != 0) { $F[1] =~ /chr(\d+)/; print $1; }'); do
# Get call rates for duplicate SNPs
        /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --memory 2048 \
            --bed $thouD/${ancestry}_chr${chr}.bed \
            --bim $thouD/${ancestry}_chr${chr}_renamed_dups.bim \
            --fam $thouD/${ancestry}_chr${chr}.fam \
            --extract $thouD/${ancestry}_chr${chr}_renamed_dups.dupvar_list \
            --missing \
            --out $thouD/${ancestry}_chr${chr}_renamed_dups

        /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --memory 2048 \
            --bed $thouD/${ancestry}_chr${chr}.bed \
            --bim $thouD/${ancestry}_chr${chr}_renamed_dups.bim \
            --fam $thouD/${ancestry}_chr${chr}.fam \
            --extract $thouD/${ancestry}_chr${chr}_renamed_dups.dupvar_list \
            --missing \
            --out $thouD/${ancestry}_chr${chr}_renamed_dups

        # Create remove list that contains the duplicate with the higher missing rate
        tail -n +2 $thouD/${ancestry}_chr${chr}_renamed_dups.lmiss | \
            perl -lane 'BEGIN { %missingness = (); }
                        if ($F[1] =~ /^(\S+)\_/) {
                            $duplicateName = $1
                        } else {
                            $duplicateName = $F[1]."_2";
                        }
                        if (exists($missingness{$duplicateName})) {
                            if ($missingness{$duplicateName} > $F[4]) {
                                print $duplicateName;
                            } else {
                                print $F[1];
                            }
                        } else {
                            $missingness{$F[1]} = $F[4];
                        }' \
                > $thouD/${ancestry}_chr${chr}_renamed_dups.remove

        /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --memory 2048 \
            --bed $thouD/${ancestry}_chr${chr}.bed \
            --bim $thouD/${ancestry}_chr${chr}_renamed_dups.bim \
            --fam $thouD/${ancestry}_chr${chr}.fam \
            --exclude $thouD/${ancestry}_chr${chr}_renamed_dups.remove \
            --make-bed \
            --out $thouD/${ancestry}_chr${chr}_renamed_dups_removed

        # Remove "_2" from variant IDs
        perl -i.bak -lne 's/\_2//; print;' $thouD/${ancestry}_chr${chr}_renamed_dups_removed.bim
    done
done

# %% [markdown]
# ### Merge chromosome data

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding

# Add chr where duplicates were removed to merge list
for ancestry in {ea,aa}; do
    echo -e "\n\n================ ${ancestry} ================\n\n"
    for chr in $(wc -l $thouD/*.dupvar_list | perl -lane 'if ($F[0] != 0) { $F[1] =~ /chr(\d+)/; if ($1 ne "1") { print $1; } }'); do
        baseName=$thouD/${ancestry}_chr${chr}_renamed_dups_removed
        echo ${baseName}.bed ${baseName}.bim ${baseName}.fam
    done > $thouD/${ancestry}_renamed.chr_merge

    # Add all other chr to merge list
    for chr in $(wc -l $thouD/*.dupvar_list | perl -lane 'if ($F[0] == 0) { $F[1] =~ /chr(\d+)/; print $1; }'); do
        baseName=$thouD/${ancestry}_chr${chr}
        echo ${baseName}.bed ${baseName}_renamed.bim ${baseName}.fam
    done >> $thouD/${ancestry}_renamed.chr_merge

    # Merge chromosomes
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 6000 \
        --merge-list $thouD/${ancestry}_renamed.chr_merge \
        --make-bed \
        --out $thouD/${ancestry}_chr_all_renamed
done

# %% [markdown]
# ## ChrX strand flipping
# Since the original 1000 Genomes Phase 3 data from the May 2013 release lacks ID information, it is not until this stage that strand flipping can be executed. At this point both the 1000 Genomes and the study data have updated IDs.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

# Copy test data
for ancestry in {ea,aa}; do
    mkdir $genD/${ancestry}/chrX_flip_test
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $genD/1000g_name_recoding/${ancestry}_chr_all_renamed \
        --chr 23 \
        --make-bed \
        --out $genD/${ancestry}/chrX_flip_test/${ancestry}_chr23_renamed
    cp $genD/1000g_name_recoding/1000g_data/chr23_renamed.bim ${ancestry}/chrX_flip_test/
    cp /shared/data/ref_panels/1000G/2013.05/plink/ALL.chrX.bed ${ancestry}/chrX_flip_test/chr23_renamed.bed
    cp /shared/data/ref_panels/1000G/2013.05/plink/ALL.chrX.fam ${ancestry}/chrX_flip_test/chr23_renamed.fam

    # Attempt merge with 1000G chrX data
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/chrX_flip_test/${ancestry}_chr23_renamed \
        --bmerge $genD/${ancestry}/chrX_flip_test/chr23_renamed \
        --merge-mode 7 \
        --make-bed \
        --out $genD/${ancestry}/chrX_flip_test/chrX_unflipped_test

    # Flip: variants
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/chrX_flip_test/${ancestry}_chr23_renamed \
        --flip $genD/${ancestry}/chrX_flip_test/chrX_unflipped_test.missnp \
        --make-bed \
        --out $genD/${ancestry}/chrX_flip_test/chrX_flipped

    # Attempt merge with 1000G chr1 data
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --bfile $genD/${ancestry}/chrX_flip_test/chrX_flipped \
        --bmerge $genD/${ancestry}/chrX_flip_test/chr23_renamed \
        --make-bed \
        --merge-mode 7 \
        --out $genD/${ancestry}/chrX_flip_test/chrX_flipped_test
done

# %% [markdown]
# The flip test suggests that flipping is necessary, so I proceed with flipping.
# ```
# wc -l $genD/*/chrX_flip_test/chrX_flipped_test.missnp
#   70 /shared/data/studies/heroin/kreek/genotype/observed/processing/aa/chrX_flip_test/chrX_flipped_test.missnp
#   70 /shared/data/studies/heroin/kreek/genotype/observed/processing/ea/chrX_flip_test/chrX_flipped_test.missnp
# ```

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing

for ancestry in {ea,aa}; do
    # Make final fip list
    if [ -a $genD/${ancestry}/chrX_flip_test/chrX_flipped_test-merge.missnp ]; then
        # Get flip list subset that does not produce errors
        echo "Subsetting flip list"
        comm -23 <(sort -u $genD/${ancestry}/chrX_flip_test/chrX_unflipped_test.missnp) <(sort -u ${ancestry}/chrX_flip_test/chrX_flipped_test.missnp) \
            > $genD/${ancestry}/chrX_flip_test/chrX.flip
    else
        # No flipped merge errors so keep all in original flip list
        sort -u $genD/${ancestry}/chrX_flip_test/chrX_unflipped_test-merge.missnp > $genD/${ancestry}/chrX_flip_test/chrX.flip 
    fi

# Perform final flip
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $genD/${ancestry}/chrX_flip_test/${ancestry}_chr23_renamed \
        --flip $genD/${ancestry}/chrX_flip_test/chrX.flip \
        --make-bed \
        --out $genD/1000g_name_recoding/${ancestry}_chr23_renamed_flipped
done

# Clean up
rm -rf $genD/{ea,aa}/chrX_flip_test/chrX_flip_test

# %% [markdown]
# ## Merge flipped chrX with autosomes¶

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding

# Extract flipped autosomes
for ancestry in {ea,aa}; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $thouD/${ancestry}_chr_all_renamed \
        --autosome \
        --make-bed \
        --out $thouD/${ancestry}_autosomes_renamed

    # Merge autosomes with flipped chrX
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $thouD/${ancestry}_autosomes_renamed \
        --bmerge $thouD/${ancestry}_chr23_renamed_flipped \
        --make-bed \
        --out $thouD/${ancestry}_chr_all_renamed_flipped
done

# %% [markdown]
# ## Allele discordance
# As a way of standardizing the data, I use 1000G phase 3 data as a reference. The study data may not match the 1000G phase 3 data for several reasons including
#
# * Discordant names
# * Discordant positions
# * Discordant alleles (swapped major and minor alleles)
# * Polymorphic alleles not fixed by strand flipping
# * Discordant allele frequencies
#
# I perform checks for these discordances using the 1000G Phase 3 data derived from data/ref_panels/1000G/2014.10/ derived from the May 2013 release. These data were downloaded from the [IMPUTE2 website](https://mathgen.stats.ox.ac.uk/impute/1000GP_Phase3.html) and reformatted to be directly compatible with IMPUTE2. These data will be used for ID recoding and MAF calculations.
#
# To determine if any study data variants have flipped alleles, I compare the variants to the appropriate 1000 Genomes Phase 3 reference superpopulation. For example, African ancestry is compared to AFR, European ancestry is compared to EUR, and Hispanic ancestry is compared to AMR.
#
# Discordance checks are used mainly to
#
# 1. Determine allele frequency discordances to remove prior to imputation
# 2. Determine if alleles are properly coded in reference to the forward/positive genome strand
#
# A large number of discordant variants indicates potential allele flipping/mismatching issues. If the number of discordant heterozygous variants is less than approximately 10,000, then it is unlikely that there were major issues with flipping or mismatching that indicate coding alleles to the wrong strand.
#
# ### Preparing study data
# The allele discordance scrip requires as input a file of MAFs, so I calculate this using PLINK.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding

# Calculate allele frequencies
for ancestry in {ea,aa}; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile $thouD/${ancestry}_chr_all_renamed_flipped \
        --freq \
        --out $thouD/${ancestry}_chr_all_renamed_flipped
done

# %% [markdown]
# ### Preparing 1000G phase 3 data
# MAF data are needed for 1000 Genomes data in addition to the study data, so I calculate these for the superpopulations(s) that matches the study group subject ancestries.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding/1000g_data

for ancestry in {ea,aa}; do
    # Get list of study variant IDs
    perl -lane 'if ($F[0] <= 23) { print $F[1]; }' $thouD/${ancestry}_chr_all_renamed_flipped.bim | \
        sort > $thouD/${ancestry}_chr_all_sorted_variants.txt
done

# Calculate autosome and chrX MAFs for 1000G AFR
pop="AFR"
ancestry="aa"
for chr in {1..22}; do
    /shared/bioinformatics/software/scripts/qsub_job.sh \
        --job_name ${pop}_${chr} \
        --script_prefix ${pop}_chr${chr}.maf \
        --mem 6 \
        --priority 0 \
        --program perl /shared/bioinformatics/software/perl/stats/calculate_maf_from_impute2_hap_file.pl \
            --hap /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chr${chr}.hap.gz\
            --legend /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chr${chr}.legend.gz \
            --sample /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3.sample \
            --chr ${chr} \
            --out ${ancestry}_${pop}_overlap_chr${chr}.maf \
            --extract ../${ancestry}_chr_all_sorted_variants.txt \
            --keep_groups ${pop}
done

chr=23
/shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name ${pop}_${chr} \
    --script_prefix ${pop}_chr${chr}.maf \
    --mem 6.8 \
    --priority 0 \
    --program perl /shared/bioinformatics/software/perl/stats/calculate_maf_from_impute2_hap_file.pl \
        --hap /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chrX_NONPAR.hap.gz\
        --legend /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chrX_NONPAR.legend.gz \
        --sample /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3.sample \
        --chr ${chr} \
        --extract ../${ancestry}_chr_all_sorted_variants.txt \
        --out ${ancestry}_${pop}_overlap_chr${chr}.maf \
        --keep_groups ${pop}


# Calculate autosome and chrX MAFs for 1000G EUR
pop="EUR"
ancestry="ea"
for chr in {1..22}; do
    /shared/bioinformatics/software/scripts/qsub_job.sh \
        --job_name ${pop}_${chr} \
        --script_prefix ${pop}_chr${chr}.maf \
        --mem 6.8 \
        --priority 0 \
        --program perl /shared/bioinformatics/software/perl/stats/calculate_maf_from_impute2_hap_file.pl \
            --hap /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chr${chr}.hap.gz\
            --legend /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chr${chr}.legend.gz \
            --sample /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3.sample \
            --chr ${chr} \
            --out ${ancestry}_${pop}_overlap_chr${chr}.maf \
            --extract ../${ancestry}_chr_all_sorted_variants.txt \
            --keep_groups ${pop}
done

chr=23
/shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name ${pop}_${chr} \
    --script_prefix ${pop}_chr${chr}.maf \
    --mem 7 \
    --priority 0 \
    --program perl /shared/bioinformatics/software/perl/stats/calculate_maf_from_impute2_hap_file.pl \
        --hap /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chrX_NONPAR.hap.gz\
        --legend /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chrX_NONPAR.legend.gz \
        --sample /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3.sample \
        --chr ${chr} \
        --extract ../${ancestry}_chr_all_sorted_variants.txt \
        --out ${ancestry}_${pop}_overlap_chr${chr}.maf \
        --keep_groups ${pop}

# Merge per chr MAFs for AA subject overlap with AFR
ancestry="aa"
pop="AFR"
head -n 1 ${ancestry}_${pop}_overlap_chr1.maf > ${ancestry}_${pop}_overlap_chr_all.maf
tail -q -n +2 ${ancestry}_${pop}_overlap_chr{1..23}.maf \
    >> ${ancestry}_${pop}_overlap_chr_all.maf

# Merge per chr MAFs for EA subject overlap with EUR
ancestry="ea"
pop="EUR"
head -n 1 ${ancestry}_${pop}_overlap_chr1.maf > ${ancestry}_${pop}_overlap_chr_all.maf
tail -q -n +2 ${ancestry}_${pop}_overlap_chr{1..23}.maf \
    >> ${ancestry}_${pop}_overlap_chr_all.maf

# %% [markdown]
# ### Discordance check

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding

# Run discordance checks for each ancestry group
pop="AFR"
ancestry="aa"
/shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name ${ancestry}_crosscheck \
    --script_prefix ${ancestry}_chr_all_renamed_1000g_discordance_check \
    --mem 6 \
    --priority 0 \
    --program "Rscript /shared/bioinformatics/software/R/check_study_data_against_1000G.R \
        --study_bim_file ${ancestry}_chr_all_renamed_flipped.bim 
        --study_frq_file ${ancestry}_chr_all_renamed_flipped.frq 
        --ref_maf_file 1000g_data/${ancestry}_${pop}_overlap_chr_all.maf 
        --out_prefix ${ancestry}_chr_all_renamed_1000g_discordance_check"


pop="EUR"
ancestry="ea"
/shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name ${ancestry}_crosscheck \
    --script_prefix ${ancestry}_chr_all_renamed_1000g_discordance_check \
    --mem 6 \
    --priority 0 \
    --program "Rscript /shared/bioinformatics/software/R/check_study_data_against_1000G.R \
        --study_bim_file ${ancestry}_chr_all_renamed_flipped.bim
        --study_frq_file ${ancestry}_chr_all_renamed_flipped.frq
        --ref_maf_file 1000g_data/${ancestry}_${pop}_overlap_chr_all.maf
        --out_prefix ${ancestry}_chr_all_renamed_1000g_discordance_check"

# Print summary of discordances
for ancestry in {ea,aa}; do
    echo "${ancestry}_chr_all_renamed_1000g_discordance_check.summary"
    cat ${ancestry}_chr_all_renamed_1000g_discordance_check.summary
done

"""
ea_chr_all_renamed_1000g_discordance_check.summary
discordant_positions    458
discordant_names        2
discordant_alleles      23036
discordant_alleles_not_fixed_by_strand_flip     19074
discordant_alleles_polymorphic_in_study_not_fixed_by_strand_flip        0
at_cg_snps_freq_diff_gt_0.2     269
aa_chr_all_renamed_1000g_discordance_check.summary
discordant_positions    436
discordant_names        2
discordant_alleles      22997
discordant_alleles_not_fixed_by_strand_flip     19041
discordant_alleles_polymorphic_in_study_not_fixed_by_strand_flip        0
at_cg_snps_freq_diff_gt_0.2     249
"""

# %% [markdown]
# ### Flip fixable alleles

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding

# Flip discordant alleles that are fixed by flipping
for ancestry in {ea,aa}; do
    comm -23 <(tail -n +2 ${ancestry}_chr_all_renamed_1000g_discordance_check.discordant_alleles | cut -f2,2 | sort -u) \
        <(tail -n +2 ${ancestry}_chr_all_renamed_1000g_discordance_check.discordant_alleles_not_fixed_by_strand_flip | cut -f2,2 | sort -u) \
        > ${ancestry}_chr_all_renamed_1000g_discordance_check.flip

    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile ${ancestry}_chr_all_renamed_flipped \
        --flip ${ancestry}_chr_all_renamed_1000g_discordance_check.flip \
        --make-bed \
        --out ${ancestry}_chr_all_renamed_final_flip
done

# %% [markdown]
# ### Secondary discordance check

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding

# Calculate allele frequencies
for ancestry in {ea,aa}; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 4000 \
        --bfile ${ancestry}_chr_all_renamed_final_flip \
        --freq \
        --out ${ancestry}_chr_all_renamed_final_flip
done

# Run discordance checks for each ancestry group
pop="AFR"
ancestry="aa"
/shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name ${ancestry}_crosscheck \
    --script_prefix ${ancestry}_chr_all_renamed_1000g_discordance_check \
    --mem 6 \
    --priority 0 \
    --program "Rscript /shared/bioinformatics/software/R/check_study_data_against_1000G.R \
        --study_bim_file ${ancestry}_chr_all_renamed_final_flip.bim 
        --study_frq_file ${ancestry}_chr_all_renamed_final_flip.frq 
        --ref_maf_file 1000g_data/${ancestry}_${pop}_overlap_chr_all.maf 
        --out_prefix ${ancestry}_chr_all_renamed_1000g_discordance_check"


pop="EUR"
ancestry="ea"
/shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name ${ancestry}_crosscheck \
    --script_prefix ${ancestry}_chr_all_renamed_1000g_discordance_check \
    --mem 6 \
    --priority 0 \
    --program "Rscript /shared/bioinformatics/software/R/check_study_data_against_1000G.R \
        --study_bim_file ${ancestry}_chr_all_renamed_final_flip.bim
        --study_frq_file ${ancestry}_chr_all_renamed_final_flip.frq
        --ref_maf_file 1000g_data/${ancestry}_${pop}_overlap_chr_all.maf
        --out_prefix ${ancestry}_chr_all_renamed_1000g_discordance_check"

# Print summary of discordances
for ancestry in {ea,aa}; do
    echo "${ancestry}_chr_all_renamed_1000g_discordance_check.summary"
    cat ${ancestry}_chr_all_renamed_1000g_discordance_check.summary
done

"""
ea_chr_all_renamed_1000g_discordance_check.summary
discordant_positions    458
discordant_names        2
discordant_alleles      23036
discordant_alleles_not_fixed_by_strand_flip     19085
discordant_alleles_polymorphic_in_study_not_fixed_by_strand_flip        0
at_cg_snps_freq_diff_gt_0.2     269
aa_chr_all_renamed_1000g_discordance_check.summary
discordant_positions    436
discordant_names        2
discordant_alleles      22997
discordant_alleles_not_fixed_by_strand_flip     19052
discordant_alleles_polymorphic_in_study_not_fixed_by_strand_flip        0
at_cg_snps_freq_diff_gt_0.2     249
"""

# %% [markdown]
# ## Abmiguous SNP filtering

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding

# Retrieve ambiguous SNPs
for ancestry in {aa,ea}; do
    perl -lane 'if (($F[4] eq "A" && $F[5] eq "T") || ($F[4] eq "T" && $F[5] eq "A") ||
    ($F[4] eq "C" && $F[5] eq "G") || ($F[4] eq "G" && $F[5] eq "C")) { print $F[1]; }' \
    ${ancestry}_chr_all_renamed_final_flip.bim | \
        sort -u | \
        grep "rs" \
        > ${ancestry}_at_cg_snps.txt
done

wc -l *_at_cg_snps.txt

"""
  35542 aa_at_cg_snps.txt
  36549 ea_at_cg_snps.txt
"""

# Remove ambiguous SNPs
for ancestry in {ea,aa}; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --memory 4000 \
    --bfile ${ancestry}_chr_all_renamed_final_flip \
    --exclude ${ancestry}_at_cg_snps.txt \
    --make-bed \
    --out ${ancestry}_chr_all_renamed_final_flip_clean
done

# %% [markdown]
# ## Set heterozygous haploids to missing

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/processing/1000g_name_recoding

for ancestry in {ea,aa}; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --noweb \
    --memory 4000 \
    --bfile ${ancestry}_chr_all_renamed_final_flip_clean \
    --set-hh-missing \
    --make-bed \
    --out ${ancestry}_chr_all_renamed_final_flip_clean_hh_missing
done

# %% [markdown]
# ## Observed genotype finalization
# As a starting point for haplotype phasing and imputation, I store the final QC processed PLINK binary fileset in a new directory final.

# %%
## EC2 command line
cd /shared/data/studies/heroin/kreek/genotype/observed
mkdir final

# Copy file sets to final directory
for ancestry in {ea,aa}; do
    for ext in {bed,bim,fam}; do
        cp processing/1000g_name_recoding/${ancestry}_chr_all_renamed_final_flip_clean_hh_missing.${ext} final/${ancestry}_chr_all.${ext}
    done
done

# %% [markdown]
# # Final upload to S3
# Once the QC process has been verified, I can delete the processing files on S3 and upload the compressed final {.bim,.fam,.bed} files to S3.

# %%
## EC2 command line
cd /shared/data/studies/phs001109_kreek/genotype/original/final

# gzip final files 
gzip *

aws s3 sync . s3://rti-heroin/kreek/data/genotype/original/20181128/

# %% [markdown]
# ```
# wc -l *{fam,bim}
#      690 aa_chr_all.fam
#      614 ea_chr_all.fam
#   503120 aa_chr_all.bim
#   510052 ea_chr_all.bim
# ```
