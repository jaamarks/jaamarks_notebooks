# ENSG00000140564.11	FURIN	3.459365606	NA	0.000541449	0.002953873	1	1	1	0.000541449	0.071904959	mashr_Brain_Substantia_nigra.metaxcan_results	0.238938709	0.288812044
# ENSG00000140564.11	FURIN	2.742949486	NA	0.006089005	0.002585127	1	1	1	0.006089005	0.078585183	mashr_Brain_Amygdala.metaxcan_results	0.545087367	0.529216099
# ENSG00000140564.11	FURIN	2.742949486	NA	0.006089005	0.00371405	1	1	1	0.006089005	0.090762101	mashr_Brain_Anterior_cingulate_cortex_BA24.metaxcan_results	0.545087367	0.580954708
# ENSG00000140564.11	FURIN	2.742949486	NA	0.006089005	0.002469876	1	1	1	0.006089005	0.077896244	mashr_Brain_Caudate_basal_ganglia.metaxcan_results	0.545087367	0.562022762
# ENSG00000140564.11	FURIN	2.742949486	NA	0.006089005	0.004707301	1	1	1	0.006089005	0.099293618	mashr_Brain_Cortex.metaxcan_results	0.545087367	0.50434479
# ENSG00000140564.11	FURIN	2.742949486	NA	0.006089005	0.002552696	1	1	1	0.006089005	0.076949047	mashr_Brain_Putamen_basal_ganglia.metaxcan_results	0.545087367	0.499296587
# ENSG00000140564.11	FURIN	2.580171108	NA	0.009875137	0.002652769	1	1	1	0.009875137	0.124081102	mashr_Brain_Frontal_Cortex_BA9.metaxcan_results	0.645268138	0.627923568
# ENSG00000140564.11	FURIN	0.418039135	NA	0.675918504	0.001530906	2	2	2	0.139978183	0.074638865	mashr_Brain_Cerebellum.metaxcan_results	0.999766345	0.999858964
# ```

# %%
# gene_name	zscore Tissue
# OPRM1 5.412908799 Brain_Cerebellum
# FURIN 0.418039135 Brain_Cerebellum

# PPP6C	-4.890491962 Frontal_Cortex_BA9
# FURIN	2.580171108 Frontal_Cortex_BA9

# PPP6C	-4.890491962 Brain_Cortex
# FURIN	2.742949486 Brain_Cortex

# PPP6C	-5.000211239 Brain_Anterior_cingulate_cortex_BA24
# FURIN	2.742949486 Brain_Anterior_cingulate_cortex_BA24

# OPRM1
library(ggplot2)

spredixcan <- data.frame(
                         gene_name = c("OPRM1", "FURIN", "PPP6C", "FURIN", "PPP6C", "FURIN", "PPP6C", "FURIN"),
                         zscore = c(5.412908799, 0.418039135, -4.890491962, 2.580171108, -4.890491962, 2.742949486, -5.000211239, 2.742949486),
                         tissue = c("Cerebellum", "Cerebellum", "Frontal Cortex (BA9)", "Frontal Cortex (BA9)", "Cortex", "Cortex", "Anterior cingulate cortex (BA24)", "Anterior cingulate cortex (BA24)")
                        )
spredixcan

myplot <- ggplot(spredixcan, aes(x = gene_name, y = zscore,  color=tissue)) +
                 geom_point(size = 3.5, position=position_dodge(width = 0.3)) + theme_bw() +
                 labs(color='Tissues') +
                 xlab("") +
                 ylab("Z-score") +
                 geom_hline(yintercept=0, size = 0.25, linetype = "dashed") + 
                 ggtitle("Genetically regulated transcriptomic\nchanges with opioid addiction (N=403,915)") +
                 coord_flip()
                
myplot
# Out:
#   gene_name zscore     tissue
# 1 OPRM1      5.4129088 Cerebellum
# 2 FURIN      0.4180391 Cerebellum
# 3 PPP6C     -4.8904920 Frontal Cortex (BA9)
# 4 FURIN      2.5801711 Frontal Cortex (BA9)
# 5 PPP6C     -4.8904920 Cortex
# 6 FURIN      2.7429495 Cortex
# 7 PPP6C     -5.0002112 Anterior cingulate cortex (BA24)
# 8 FURIN      2.7429495 Anterior cingulate cortex (BA24)
# plot without title

# %%
#ggplot2
# theme_bw: white bg
# geom_vline(xintercept=0, size = 0.25, linetype = "dashed"): add vertical line
# aes: map variables to aesthetic properties
