# %%
import pandas as pd
data = pd.io.stata.read_stata('C://Users//jmarks//Desktop//Projects//Nicotine//eMerge//phenotype/Data Phenotype.dta')
data2 = pd.io.stata.read_stata('C://Users//jmarks//Desktop//Projects//Nicotine//eMerge//phenotype/FTND Phenotype.dta')
#data.to_csv('my_stata_file.csv')
data2
# Out:
#       dbgap_subject_id  emergeid  px060701_smoking_cigarette_quant   v96  v97  \
# 0               197114  16214874                               NaN   NaN  NaN
# 1               196041  16214875                               NaN   NaN  NaN
# 2               199794  16214879                               NaN   NaN  NaN
# 3               197593  16214881                               NaN   NaN  NaN
# 4               199622  16214896                               NaN   NaN  NaN
# 5               198387  16214899                               NaN   NaN  NaN
# 6               196059  16214926                               NaN   NaN  NaN
# 7               198933  16214927                               NaN   NaN  NaN
# 8               196928  16214948                               NaN   NaN  NaN
# 9               196629  16215019                               NaN   0.0  NaN
# 10              197244  16215035                               NaN   NaN  NaN
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\jmarks\\Desktop\\GitHub\\jaamarks_notebooks\\Nicotine_Project\\develop'
