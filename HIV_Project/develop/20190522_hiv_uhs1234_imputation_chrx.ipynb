# %% [markdown]
# # UHS1-4 chrX imputation
# __Author__: Jesse Marks
#
# **Date:** October 04, 2018
#
# **GitHub Issue:** [Issue #112](https://github.com/RTIInternational/bioinformatics/issues/112)
#
# This document logs the steps taken to perform pre-imputation procedures on the merged datasets of UHS1, UHS2, UHS3, and UHS4—both EA and AA. The starting point for this analysis is after quality control of observed genotypes. The quality controlled genotypes are oriented on the GRCh37 plus strand. Based on findings from [Johnson et al.](https://link.springer.com/article/10.1007/s00439-013-1266-7), the intersection set of variants for will be used for imputation.
#
# ## Software and tools
# The software and tools used for porcessing these data are
# * [Michigan Imputation Server](https://imputationserver.sph.umich.edu/index.html) (MIS)
# * [Amazon Web Services (AWS) - Cloud Computing Services](https://aws.amazon.com/)
#     * Linux AMI
# * [PLINK v1.90 beta 4.10](https://www.cog-genomics.org/plink/)
# * [bgzip](http://www.htslib.org/doc/tabix.html)
# * [BCF Tools](http://www.htslib.org/doc/bcftools.html)
# * Windows 10 with [Cygwin](https://cygwin.com/) installed
# * GNU bash version 4.2.46
#
# ## Data retrieval and organization
# PLINK binary filesets will be obtained from AWS S3 storage.
#
# Nathan Gaddis performed the QC and stored the observed genotype data at:
#
# ```
# UHS1
# s3://rti-midas-data/studies/hiv/observed/final/uhs1.aa.chr23
# s3://rti-midas-data/studies/hiv/observed/final/uhs1.ea.chr23
#
# UHS2
#
# s3://rti-midas-data/studies/hiv/observed/final/uhs2.aa.chr23
# s3://rti-midas-data/studies/hiv/observed/final/uhs2.ea.chr23
#
# UHS3
# s3://rti-midas-data/studies/hiv/observed/final/uhs3.aa.V1-2.chr23
# s3://rti-midas-data/studies/hiv/observed/final/uhs3.ea.V1-2.chr23
# s3://rti-midas-data/studies/hiv/observed/final/uhs3.aa.V1-3.chr23
# s3://rti-midas-data/studies/hiv/observed/final/uhs3.ea.V1-3.chr23
# s3://rti-midas-data/studies/hiv/observed/final/uhs3.aa.merged.chr23
# s3://rti-midas-data/studies/hiv/observed/final/uhs3.ea.merged.chr23
#
# UHS4
# s3://rti-midas-data/studies/uhs4/observed/genotypes/final/uhs4/merged2.ea
# s3://rti-midas-data/studies/uhs4/observed/genotypes/final/uhs4/merged2.aa
# ```
#
#
# **Note**: For UHS3 I will use v1-2 and v1-3 datasets. I will treat them like two different cohorts. Therefore, when I merge UHS1-4 I will be merging 4 data sets per ancestry.
#
# * uhs1.aa, uhs2.aa, uhs3.aa.V1-2,uhs3.aa.V1-3, & uhs4.merged2.aa
# * uhs1.ea, uhs2.ea, uhs3.ea.V1-2,uhs3.ea.V1-3, & uhs4.merged2.ea
#
# **Note2**: The STRUCTURE analysis was performed on the combined UHS1-4 data. This resulted in a new ancestry partitioning. In particular, one UHS1 sample and one UHS4 sample was reassigned ancestry groups.
#
# **Note3:** The UHS1 chrX sample counts are in discordance with the autosome sample counts. For example:
# ```
#   2015 uhs1.aa.chr23.fam
#   2016 uhs1.aa.fam
# ```

# %% [markdown]
# ### chrX Statistics Breakdown
# This table includes the initial number of variants in each study as well as the final number of variants in the intersection set. The `Variants Post-Filtering` is in referral to the filtering steps (1) remove discordant alleles & (2) removal of monomorphic variants.
#
# #### EA
# | Data Set      | Initial Variants | Variants Post-Filtering  |
# |---------------|------------------|--------------------------|
# | UHS1          | 17,408           |                          |
# | UHS2          | 32,857           |                          |
# | UHS3_V1-2     | 24,202           |                          |
# | UHS3_V1-3     | 35,440           |                          |
# | UHS4          | 35,469           |                          |
# | Intersection  | NA               |                          |
#
#
# #### AA
# | Data Set      | Initial Variants | Variants Post-Filtering  |
# |---------------|------------------|--------------------------|
# | UHS1          | 17,396           |                          |
# | UHS2          | 23,484           |                          |
# | UHS3_V1-2     | 41,884           |                          |
# | UHS3_V1-3     | 44,706           |                          |
# | UHS4          | 29,488           |                          |
# | Merged        | NA               |                          |

# %% [markdown]
# ## Create Directory Structure & Download Data
# The following section needs to be modified each time to reflect where the data is stored!

# %%
### EC2 command line (bash) ###

# Modify variables below
######################################################################
base_dir=/shared/jmarks/hiv/uhs1-4/chrX_processing
base_name="chr23" # chr23 or chr_all
#chr_list={1..23} # or {1..22} 
ancestry_list="aa ea" # space delimited Ex. "ea aa ha"
study_list="uhs1 uhs2 uhs3_v1-2 uhs3_v1-3 uhs4" # space delimited 
######################################################################

mkdir -p ${base_dir}/processing/{intersect,1000g,impute_prep}
for study in ${study_list};do
    for ancestry in ${ancestry_list};do
        mkdir -p ${base_dir}/processing/${study}
        mkdir -p ${base_dir}/data/${study}/genotype/observed/${ancestry}
    done
done

## download genotype (with AWS CLI tools) to respective directories ##

#aws s3 cp s3://rti-midas-data/studies/hiv/observed/final/uhs3.ea.V1-3.chr23.fam .
#aws s3 cp s3://rti-midas-data/studies/hiv/observed/final/uhs3.ea.V1-3.chr23.bed .
#aws s3 cp s3://rti-midas-data/studies/hiv/observed/final/uhs3.ea.V1-3.chr23.bim .
#...

# %% [markdown]
# # Data Processing
# ## Data Wrangling
# The UHS4 chrX genotype data have not been separated from the autosomes like the other sub-groups have. Therefore, we will do this now.

# %%
cd /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4
## break out chrX data for UHS4
for ancestry in ea aa; do
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 2048 \
        --bfile uhs4.merged2.$ancestry \
        --chr 23 \
        --make-bed \
        --out uhs4.merged2.$ancestry.chr23
done

## uhs1: merge ancestries
study=uhs1            
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --bfile ${base_dir}/$study/uhs1.aa.chr23 \
    --bmerge ${base_dir}/$study/uhs1.ea.chr23 \
    --make-bed \
    --out $base_dir/$study/$study.aa+ea.chr23.1KG.structure

## uhs4: merge ancestries
study=uhs4
/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
    --bfile ${base_dir}/$study/uhs4.merged2.aa.chr23 \
    --bmerge ${base_dir}/$study/uhs4.merged2.ea.chr23 \
    --make-bed \
    --out $base_dir/$study/$study.aa+ea.chr23.1KG.structure
# Out:
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to uhs4.merged2.ea.chr23.log.
# Options in effect:
#   --bfile uhs4.merged2.ea
#   --chr 23
#   --make-bed
#   --memory 2048
#   --noweb
#   --out uhs4.merged2.ea.chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 35469 out of 2073618 variants loaded from .bim file.
# 989 people (659 males, 330 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 989 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.974134.
# 35469 variants and 989 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to uhs4.merged2.ea.chr23.bed + uhs4.merged2.ea.chr23.bim +
# uhs4.merged2.ea.chr23.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to uhs4.merged2.aa.chr23.log.
# Options in effect:
#   --bfile uhs4.merged2.aa
#   --chr 23
#   --make-bed
#   --memory 2048
#   --noweb
#   --out uhs4.merged2.aa.chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 29488 out of 1878335 variants loaded from .bim file.
# 1072 people (766 males, 306 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1072 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.971589.
# 29488 variants and 1072 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to uhs4.merged2.aa.chr23.bed + uhs4.merged2.aa.chr23.bim +
# uhs4.merged2.aa.chr23.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa+ea.chr23.1KG.structure.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa.chr23
#   --bmerge /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.ea.chr23
#   --make-bed
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa+ea.chr23.1KG.structure
#
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 2015 people loaded from
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa.chr23.fam.
# 1140 people to be merged from
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.ea.chr23.fam.
# Of these, 1140 are new, while 0 are present in the base dataset.
# 17396 markers loaded from
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa.chr23.bim.
# 17408 markers to be merged from
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.ea.chr23.bim.
# Of these, 17 are new, while 17391 are present in the base dataset.
# Warning: Variants 'X:67923735:C:T' and 'X:67923735:A:G' have the same position.
# Warning: Variants 'X:139580982:C:T' and 'X:139580982:A:G' have the same
# position.
# Warning: Variants 'X:150267369:C:T' and 'X:150267369:A:G' have the same
# position.
# Performing single-pass merge (3155 people, 17413 variants).
# Merged fileset written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa+ea.chr23.1KG.structure-merge.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa+ea.chr23.1KG.structure-merge.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa+ea.chr23.1KG.structure-merge.fam
# .
# 17413 variants loaded from .bim file.
# 3155 people (2374 males, 781 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 3155 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.990882.
# 17413 variants and 3155 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa+ea.chr23.1KG.structure.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa+ea.chr23.1KG.structure.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa+ea.chr23.1KG.structure.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.aa+ea.chr23.1KG.structure.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.merged2.aa.chr23
#   --bmerge /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.merged2.ea.chr23
#   --make-bed
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.aa+ea.chr23.1KG.structure
#
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 1072 people loaded from
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.merged2.aa.chr23.fam.
# 989 people to be merged from
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.merged2.ea.chr23.fam.
# Of these, 989 are new, while 0 are present in the base dataset.
# 29488 markers loaded from
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.merged2.aa.chr23.bim.
# 35469 markers to be merged from
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.merged2.ea.chr23.bim.
# Of these, 6515 are new, while 28954 are present in the base dataset.
# Performing single-pass merge (2061 people, 36003 variants).
# Merged fileset written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.aa+ea.chr23.1KG.structure-merge.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.aa+ea.chr23.1KG.structure-merge.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.aa+ea.chr23.1KG.structure-merge.fam
# .
# 36003 variants loaded from .bim file.
# 2061 people (1425 males, 636 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2061 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.874429.
# 36003 variants and 2061 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.aa+ea.chr23.1KG.structure.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.aa+ea.chr23.1KG.structure.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.aa+ea.chr23.1KG.structure.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
## partition UHS1 and UHS4 into respective ancestry groups ##
plots=/shared/jmarks/hiv/uhs1-4/autosome_processing/structure/triangle_plots/thresholding
anlist="ea aa"
for study in uhs1 uhs4; do
    for an in $anlist; do
        /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --bfile $base_dir/$study/$study.aa+ea.chr23.1KG.structure \
            --keep $plots/$an.subject_ids.keep.txt \
            --make-bed \
            --out $base_dir/data/$study/genotype/observed/$an/$study.$an.chr23.1KG.structure
    done
done
# Out:
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa+ea.chr23.1KG.structure
#   --keep /shared/jmarks/hiv/uhs1-4/autosome_processing/structure/triangle_plots/thresholding/ea.subject_ids.keep.txt
#   --make-bed
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure
#
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 17413 variants loaded from .bim file.
# 3155 people (2374 males, 781 females) loaded from .fam.
# --keep: 1128 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1128 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate in remaining samples is 0.992074.
# 17413 variants and 1128 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs1/uhs1.aa+ea.chr23.1KG.structure
#   --keep /shared/jmarks/hiv/uhs1-4/autosome_processing/structure/triangle_plots/thresholding/aa.subject_ids.keep.txt
#   --make-bed
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure
#
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 17413 variants loaded from .bim file.
# 3155 people (2374 males, 781 females) loaded from .fam.
# --keep: 2008 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2008 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate in remaining samples is 0.990263.
# 17413 variants and 2008 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.aa+ea.chr23.1KG.structure
#   --keep /shared/jmarks/hiv/uhs1-4/autosome_processing/structure/triangle_plots/thresholding/ea.subject_ids.keep.txt
#   --make-bed
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure
#
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 36003 variants loaded from .bim file.
# 2061 people (1425 males, 636 females) loaded from .fam.
# --keep: 988 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 988 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate in remaining samples is 0.959739.
# 36003 variants and 988 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/uhs4/uhs4.aa+ea.chr23.1KG.structure
#   --keep /shared/jmarks/hiv/uhs1-4/autosome_processing/structure/triangle_plots/thresholding/aa.subject_ids.keep.txt
#   --make-bed
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure
#
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 36003 variants loaded from .bim file.
# 2061 people (1425 males, 636 females) loaded from .fam.
# --keep: 1072 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1072 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate in remaining samples is 0.795883.
# 36003 variants and 1072 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
ww $plots/ea.subject_ids.keep.txt
ww $plots/aa.subject_ids.keep.txt
# Out:
# 3023 /shared/jmarks/hiv/uhs1-4/autosome_processing/structure/triangle_plots/thresholding/ea.subject_ids.keep.txt
# 4026 /shared/jmarks/hiv/uhs1-4/autosome_processing/structure/triangle_plots/thresholding/aa.subject_ids.keep.txt

# %%
ww /shared/jmarks/hiv/uhs1-4/autosome_processing/data/*/*/*/aa/*fam
echo ""
ww /shared/jmarks/hiv/uhs1-4/autosome_processing/data/*/*/*/ea/*fam
# Out:
#   2009 /shared/jmarks/hiv/uhs1-4/autosome_processing/data/uhs1/genotype/observed/aa/uhs1.aa.1KG.structure.fam
#    767 /shared/jmarks/hiv/uhs1-4/autosome_processing/data/uhs2/genotype/observed/aa/uhs2.aa.1KG.structure.fam
#     84 /shared/jmarks/hiv/uhs1-4/autosome_processing/data/uhs3_v1-2/genotype/observed/aa/uhs3_v1-2.aa.1KG.structure.fam
#     94 /shared/jmarks/hiv/uhs1-4/autosome_processing/data/uhs3_v1-3/genotype/observed/aa/uhs3_v1-3.aa.1KG.structure.fam
#   1072 /shared/jmarks/hiv/uhs1-4/autosome_processing/data/uhs4/genotype/observed/aa/uhs4.aa.1KG.structure.fam
#   4026 total
#
#   1130 /shared/jmarks/hiv/uhs1-4/autosome_processing/data/uhs1/genotype/observed/ea/uhs1.ea.1KG.structure.fam
#    828 /shared/jmarks/hiv/uhs1-4/autosome_processing/data/uhs2/genotype/observed/ea/uhs2.ea.1KG.structure.fam
#     33 /shared/jmarks/hiv/uhs1-4/autosome_processing/data/uhs3_v1-2/genotype/observed/ea/uhs3_v1-2.ea.1KG.structure.fam
#     44 /shared/jmarks/hiv/uhs1-4/autosome_processing/data/uhs3_v1-3/genotype/observed/ea/uhs3_v1-3.ea.1KG.structure.fam
#    988 /shared/jmarks/hiv/uhs1-4/autosome_processing/data/uhs4/genotype/observed/ea/uhs4.ea.1KG.structure.fam
#   3023 total

# %%
echo ""
ww /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs*/genotype/observed/aa/*fam
echo ""
ww /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs*/genotype/observed/ea/*fam
# Out:
#   2008 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.fam
#    767 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/aa/uhs2.aa.chr23.fam
#     84 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/aa/uhs3.aa.V1-2.chr23.fam
#     94 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/aa/uhs3.aa.V1-3.chr23.fam
#   1072 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.fam
#   4025 total
#
#   1128 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.fam
#    828 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/ea/uhs2.ea.chr23.fam
#     33 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/ea/uhs3.ea.V1-2.chr23.fam
#     44 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/ea/uhs3.ea.V1-3.chr23.fam
#    988 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.fam
#   3021 total

# %%
ww /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs*/genotype/observed/ea/*bim 
echo ""
ww /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs*/genotype/observed/aa/*bim
# Out:
#   17413 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.bim
#   32857 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/ea/uhs2.ea.chr23.bim
#   24202 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/ea/uhs3.ea.V1-2.chr23.bim
#   35440 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/ea/uhs3.ea.V1-3.chr23.bim
#   36003 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.bim
#  145915 total
#
#   17413 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.bim
#   23484 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/aa/uhs2.aa.chr23.bim
#   41884 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/aa/uhs3.aa.V1-2.chr23.bim
#   44706 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/aa/uhs3.aa.V1-3.chr23.bim
#   36003 /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.bim
#  163490 total

# %% [markdown]
# ## GRCh37 strand and allele discordance check
# ### MAF for study data

# %%
### EC1 command line (Bash) ###

# write out the MAF report
for study in ${study_list}; do
    study_dir=${base_dir}/processing/${study}/strand_check
    mkdir ${study_dir}
    for ancestry in ${ancestry_list};do
        data_dir=${base_dir}/data/${study}/genotype/observed/${ancestry}
        /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --memory 2048 \
            --bed ${data_dir}/*bed\
            --bim ${data_dir}/*bim\
            --fam ${data_dir}/*fam\
            --freq \
            --out ${study_dir}/${ancestry}_${base_name}
    done
done

# Get list of variants from all studies
studies=($study_list)  #studies=(uhs1 uhs2 uhs3_v1-2 uhs3_v1-3 uhs4) # array of study names
num=${#studies[@]}

## Get intersection set
for ancestry in ${ancestry_list};do
    bim_files=()
    for (( i=0; i<${num}; i++ ));do
        bim_files+=(${base_dir}/data/${studies[$i]}/genotype/observed/$ancestry/*bim)
    done
    
    echo -e "\nCalculating intersection between $ancestry ${study_list}...\n"
    cat ${bim_files[@]}| cut -f2 | sort |  uniq -c | awk -v num=$num '$1 == num {print $2}' \
        > ${base_dir}/processing/intersect/${ancestry}_variant_intersection.txt
    ww ${base_dir}/processing/intersect/${ancestry}_variant_intersection.txt
done
# Out:
# mkdir: cannot create directory ‘/shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check’: File exists
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check/aa_chr23.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.bim
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.fam
#   --freq
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check/aa_chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 17413 variants loaded from .bim file.
# 2008 people (1423 males, 585 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2008 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.990263.
# --freq: Allele frequencies (founders only) written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check/aa_chr23.frq
# .
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check/ea_chr23.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.bim
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.fam
#   --freq
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check/ea_chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 17413 variants loaded from .bim file.
# 1128 people (942 males, 186 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1128 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.992074.
# --freq: Allele frequencies (founders only) written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check/ea_chr23.frq
# .
# mkdir: cannot create directory ‘/shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check’: File exists
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check/aa_chr23.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/aa/uhs2.aa.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/aa/uhs2.aa.chr23.bim
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/aa/uhs2.aa.chr23.fam
#   --freq
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check/aa_chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 23484 variants loaded from .bim file.
# 767 people (517 males, 250 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 767 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.974578.
# --freq: Allele frequencies (founders only) written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check/aa_chr23.frq
# .
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check/ea_chr23.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/ea/uhs2.ea.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/ea/uhs2.ea.chr23.bim
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/ea/uhs2.ea.chr23.fam
#   --freq
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check/ea_chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 32857 variants loaded from .bim file.
# 828 people (495 males, 333 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 828 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.976798.
# --freq: Allele frequencies (founders only) written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check/ea_chr23.frq
# .
# mkdir: cannot create directory ‘/shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check’: File exists
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check/aa_chr23.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/aa/uhs3.aa.V1-2.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/aa/uhs3.aa.V1-2.chr23.bim
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/aa/uhs3.aa.V1-2.chr23.fam
#   --freq
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check/aa_chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 41884 variants loaded from .bim file.
# 84 people (59 males, 25 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 84 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.914796.
# --freq: Allele frequencies (founders only) written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check/aa_chr23.frq
# .
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check/ea_chr23.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/ea/uhs3.ea.V1-2.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/ea/uhs3.ea.V1-2.chr23.bim
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/ea/uhs3.ea.V1-2.chr23.fam
#   --freq
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check/ea_chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 24202 variants loaded from .bim file.
# 33 people (18 males, 15 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 33 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.884568.
# --freq: Allele frequencies (founders only) written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check/ea_chr23.frq
# .
# mkdir: cannot create directory ‘/shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check’: File exists
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check/aa_chr23.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/aa/uhs3.aa.V1-3.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/aa/uhs3.aa.V1-3.chr23.bim
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/aa/uhs3.aa.V1-3.chr23.fam
#   --freq
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check/aa_chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 44706 variants loaded from .bim file.
# 94 people (63 males, 31 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 94 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.905208.
# --freq: Allele frequencies (founders only) written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check/aa_chr23.frq
# .
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check/ea_chr23.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/ea/uhs3.ea.V1-3.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/ea/uhs3.ea.V1-3.chr23.bim
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/ea/uhs3.ea.V1-3.chr23.fam
#   --freq
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check/ea_chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 35440 variants loaded from .bim file.
# 44 people (24 males, 20 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 44 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.927423.
# --freq: Allele frequencies (founders only) written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check/ea_chr23.frq
# .
# mkdir: cannot create directory ‘/shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check’: File exists
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check/aa_chr23.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.bim
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.fam
#   --freq
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check/aa_chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 36003 variants loaded from .bim file.
# 1072 people (766 males, 306 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1072 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.795883.
# --freq: Allele frequencies (founders only) written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check/aa_chr23.frq
# .
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check/ea_chr23.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.bim
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.fam
#   --freq
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check/ea_chr23
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 36003 variants loaded from .bim file.
# 988 people (658 males, 330 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 988 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.959739.
# --freq: Allele frequencies (founders only) written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check/ea_chr23.frq
# .
#
# Calculating intersection between aa uhs1 uhs2 uhs3_v1-2 uhs3_v1-3 uhs4...
#
# 5141 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_variant_intersection.txt
#
# Calculating intersection between ea uhs1 uhs2 uhs3_v1-2 uhs3_v1-3 uhs4...
#
# 3412 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_variant_intersection.txt

# %% [markdown]
# ### MAF for 1000G
# This pipeline is currently set up to handle EUR and AFR populations.
# #### Autosomes
# Get 1000G MAF for chromosomes 1–22 (autosomes).

# %%
#### EC2 command line (Bash)
#
## Calculate autosome MAFs for 1000G populations
#for ancestry in ${ancestry_list};do
#
#    if [ $ancestry == "ea" ]
#    then
#        pop="EUR"
#    else
#        pop="AFR"
#    fi
#    
#    for chr in {1..22}; do
#        /shared/bioinformatics/software/scripts/qsub_job.sh \
#            --job_name ${pop}_${chr}_MAF \
#            --script_prefix ${base_dir}/processing/1000g/${pop}_chr${chr}.maf \
#            --mem 6.8 \
#            --nslots 1 \
#            --priority 0 \
#            --program /shared/bioinformatics/software/perl/stats/calculate_maf_from_impute2_hap_file.pl \
#                --hap /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chr${chr}.hap.gz\
#                --legend /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chr${chr}.legend.gz \
#                --sample /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3.sample \
#                --chr ${chr} \
#                --out ${base_dir}/1000g/${pop}_chr${chr}.maf \
#                --extract ${base_dir}/processing/intersect/${ancestry}_variant_intersection.txt \
#                --keep_groups ${pop}
#    done
#done

# %% [markdown]
# #### chrX
# Get 1000G MAF for chromosome 23 (chrX).

# %%
### Bash ###

chr=23
for ancestry in ${ancestry_list};do

    if [ $ancestry == "ea" ]
    then
        pop="EUR"
    else
        pop="AFR"
    fi

    /shared/bioinformatics/software/scripts/qsub_job.sh \
        --job_name ${pop}_23_MAF \
        --script_prefix ${base_dir}/processing/1000g/${pop}_chr${chr}.maf \
        --mem 6.8 \
        --nslots 1 \
        --priority 0 \
        --program /shared/bioinformatics/software/perl/stats/calculate_maf_from_impute2_hap_file.pl \
            --hap /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chrX_NONPAR.hap.gz\
            --legend /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3_chrX_NONPAR.legend.gz \
            --sample /shared/data/ref_panels/1000G/2014.10/1000GP_Phase3.sample \
            --chr $chr \
            --out ${base_dir}/processing/1000g/${pop}_chr${chr}.maf \
            --extract ${base_dir}/processing/intersect/${ancestry}_variant_intersection.txt \
            --keep_groups ${pop}
done
# Out:
# Your job 8231 ("AFR_23_MAF") has been submitted
# Your job 8232 ("EUR_23_MAF") has been submitted

# %% [markdown]
# ### Merge 1000G chromosomes
# Only need to perform this if there were multiple chromosomes for which the MAF was calculated—e.g. more than just chrX.

# %%
#### Bash ###
##chr_list={1..23}
#
## Merge per chr MAFs for each 1000G population
#for ancestry in ${ancestry_list};do
#    if [ $ancestry == "ea" ]
#    then
#        pop="EUR"
#    else
#        pop="AFR"
#    fi
#    
#        head -n 1 ${base_dir}/1000g/${pop}_chr1.maf > 1000g/${pop}_chr_all.maf
#        tail -q -n +2 1000g/${pop}_${chr_list}.maf \ # chr_list defined in beginning
#            >> 1000g/${pop}_chr_all.maf
#done

# %% [markdown]
# ###  Allele Discordances Check
# The allele discordances will be resolved by
# * Flipping allele discordances that are fixed by flipping
# * Removing SNPs with discordant names
# * Removing SNPs with discordant positions
# * Removing allele discordances that are not resolved by flipping
# * Removing alleles with large deviations from the reference population allele frequencies
#
# Given that the allele discordance check was done using a union set of SNPs across all studies within an ancestry group, some of the SNPs logged as discordant for a given study may not actually be in the study. Fortunately, if they are not in a given study they will not interfere with the filtering procedures. Note that the intersection set is used for the final studies merger.
#
# #### Autosomes

# %%
#### Bash ###
#
## Run discordance checks for each ancestry group
#for study in ${study_list}; do
#    for ancestry in ${ancestry_list};do
#        if [ $ancestry = "ea" ]; then
#            pop=EUR
#        else
#            pop=AFR
#        fi
#
#       /shared/bioinformatics/software/scripts/qsub_job.sh \
#           --job_name ${ancestry}_${study}_crosscheck \
#           --script_prefix ${base_dir}/strand_check/${ancestry}_allele_discordance_check \
#           --mem 6 \
#           --nslots 4 \
#           --priority 0 \
#           --program "Rscript /shared/bioinformatics/software/R/check_study_data_against_1000G.R
#               --study_bim_file ${base_dir}/${study}/genotype/observed/${ancestry}/*bim
#               --study_frq_file ${base_dir}/${study}/strand_check/${ancestry}_chr_all.frq
#               --ref_maf_file ${base_dir}/1000g/${pop}_chr_all.maf
#               --out_prefix ${base_dir}/${study}/strand_check/${ancestry}_allele_discordance"
#    done
#done

# %% [markdown]
# #### chrX

# %%
for study in ${study_list}; do
    for ancestry in ${ancestry_list};do
        if [ $ancestry = "ea" ]; then
            pop=EUR
        else
            pop=AFR
        fi

        # chr23 discordance check
        /shared/bioinformatics/software/scripts/qsub_job.sh \
            --job_name ${ancestry}_${study}_crosscheck \
            --script_prefix ${base_dir}/processing/${study}/strand_check/${ancestry}_allele_discordance_check \
            --mem 6.8 \
            --nslots 1 \
            --priority 0 \
            --program "Rscript /shared/bioinformatics/software/R/check_study_data_against_1000G.R
                --study_bim_file ${base_dir}/data/${study}/genotype/observed/${ancestry}/*bim
                --study_frq_file ${base_dir}/processing/${study}/strand_check/${ancestry}_chr23.frq
                --ref_maf_file ${base_dir}/processing/1000g/${pop}_chr23.maf
                --out_prefix ${base_dir}/processing/${study}/strand_check/${ancestry}_allele_discordance"
    done
done
# Out:
# Your job 8233 ("aa_uhs1_crosscheck") has been submitted
# Your job 8234 ("ea_uhs1_crosscheck") has been submitted
# Your job 8235 ("aa_uhs2_crosscheck") has been submitted
# Your job 8236 ("ea_uhs2_crosscheck") has been submitted
# Your job 8237 ("aa_uhs3_v1-2_crosscheck") has been submitted
# Your job 8238 ("ea_uhs3_v1-2_crosscheck") has been submitted
# Your job 8239 ("aa_uhs3_v1-3_crosscheck") has been submitted
# Your job 8240 ("ea_uhs3_v1-3_crosscheck") has been submitted
# Your job 8241 ("aa_uhs4_crosscheck") has been submitted
# Your job 8242 ("ea_uhs4_crosscheck") has been submitted

# %% [markdown]
# ### Resolving Allele Discordances

# %%
### Bash ###

# Apply filters
for study in ${study_list}; do
    for ancestry in ${ancestry_list};do
        echo -e "\n===============\nProcessing ${study}_${ancestry}\n"
        echo "Making remove list"
        cat <(cut -f2,2 ${base_dir}/processing/${study}/strand_check/${ancestry}_allele_discordance.discordant_alleles_not_fixed_by_strand_flip | tail -n +2) \
            <(cut -f2,2 ${base_dir}/processing/${study}/strand_check/${ancestry}_allele_discordance.at_cg_snps_freq_diff_gt_0.2 | tail -n +2) \
            <(cut -f2,2 ${base_dir}/processing/${study}/strand_check/${ancestry}_allele_discordance.discordant_names | tail -n +2) \
            <(cut -f2,2 ${base_dir}/processing/${study}/strand_check/${ancestry}_allele_discordance.discordant_positions | tail -n +2) \
            <(cut -f2,2 ${base_dir}/processing/${study}/strand_check/${ancestry}_allele_discordance.discordant_alleles_polymorphic_in_study_not_fixed_by_strand_flip | tail -n +2) | \
              sort -u > ${base_dir}/processing/${study}/strand_check/${ancestry}_snps.remove

        # Create flip list
        echo "Making flip list"
        comm -23 <(cut -f2,2 ${base_dir}/processing/${study}/strand_check/${ancestry}_allele_discordance.discordant_alleles | tail -n +2 | sort -u) \
                 <(cut -f2,2 ${base_dir}/processing/${study}/strand_check/${ancestry}_allele_discordance.discordant_alleles_not_fixed_by_strand_flip | tail -n +2 | sort -u) \
                 > ${base_dir}/processing/${study}/strand_check/${ancestry}_snps.flip

        # Apply filters
        /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --memory 2048 \
            --bed     ${base_dir}/data/${study}/genotype/observed/${ancestry}/*bed \
            --bim     ${base_dir}/data/${study}/genotype/observed/${ancestry}/*bim \
            --fam     ${base_dir}/data/${study}/genotype/observed/${ancestry}/*fam \
            --exclude ${base_dir}/processing/${study}/strand_check/${ancestry}_snps.remove \
            --flip    ${base_dir}/processing/${study}/strand_check/${ancestry}_snps.flip \
            --make-bed \
            --out     ${base_dir}/processing/${study}/${ancestry}_filtered
    done
done
# Out:
# ===============
# Processing uhs1_aa
#
# Making remove list
# Making flip list
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.bim
#   --exclude /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check/aa_snps.remove
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/aa/uhs1.aa.chr23.1KG.structure.fam
#   --flip /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check/aa_snps.flip
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1152 MB successfully, after larger attempt(s) failed.
# 17413 variants loaded from .bim file.
# 2008 people (1423 males, 585 females) loaded from .fam.
# --flip: 2561 SNPs flipped.
# --exclude: 17399 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2008 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.990259.
# 17399 variants and 2008 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered.bed +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered.bim +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered.fam ...
# 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
#
# ===============
# Processing uhs1_ea
#
# Making remove list
# Making flip list
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.bim
#   --exclude /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check/ea_snps.remove
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs1/genotype/observed/ea/uhs1.ea.chr23.1KG.structure.fam
#   --flip /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/strand_check/ea_snps.flip
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1152 MB successfully, after larger attempt(s) failed.
# 17413 variants loaded from .bim file.
# 1128 people (942 males, 186 females) loaded from .fam.
# --flip: 1700 SNPs flipped.
# --exclude: 17410 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1128 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.992074.
# 17410 variants and 1128 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered.bed +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered.bim +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered.fam ...
# 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
#
# ===============
# Processing uhs2_aa
#
# Making remove list
# Making flip list
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/aa/uhs2.aa.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/aa/uhs2.aa.chr23.bim
#   --exclude /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check/aa_snps.remove
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/aa/uhs2.aa.chr23.fam
#   --flip /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check/aa_snps.flip
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1152 MB successfully, after larger attempt(s) failed.
# 23484 variants loaded from .bim file.
# 767 people (517 males, 250 females) loaded from .fam.
# --flip: 0 SNPs flipped.
# --exclude: 23484 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 767 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.974578.
# 23484 variants and 767 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered.bed +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered.bim +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered.fam ...
# 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
#
# ===============
# Processing uhs2_ea
#
# Making remove list
# Making flip list
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/ea/uhs2.ea.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/ea/uhs2.ea.chr23.bim
#   --exclude /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check/ea_snps.remove
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs2/genotype/observed/ea/uhs2.ea.chr23.fam
#   --flip /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/strand_check/ea_snps.flip
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1152 MB successfully, after larger attempt(s) failed.
# 32857 variants loaded from .bim file.
# 828 people (495 males, 333 females) loaded from .fam.
# --flip: 0 SNPs flipped.
# --exclude: 32857 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 828 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.976798.
# 32857 variants and 828 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered.bed +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered.bim +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered.fam ...
# 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
#
# ===============
# Processing uhs3_v1-2_aa
#
# Making remove list
# Making flip list
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/aa/uhs3.aa.V1-2.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/aa/uhs3.aa.V1-2.chr23.bim
#   --exclude /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check/aa_snps.remove
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/aa/uhs3.aa.V1-2.chr23.fam
#   --flip /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check/aa_snps.flip
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1152 MB successfully, after larger attempt(s) failed.
# 41884 variants loaded from .bim file.
# 84 people (59 males, 25 females) loaded from .fam.
# --flip: 2 SNPs flipped.
# --exclude: 41847 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 84 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.914726.
# 41847 variants and 84 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
#
# ===============
# Processing uhs3_v1-2_ea
#
# Making remove list
# Making flip list
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/ea/uhs3.ea.V1-2.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/ea/uhs3.ea.V1-2.chr23.bim
#   --exclude /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check/ea_snps.remove
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-2/genotype/observed/ea/uhs3.ea.V1-2.chr23.fam
#   --flip /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/strand_check/ea_snps.flip
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1152 MB successfully, after larger attempt(s) failed.
# 24202 variants loaded from .bim file.
# 33 people (18 males, 15 females) loaded from .fam.
# --flip: 0 SNPs flipped.
# --exclude: 24197 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 33 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.884547.
# 24197 variants and 33 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
#
# ===============
# Processing uhs3_v1-3_aa
#
# Making remove list
# Making flip list
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/aa/uhs3.aa.V1-3.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/aa/uhs3.aa.V1-3.chr23.bim
#   --exclude /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check/aa_snps.remove
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/aa/uhs3.aa.V1-3.chr23.fam
#   --flip /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check/aa_snps.flip
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1152 MB successfully, after larger attempt(s) failed.
# 44706 variants loaded from .bim file.
# 94 people (63 males, 31 females) loaded from .fam.
# --flip: 2 SNPs flipped.
# --exclude: 44668 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 94 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.905134.
# 44668 variants and 94 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
#
# ===============
# Processing uhs3_v1-3_ea
#
# Making remove list
# Making flip list
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/ea/uhs3.ea.V1-3.chr23.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/ea/uhs3.ea.V1-3.chr23.bim
#   --exclude /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check/ea_snps.remove
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs3_v1-3/genotype/observed/ea/uhs3.ea.V1-3.chr23.fam
#   --flip /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/strand_check/ea_snps.flip
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1152 MB successfully, after larger attempt(s) failed.
# 35440 variants loaded from .bim file.
# 44 people (24 males, 20 females) loaded from .fam.
# --flip: 0 SNPs flipped.
# --exclude: 35436 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 44 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.927415.
# 35436 variants and 44 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
#
# ===============
# Processing uhs4_aa
#
# Making remove list
# Making flip list
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.bim
#   --exclude /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check/aa_snps.remove
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/aa/uhs4.aa.chr23.1KG.structure.fam
#   --flip /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check/aa_snps.flip
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1152 MB successfully, after larger attempt(s) failed.
# 36003 variants loaded from .bim file.
# 1072 people (766 males, 306 females) loaded from .fam.
# --flip: 0 SNPs flipped.
# --exclude: 36003 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1072 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.795883.
# 36003 variants and 1072 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered.bed +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered.bim +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered.fam ...
# 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
#
# ===============
# Processing uhs4_ea
#
# Making remove list
# Making flip list
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered.log.
# Options in effect:
#   --bed /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.bed
#   --bim /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.bim
#   --exclude /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check/ea_snps.remove
#   --fam /shared/jmarks/hiv/uhs1-4/chrX_processing/data/uhs4/genotype/observed/ea/uhs4.ea.chr23.1KG.structure.fam
#   --flip /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/strand_check/ea_snps.flip
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 36003 variants loaded from .bim file.
# 988 people (658 males, 330 females) loaded from .fam.
# --flip: 0 SNPs flipped.
# --exclude: 36003 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 988 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.959739.
# 36003 variants and 988 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered.bed +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered.bim +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered.fam ...
# 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
wc -l $base_dir/processing/*/*filtered.bim
# Out:
#    17399 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered.bim
#    17410 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered.bim
#    23484 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered.bim
#    32857 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered.bim
#    41847 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered.bim
#    24197 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered.bim
#    44668 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered.bim
#    35436 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered.bim
#    36003 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered.bim
#    36003 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered.bim
#   309304 total

# %% [markdown]
# ## Remove monomorphic variants
# Monomorphic variants prevent MIS from accepting the genotype data. In this case, an arbitrarily small MAF is set that is smaller than the lower bound for these data.

# %%
### Bash ###

# Apply filters
for study in ${study_list}; do
    for ancestry in ${ancestry_list};do
        geno_dir=${base_dir}/processing/${study}

        /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --memory 2048 \
            --bfile ${geno_dir}/${ancestry}_filtered \
            --maf 0.000001 \
            --make-bed \
            --out ${geno_dir}/${ancestry}_filtered_mono
    done
done
# Out:
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered_mono.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered
#   --maf 0.000001
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered_mono
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 17399 variants loaded from .bim file.
# 2008 people (1423 males, 585 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2008 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.990259.
# 884 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 16515 variants and 2008 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered_mono.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered_mono.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered_mono.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered_mono.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered
#   --maf 0.000001
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered_mono
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 17410 variants loaded from .bim file.
# 1128 people (942 males, 186 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1128 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.992074.
# 1708 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 15702 variants and 1128 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered_mono.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered_mono.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered_mono.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered_mono.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered
#   --maf 0.000001
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered_mono
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 23484 variants loaded from .bim file.
# 767 people (517 males, 250 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 767 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.974578.
# 2261 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 21223 variants and 767 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered_mono.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered_mono.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered_mono.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered_mono.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered
#   --maf 0.000001
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered_mono
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 32857 variants loaded from .bim file.
# 828 people (495 males, 333 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 828 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.976798.
# 8371 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 24486 variants and 828 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered_mono.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered_mono.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered_mono.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered_mono.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered
#   --maf 0.000001
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered_mono
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 41847 variants loaded from .bim file.
# 84 people (59 males, 25 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 84 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.914726.
# 4773 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 37074 variants and 84 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered_mono.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered_mono.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered_mono.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered_mono.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered
#   --maf 0.000001
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered_mono
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 24197 variants loaded from .bim file.
# 33 people (18 males, 15 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 33 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.884547.
# 4478 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 19719 variants and 33 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered_mono.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered_mono.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered_mono.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered_mono.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered
#   --maf 0.000001
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered_mono
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 44668 variants loaded from .bim file.
# 94 people (63 males, 31 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 94 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.905134.
# 4895 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 39773 variants and 94 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered_mono.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered_mono.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered_mono.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered_mono.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered
#   --maf 0.000001
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered_mono
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 35436 variants loaded from .bim file.
# 44 people (24 males, 20 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 44 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.927415.
# 9045 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 26391 variants and 44 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered_mono.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered_mono.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered_mono.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered_mono.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered
#   --maf 0.000001
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered_mono
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 36003 variants loaded from .bim file.
# 1072 people (766 males, 306 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1072 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.795883.
# 8037 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 27966 variants and 1072 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered_mono.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered_mono.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered_mono.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered_mono.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered
#   --maf 0.000001
#   --make-bed
#   --memory 2048
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered_mono
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 2048 MB for main workspace.
# Allocated 1536 MB successfully, after larger attempt(s) failed.
# 36003 variants loaded from .bim file.
# 988 people (658 males, 330 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 988 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.959739.
# 9358 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 26645 variants and 988 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered_mono.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered_mono.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered_mono.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
wc -l $base_dir/processing/*/*mono.bim
# Out:
#    16515 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered_mono.bim
#    15702 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered_mono.bim
#    21223 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered_mono.bim
#    24486 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered_mono.bim
#    37074 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered_mono.bim
#    19719 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered_mono.bim
#    39773 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered_mono.bim
#    26391 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered_mono.bim
#    27966 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered_mono.bim
#    26645 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered_mono.bim
#   255494 total

# %% [markdown]
# ### SNP intersection

# %%
studies=($study_list)  #studies=(UHS1 UHS2 UHS3_v1-2 UHS3_v1-3) # array of study names
num=${#studies[@]}

# Get intersection set
for ancestry in ${ancestry_list};do
    bim_files=()
    for (( i=0; i<${num}; i++ ));do
        bim_files+=(${base_dir}/processing/${studies[$i]}/${ancestry}_filtered_mono.bim)
    done
    
    echo -e "\nCalculating intersection between $ancestry ${study_list}...\n"
    cat ${bim_files[@]} | cut -f2 | sort | uniq -c | awk -v num=$num '$1 == num {print $2}' \
        > ${base_dir}/processing/intersect/${ancestry}_variant_intersection.txt

    # Make new PLINK binary file sets
    for study in ${studies[@]}; do
        /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --bfile ${base_dir}/processing/${study}/${ancestry}_filtered_mono \
            --extract ${base_dir}/processing/intersect/${ancestry}_variant_intersection.txt \
            --make-bed \
            --out ${base_dir}/processing/intersect/${study}_${ancestry}_filtered_snp_intersection
    done
done
# Out:
# Calculating intersection between aa uhs1 uhs2 uhs3_v1-2 uhs3_v1-3 uhs4...
#
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs1_aa_filtered_snp_intersection.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/aa_filtered_mono
#   --extract /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_variant_intersection.txt
#   --make-bed
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs1_aa_filtered_snp_intersection
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 16515 variants loaded from .bim file.
# 2008 people (1423 males, 585 females) loaded from .fam.
# --extract: 4581 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2008 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99358.
# 4581 variants and 2008 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs1_aa_filtered_snp_intersection.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs1_aa_filtered_snp_intersection.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs1_aa_filtered_snp_intersection.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs2_aa_filtered_snp_intersection.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/aa_filtered_mono
#   --extract /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_variant_intersection.txt
#   --make-bed
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs2_aa_filtered_snp_intersection
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 21223 variants loaded from .bim file.
# 767 people (517 males, 250 females) loaded from .fam.
# --extract: 4581 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 767 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.97656.
# 4581 variants and 767 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs2_aa_filtered_snp_intersection.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs2_aa_filtered_snp_intersection.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs2_aa_filtered_snp_intersection.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-2_aa_filtered_snp_intersection.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/aa_filtered_mono
#   --extract /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_variant_intersection.txt
#   --make-bed
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-2_aa_filtered_snp_intersection
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 37074 variants loaded from .bim file.
# 84 people (59 males, 25 females) loaded from .fam.
# --extract: 4581 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 84 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.973729.
# 4581 variants and 84 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-2_aa_filtered_snp_intersection.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-2_aa_filtered_snp_intersection.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-2_aa_filtered_snp_intersection.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-3_aa_filtered_snp_intersection.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/aa_filtered_mono
#   --extract /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_variant_intersection.txt
#   --make-bed
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-3_aa_filtered_snp_intersection
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 39773 variants loaded from .bim file.
# 94 people (63 males, 31 females) loaded from .fam.
# --extract: 4581 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 94 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.965617.
# 4581 variants and 94 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-3_aa_filtered_snp_intersection.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-3_aa_filtered_snp_intersection.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-3_aa_filtered_snp_intersection.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs4_aa_filtered_snp_intersection.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/aa_filtered_mono
#   --extract /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_variant_intersection.txt
#   --make-bed
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs4_aa_filtered_snp_intersection
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 27966 variants loaded from .bim file.
# 1072 people (766 males, 306 females) loaded from .fam.
# --extract: 4581 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1072 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.959536.
# 4581 variants and 1072 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs4_aa_filtered_snp_intersection.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs4_aa_filtered_snp_intersection.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs4_aa_filtered_snp_intersection.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
#
# Calculating intersection between ea uhs1 uhs2 uhs3_v1-2 uhs3_v1-3 uhs4...
#
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs1_ea_filtered_snp_intersection.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs1/ea_filtered_mono
#   --extract /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_variant_intersection.txt
#   --make-bed
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs1_ea_filtered_snp_intersection
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 15702 variants loaded from .bim file.
# 1128 people (942 males, 186 females) loaded from .fam.
# --extract: 3251 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1128 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99276.
# 3251 variants and 1128 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs1_ea_filtered_snp_intersection.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs1_ea_filtered_snp_intersection.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs1_ea_filtered_snp_intersection.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs2_ea_filtered_snp_intersection.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs2/ea_filtered_mono
#   --extract /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_variant_intersection.txt
#   --make-bed
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs2_ea_filtered_snp_intersection
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 24486 variants loaded from .bim file.
# 828 people (495 males, 333 females) loaded from .fam.
# --extract: 3251 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 828 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.97431.
# 3251 variants and 828 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs2_ea_filtered_snp_intersection.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs2_ea_filtered_snp_intersection.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs2_ea_filtered_snp_intersection.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-2_ea_filtered_snp_intersection.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-2/ea_filtered_mono
#   --extract /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_variant_intersection.txt
#   --make-bed
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-2_ea_filtered_snp_intersection
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 19719 variants loaded from .bim file.
# 33 people (18 males, 15 females) loaded from .fam.
# --extract: 3251 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 33 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.942423.
# 3251 variants and 33 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-2_ea_filtered_snp_intersection.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-2_ea_filtered_snp_intersection.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-2_ea_filtered_snp_intersection.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-3_ea_filtered_snp_intersection.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs3_v1-3/ea_filtered_mono
#   --extract /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_variant_intersection.txt
#   --make-bed
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-3_ea_filtered_snp_intersection
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 26391 variants loaded from .bim file.
# 44 people (24 males, 20 females) loaded from .fam.
# --extract: 3251 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 44 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.95809.
# 3251 variants and 44 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-3_ea_filtered_snp_intersection.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-3_ea_filtered_snp_intersection.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs3_v1-3_ea_filtered_snp_intersection.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs4_ea_filtered_snp_intersection.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/uhs4/ea_filtered_mono
#   --extract /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_variant_intersection.txt
#   --make-bed
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs4_ea_filtered_snp_intersection
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 978 MB for main workspace.
# 26645 variants loaded from .bim file.
# 988 people (658 males, 330 females) loaded from .fam.
# --extract: 3251 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 988 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.959802.
# 3251 variants and 988 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs4_ea_filtered_snp_intersection.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs4_ea_filtered_snp_intersection.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/uhs4_ea_filtered_snp_intersection.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
ww $base_dir/processing/intersect/*section.txt
# Out:
#   4581 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_variant_intersection.txt
#   3251 /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_variant_intersection.txt
#   7832 total

# %% [markdown]
# ### Merge test
# As a final check to confirm that our data sets are all compatible, a PLINK file set merge is conducted. If any issues persist then an error will be raised.

# %%
chr=23 # comment out if not running chrX exclusively
for ancestry in $ancestry_list;do

    echo "Creating $ancestry merge-list"
    touch ${base_dir}/processing/intersect/${ancestry}_merge_list.txt
    for study in $study_list;do
        echo ${base_dir}/processing/intersect/${study}_${ancestry}_filtered_snp_intersection >>\
             ${base_dir}/processing/intersect/${ancestry}_merge_list.txt
    done
    
    if [ $chr==23 ]; then
        out_file=${ancestry}_studies_merged_chrx
    else
        out_file=${ancestry}_studies_merged
    fi

# Merge file sets
    echo -e "\n\n======== ${ancestry} ========\n\n"
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 4000 \
        --merge-list ${base_dir}/processing/intersect/${ancestry}_merge_list.txt \
        --make-bed \
        --out ${base_dir}/processing/intersect/$out_file
done
# Out:
# Creating aa merge-list
#
#
# ======== aa ========
#
#
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_studies_merged.log.
# Options in effect:
#   --make-bed
#   --memory 4000
#   --merge-list /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_merge_list.txt
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_studies_merged
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 4000 MB for main workspace.
# Allocated 1265 MB successfully, after larger attempt(s) failed.
# Performing single-pass merge (4025 people, 4581 variants).
# Merged fileset written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_studies_merged-merge.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_studies_merged-merge.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_studies_merged-merge.fam
# .
# 4581 variants loaded from .bim file.
# 4025 people (2828 males, 1197 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 4025 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.980202.
# 4581 variants and 4025 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_studies_merged.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_studies_merged.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/aa_studies_merged.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# Creating ea merge-list
#
#
# ======== ea ========
#
#
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_studies_merged.log.
# Options in effect:
#   --make-bed
#   --memory 4000
#   --merge-list /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_merge_list.txt
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_studies_merged
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 4000 MB for main workspace.
# Allocated 1265 MB successfully, after larger attempt(s) failed.
# Performing single-pass merge (3021 people, 3251 variants).
# Merged fileset written to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_studies_merged-merge.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_studies_merged-merge.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_studies_merged-merge.fam
# .
# 3251 variants loaded from .bim file.
# 3021 people (2137 males, 884 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 3021 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.975869.
# 3251 variants and 3021 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_studies_merged.bed
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_studies_merged.bim
# +
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/intersect/ea_studies_merged.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
wc -l $base_dir/processing/intersect/*merged*bim
  4581 /shared/jmarks/hiv/uhs1234/chrX_processing//processing/intersect/aa_studies_merged_chrx.bim
  3251 /shared/jmarks/hiv/uhs1234/chrX_processing//processing/intersect/ea_studies_merged_chrx.bim

# %% [markdown]
# ## Imputation preparation for Michigan Imputation Server
# Visit the [MIS Getting Started Webpage](https://imputationserver.sph.umich.edu/start.html#!pages/help) for more information about the preparing the data for upload to MIS.

# %% [markdown]
# ### VCF File Conversion

# %%
### Split by chr and remove any individuals with missing data for whole chr

chr=23
for ancestry in $ancestry_list;do


    if [ $chr==23 ]; then
        myfile=${ancestry}_studies_merged_chrx
    else
        myfile=${ancestry}_studies_merged
    fi
    
    # Remove SNPs
    /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 4000 \
        --bfile ${base_dir}/processing/intersect/$myfile \
        --chr ${chr} \
        --mind 0.99 \
        --make-bed \
        --out ${base_dir}/processing/impute_prep/${ancestry}_chr${chr}_for_phasing 
done > ${base_dir}/processing/impute_prep/chr_splitting.log 


### Split by chr and remove any individuals with missing data for whole chr

# if merged data sets together
#for ancestry in $ancestry_list;do
#    for chr in {1..23};do
#        # Remove SNPs
#        /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
#            --noweb \
#            --memory 4000 \
#            --bfile ${base_dir}/processing/intersect/${ancestry}_studies_merged \
#            --chr ${chr} \
#            --mind 0.99 \
#            --make-bed \
#            --out ${base_dir}/processing/impute_prep/${ancestry}_chr${chr}_for_phasing 
#    done > ${base_dir}/processing/impute_prep/chr_splitting.log 
#done

for ancestry in $ancestry_list; do
    grep removed $base_dir/processing/impute_prep/$ancestry*log |
        perl -lne '/(\d+)(\speople)/;
             $mycount += $1; 
             print $mycount if eof'  > $base_dir/processing/impute_prep/$ancestry.removed
    any_removed=$(cat $base_dir/processing/impute_prep/$ancestry.removed)
    if [ "$any_removed" == 0 ]; then
        echo "No $ancestry subjects removed"
    else
        echo "Some $ancestry subjects removed"
    fi
done
# Out:
# No aa subjects removed
# No ea subjects removed

# %%
# EC2 command line #
#for chr in ${chr_list};do
chr=23
    for ancestry in ${ancestry_list};do
        final_dir=${base_dir}/processing/impute_prep/${ancestry}
        mkdir $final_dir
        /shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
            --noweb \
            --memory 5000 \
            --bfile ${final_dir}/../${ancestry}_chr${chr}_for_phasing \
            --output-chr M \
            --set-hh-missing \
            --recode vcf bgz \
            --out ${final_dir}/${ancestry}_chr${chr}_final
    done
#done
# Out:
# mkdir: cannot create directory ‘/shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa’: File exists
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa/aa_chr23_final.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa/../aa_chr23_for_phasing
#   --memory 5000
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa/aa_chr23_final
#   --output-chr M
#   --recode vcf bgz
#   --set-hh-missing
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 5000 MB for main workspace.
# Allocated 1185 MB successfully, after larger attempt(s) failed.
# 4581 variants loaded from .bim file.
# 4025 people (2828 males, 1197 females) loaded from .fam.
# Using up to 2 threads (change this with --threads).
# Before main variant filters, 4025 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.980202.
# 4581 variants and 4025 people pass filters and QC.
# Note: No phenotypes present.
# Warning: Underscore(s) present in sample IDs.
# --recode vcf bgz to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa/aa_chr23_final.vcf.gz
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: cannot create directory ‘/shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/ea’: File exists
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/ea/ea_chr23_final.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/ea/../ea_chr23_for_phasing
#   --memory 5000
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/ea/ea_chr23_final
#   --output-chr M
#   --recode vcf bgz
#   --set-hh-missing
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 5000 MB for main workspace.
# Allocated 1185 MB successfully, after larger attempt(s) failed.
# 3251 variants loaded from .bim file.
# 3021 people (2137 males, 884 females) loaded from .fam.
# Using up to 2 threads (change this with --threads).
# Before main variant filters, 3021 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.975869.
# 3251 variants and 3021 people pass filters and QC.
# Note: No phenotypes present.
# Warning: Underscore(s) present in sample IDs.
# --recode vcf bgz to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/ea/ea_chr23_final.vcf.gz
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %% [markdown]
# Transfer the *.vcf.gz files to local machine (per chromosome) and then upload to MIS.

# %% [markdown]
# ## Upload to Michigan Imputation Server (MIS)
#
# ### Uploading parameters
# These are the parameters that were selected on MIS.
#
# __Name__: UHS1-3_merged_chrX_EA_v02
#
# __Reference Panel__ 1000G Phase 3 v5
#
# __Input Files__ File Upload <br>
#
# * Select Files - select VCF (.gz) files that were downloaded to local machine from cloud. <br>
#
# __Phasing__: ShapeIT v2.r790 (unphased)
#
# __Population__: EUR
#
# __Mode__: Quality Control & Imputation
#
# * I will not attempt to re-identify or contact research participants.
# * I will report any inadvertent data release, security breach or other data management incident of which I become aware.

# %% [markdown]
# # Troubleshooting
#
# ```
# Chromosome X check failed!
# java.io.IOException: Found haplotype 0/1 at pos 2788707 for male proband 8002221030_HHG6599_AS93-4798_8002221030_HHG6599_AS93-4798
# Found haplotype 0/1 at pos 2825403 for male proband 8002221030_HHG6599_AS93-4798_8002221030_HHG6599_AS93-4798
# Found haplotype 0/1 at pos 2862721 for male proband 8002221030_HHG6599_AS93-4798_8002221030_HHG6599_AS93-4798
# Found haplotype 0/1 at pos 2985672 for male proband 8002221030_HHG6599_AS93-4798_8002221030_HHG6599_AS93-4798
# Found haplotype 0/1 at pos 3002687 for male proband 8002221030_HHG6599_AS93-4798_8002221030_HHG6599_AS93-4798
# Found haplotype 0/1 at pos 3028289 for male proband 8002221030_HHG6599_AS93-4798_8002221030_HHG6599_AS93-4798
# Found haplotype 0/1 at pos 3296294 for male proband 8002221030_HHG6599_AS93-4798_8002221030_HHG6599_AS93-4798
# Found haplotype 0/1 at pos 3542110 for male proband 8002221030_HHG6599_AS93-4798_8002221030_HHG6599_AS93-4798
# Found haplotype 0/1 at pos 3627414 for male proband 8002221030_HHG6599
# Error during manifest file creation.
# ```
#
# **We are going to remove subject listed above in the MIS error message from the study.**

# %%
remove_dir=$base_dir/processing/impute_prep/aa/remove_subject
mkdir $remove_dir
ancestry=aa
chr=23
echo 8002221030_HHG6599_AS93-4798 8002221030_HHG6599_AS93-4798 > ${remove_dir}/remove_list.tsv

/shared/bioinformatics/software/third_party/plink-1.90-beta-4.10-x86_64/plink \
        --noweb \
        --memory 5000 \
        --bfile ${remove_dir}/../../${ancestry}_chr${chr}_for_phasing \
        --output-chr M \
        --set-hh-missing \
        --remove-fam $remove_dir/remove_list.tsv \
        --recode vcf bgz \
        --out ${remove_dir}/${ancestry}_chr${chr}_final_v02
# Out:
# mkdir: cannot create directory ‘/shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa/remove_subject’: File exists
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa/remove_subject/aa_chr23_final_v02.log.
# Options in effect:
#   --bfile /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa/remove_subject/../../aa_chr23_for_phasing
#   --memory 5000
#   --noweb
#   --out /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa/remove_subject/aa_chr23_final_v02
#   --output-chr M
#   --recode vcf bgz
#   --remove-fam /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa/remove_subject/remove_list.tsv
#   --set-hh-missing
#
# Note: --noweb has no effect since no web check is implemented yet.
# 1957 MB RAM detected; reserving 5000 MB for main workspace.
# Allocated 1185 MB successfully, after larger attempt(s) failed.
# 4581 variants loaded from .bim file.
# 4025 people (2828 males, 1197 females) loaded from .fam.
# --remove-fam: 4024 people remaining.
# Using up to 2 threads (change this with --threads).
# Before main variant filters, 4024 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate in remaining samples is 0.980223.
# 4581 variants and 4024 people pass filters and QC.
# Note: No phenotypes present.
# Warning: Underscore(s) present in sample IDs.
# --recode vcf bgz to
# /shared/jmarks/hiv/uhs1-4/chrX_processing/processing/impute_prep/aa/remove_subject/aa_chr23_final_v02.vcf.gz

# %% [markdown]
# # Download Imputed Results from MIS
# First, download the data form the Michigan Imputation Server (MIS) by clicking on the link provided in the email they send out to alert you that your data has finished. Here you will find commands for downloading the data.

# %%
## EC2 (share drive)
# Note: jmarks is a symlink; you will have to save results
# to the share drive because they are very large)

# create directory structure
mkdir -p /home/ec2-user/jmarks/hiv/uhs123/data/uhs123_merged/genotype/imputed/{ea,aa}/chr23

# %% [markdown]
# ## ChrX
# ### EA
# The zip files from Michigan Imputation Server (MIS) need to be inflated before you can begin working with them. They require a passcode that is sent by MIS to email.
# * EA password: z@j1CRuP:Diw3Y
#
# Then, inflate imputation results.

# %%
ancestry=ea
study=uhs1-4
passW="'z@j1CRuP:Diw3Y'"
cd /shared/jmarks/hiv/uhs1234/gwas/genotype/imputed/$ancestry


# download.file
####################################################################################################
####################################################################################################
# QC-results
wget https://imputationserver.sph.umich.edu/share/results/3e003fabde51f68742c3df72b19720dc/qcreport.html

# Imputation Results
wget https://imputationserver.sph.umich.edu/share/results/ce8b8d3a6e056b00d429efb863350952/chr_X.no.auto_female.zip
wget https://imputationserver.sph.umich.edu/share/results/20d74f774326075473cf154d4a619622/chr_X.no.auto_male.zip

# Logs
wget https://imputationserver.sph.umich.edu/share/results/d5d5d852884d1b437eec9665d880641/chr_X.no.auto_female.log
wget https://imputationserver.sph.umich.edu/share/results/1afd40c6ed931bf4530a50e2d41eb764/chr_X.no.auto_male.log


# SNP Statistics
wget https://imputationserver.sph.umich.edu/share/results/d7270cc7271a914540a9a11aed68baf3/statistics.txt

####################################################################################################
####################################################################################################

/shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name MIS.dowload.$study.$ancestry.chrx \
    --script_prefix imputed.data.download.$ancestry.chrx \
    --mem 3 \
    --nslots 1 \
    --priority 0 \
    --program bash download.file

# inflate chr results
for file in *zip; do
    /shared/bioinformatics/software/scripts/qsub_job.sh \
        --job_name unzip.$study.$ancestry.chrx \
        --script_prefix unzip.imputed.$study.$ancestry.chrx.data \
        --mem 3 \
        --nslots 2 \
        --priority 0 \
        --program unzip -P $passW $file 
done

# we can remove the original imputed data from MIS after we inflate the zip files
rm -rf *zip

# %% [markdown]
# ### AA
# The zip files from Michigan Imputation Server (MIS) need to be inflated before you can begin working with them. They require a passcode that is sent by MIS to email.
# * AA password: LFkee+tMo31WV:
#
# Then, inflate imputation results.

# %%
ancestry=aa
study=uhs1-4
passW="'LFkee+tMo31WV:'"
cd /shared/jmarks/hiv/uhs1234/gwas/genotype/imputed/$ancestry


# download.file
####################################################################################################
####################################################################################################
# QC-results
wget https://imputationserver.sph.umich.edu/share/results/dae3adc9d1820e3e7b6108ed82c8851c/qcreport.html

# Imputation Results
wget https://imputationserver.sph.umich.edu/share/results/fef581304eaa1ce12cfaaf6d570a5dfb/chr_X.no.auto_female.zip
wget https://imputationserver.sph.umich.edu/share/results/851f851b7dbe42aac869cfc6c4b465c9/chr_X.no.auto_male.zip

# Logs
wget https://imputationserver.sph.umich.edu/share/results/f65c749682821647a9cd40597588807a/chr_X.no.auto_female.log
wget https://imputationserver.sph.umich.edu/share/results/7a8fca2dc09fe487c09fe80220be8ea6/chr_X.no.auto_male.log

# SNP Statistics
wget https://imputationserver.sph.umich.edu/share/results/15699900e18d5b91e416476d33b1f452/statistics.txt

####################################################################################################
####################################################################################################

/shared/bioinformatics/software/scripts/qsub_job.sh \
    --job_name MIS.dowload.$study.$ancestry.chrx \
    --script_prefix imputed.data.download.$ancestry.chrx \
    --mem 3 \
    --nslots 1 \
    --priority 0 \
    --program bash download.file

# inflate chr results
for file in *zip; do
    /shared/bioinformatics/software/scripts/qsub_job.sh \
        --job_name unzip.$study.$ancestry.chrx \
        --script_prefix unzip.imputed.$study.$ancestry.chrx.data \
        --mem 3 \
        --nslots 2 \
        --priority 0 \
        --program unzip -P $passW $file 
done

# we can remove the original imputed data from MIS after we inflate the zip files
rm -rf *zip

# %% [markdown]
# # Upload to S3

# %%
ancestry=aa
# mv inflated results to respective directories and upload to s3
files="chrX.no.auto_male.dose.vcf.gz chrX.no.auto_male.dose.vcf.gz.tbi chrX.no.auto_male.info.gz chr_X.no.auto_male.log "
for file in $files; do
    aws s3 cp $file s3://rti-hiv/hiv_uhs1234/data/genotype/imputed/$ancestry/$file --quiet &
done
