# %% [markdown]
# # SNP Lookup for UKBiobank SNPs
# The attached file contains SNPs associated with various brain imaging outcomes from the UK Biobank. I’m interested in seeing their associations with nicotine dependence. Pull their results from the current FTND meta-analyses for all ancestries (056) and European-specific (057)?  There should be 615 unique SNP IDs here.

# %%
cd //rcdcollaboration01.rti.ns/gxg/Analysis/META/1df/056.eur18cohorts.afr.11cohorts.1000G_p3
head aand+adaa+cogend+cogend2+copdgene1+copdgene2+decode+dental_caries+eagle+emerge+finrisk+ftc+gain+german+jhs_aric+minnesota_twins+nongain+ntr+sage+uw-tturc+yale-penn.afr+eur.chr1.1df

# note that I will have to look the snp up by position
"""
MarkerName chr position Allele1 Allele2 Effect StdErr P-value Direction HetISq HetChiSq HetDf HetPVal
1:10177:A:AC 1 10177 a ac -0.0049 0.0095 0.6061 -+----+-++?++???-+?-?-?+-+-?? 6.4 20.291 19 0.3772
rs145072688:10352:T:TA 1 10352 t ta -0.0024 0.0094 0.7978 +++-+-+-+-?-+???-+?-?-?-++-?? 8.4 20.754 19 0.3506
1:10583:A:G 1 10583 a g -0.0231 0.0164 0.159 ??????????-?????????????????? 0.0 0.000 0 1
1:10611:C:G 1 10611 c g 0.2609 0.5714 0.648 ??????????+?????????????????? 0.0 0.000 0 1
1:10642:G:A 1 10642 a g -0.1026 0.0987 0.2985 ?--???-?+???????????????????? 0.0 0.220 3 0.9743
1:11008:C:G 1 11008 c g 0.0363 0.0134 0.006825 -+-+-++++-?-+???++-+?-?++-+?? 22.1 25.679 20 0.1767
"""

# %% [markdown]
# ## 056 - cross ancestry

# %%
cd /cygdrive/c/Users/jmarks/Desktop/Projects/Nicotine/UKBiobank

workingDir=/cygdrive/c/Users/jmarks/Desktop/Projects/Nicotine/UKBiobank
dataDir=//rcdcollaboration01.rti.ns/gxg/Analysis/META/1df/056.eur18cohorts.afr.11cohorts.1000G_p3

for chr in {1..22}; do
    perl $workingDir/extract_rows.pl \
         --source $dataDir/aand+adaa+cogend+cogend2+copdgene1+copdgene2+decode+dental_caries+eagle+emerge+finrisk+ftc+gain+german+jhs_aric+minnesota_twins+nongain+ntr+sage+uw-tturc+yale-penn.afr+eur.chr$chr.1df \
         --id_list $workingDir/ukbiobank.snp_rsID.20180725 \
         --out $workingDir/20180725.ukbiobank.lookup.results.chr$chr \
         --header 0 \
         --id_column 0
done &

# combine data
head -n1 $dataDir/aand+adaa+cogend+cogend2+copdgene1+copdgene2+decode+dental_caries+eagle+emerge+finrisk+ftc+gain+german+jhs_aric+minnesota_twins+nongain+ntr+sage+uw-tturc+yale-penn.afr+eur.chr22.1df >\
    $workingDir/20180725.ukbiobank.lookup.results.ALL_CHR
for chr in {1..22};do
    cat $workingDir/20180725.ukbiobank.lookup.results.chr$chr >> $workingDir/20180725.ukbiobank.lookup.results.ALL_CHR
done

# %% [markdown]
# ### Identify SNPs not found

# %%
workingDir=/cygdrive/c/Users/jmarks/Desktop/Projects/Nicotine/UKBiobank

awk ' NR>=2{ gsub( ":.+$", "", $1); {print $1}}' *R | sort > a
sort $workingDir/ukbiobank.snp_rsID.20180725 > b

# below are the SNPs that did not show up in the lookup
comm -13 a b > c
cat c
"rs10792032
rs113204513
rs118142338
rs12786914
rs140229969
rs141591500
rs142398875
rs143698232
rs147532338
rs148030977
rs188625068
rs382362
rs541688816
rs544995
rs565373967
rs576272362
rs74617459
rs79229380
rs79742625
"

wc -l a b c
"""
 598 a
  615 b
   19 c
"""
# note that there were 19 SNPs missing despite the difference of 615-598 
# (total number of SNPs to lookup [minus] total number of SNPs found)
# this is because a couple of the SNPs were found twice in the lookup.
# namely the following:

uniq -dc a
"""
      2 rs2848544
      2 rs75006098
"""

grep rs2848544 *R
"""
rs2848544:98139300:G:A 11 98139300 a g 0.0074 0.0088 0.398 ++----+---?+--?---?+-+-+-+--+ 22.6 32.312 25 0.1492
rs2848544:98139300:G:C 11 98139300 c g 0.0028 0.0058 0.6275 -+-+++-++-?+++?+-+?-++-----++ 0.0 16.955 25 0.8834
"""
grep 75006098 *R
"""
rs75006098:135082593:A:T 2 135082593 a t 0.0052 0.0065 0.4272 +---+-++--+--+?+--?++---+++++ 0.0 19.129 26 0.8309
rs75006098:135082593:A:AT 2 135082593 a at 0.0170 0.0169 0.3143 -++?+?+?+???????-??-???+?-?+? 34.4 15.255 10 0.123
"""

# %% [markdown]
# ## 057 - European-specific

# %%
cd /cygdrive/c/Users/jmarks/Desktop/Projects/Nicotine/UKBiobank/057.eur

workingDir=/cygdrive/c/Users/jmarks/Desktop/Projects/Nicotine/UKBiobank
outDir=057.eur
dataDir=//rcdcollaboration01.rti.ns/gxg/Analysis/META/1df/057.eur18cohorts.1000G_p3

for chr in {1..22}; do
    perl $workingDir/extract_rows.pl \
         --source $dataDir/cogend+cogend2+copdgene1+copdgene2+decode+dental_caries+eagle+emerge+finrisk+ftc+gain+german+minnesota_twins+nongain+ntr+sage+uw-tturc+yale-penn.eur.chr$chr.1df \
         --id_list $workingDir/ukbiobank.snp_rsID.20180725 \
         --out $workingDir/$outDir/20180725.ukbiobank.eur-specific.lookup.results.chr$chr \
         --header 0 \
         --id_column 0
done &


# combine data
head -n1 $dataDir/cogend+cogend2+copdgene1+copdgene2+decode+dental_caries+eagle+emerge+finrisk+ftc+gain+german+minnesota_twins+nongain+ntr+sage+uw-tturc+yale-penn.eur.chr8.1df >\
    $workingDir/$outDir/20180725.ukbiobank.eur-specific.lookup.results.ALL_CHR
for chr in {1..22};do
    cat $workingDir/$outDir/20180725.ukbiobank.eur-specific.lookup.results.chr$chr >> $workingDir/$outDir/20180725.ukbiobank.eur-specific.lookup.results.ALL_CHR
done

# %% [markdown]
# ### Identify SNPs not found

# %%
workingDir=/cygdrive/c/Users/jmarks/Desktop/Projects/Nicotine/UKBiobank
outDir=057.eur

awk ' NR>=2{ gsub( ":.+$", "", $1); {print $1}}' $workingDir/$outDir/*R | sort > $workingDir/$outDir/a
sort $workingDir/ukbiobank.snp_rsID.20180725 > $workingDir/$outDir/b

# below are the SNPs that did not show up in the lookup
comm -13 a b > c
cat c
"
rs10792032
rs111639861
rs113204513
rs114201065
rs118142338
rs12786914
rs140229969
rs141591500
rs142398875
rs143698232
rs147532338
rs148030977
rs188625068
rs382362
rs541688816
rs544995
rs565373967
rs576272362
rs73260633
rs74617459
rs79229380
rs79742625
"

wc -l a b c
"""
594 a
  615 b
   22 c
"""
# note that there were 22 SNPs missing despite the difference of 615-594 
# (total number of SNPs to lookup [minus] total number of SNPs found)
# this is because a SNP was found twice in the lookup.
# namely the following:

uniq -dc a
"""
      2 rs2848544
"""

grep rs2848544 *R
"""
rs2848544:98139300:G:A 11 98139300 a g -0.0161 0.0139 0.2458 ----?+--?--?-+---+ 0.0 8.735 14 0.8476
rs2848544:98139300:G:C 11 98139300 c g 0.0075 0.0073 0.3069 +++-?+++?++?++---+ 0.0 8.856 14 0.8401
"""

# %% [markdown]
# ## Perl Extract Script

# %%
cat extract.pl

"""
#!/usr/bin/perl

# Example:
# perl /share/nas02/bioinformatics_group/software/perl/extract_rows.pl \
#  --source /share/nas02/bioinformatics_group/data/ref_panels/hapmap_phase_3/beagle/ALL/hapmap3_r2_b36_chr22.5MB_chunk.0.marker \
#  --id_list /share/nas02/bioinformatics_group/data/ref_panels/hapmap_phase_3/beagle/ALL/hapmap3_r2_b36_chr22.5MB_chunk.0.keep_snps \
#  --out /share/nas02/bioinformatics_group/data/ref_panels/hapmap_phase_3/beagle/ALL/hapmap3_r2_b36_chr22.5MB_chunk.0.keep.marker \
#  --header 0 \
#  --id_column 0

use strict;
use warnings;
use Getopt::Long;
use constant FALSE => 0;
use constant TRUE  => 1;

# Autoflush STDOUT
select((select(STDOUT), $|=1)[0]);

my $fileSource = '';
my $fileIdList = '';
my $fileOut = '';
my $remove = FALSE;
my $sourceHeaderRowCount = 0;
my $sourceIdColumn = 0;

GetOptions ('source=s' => \$fileSource,                                 # Name of file from which rows will be extracted
                        'id_list=s' => \$fileIdList,                            # Name of file containing list of identifiers for rows to be extracted or removed
                        'out=s' => \$fileOut,                                           # Name of output file
                        'remove' => \$remove,                                           # Rows corresponding to items in the ID list will be removed rather than extracted
                        'header:i' => \$sourceHeaderRowCount,           # Number of header rows in source file
                        'id_column:i' => \$sourceIdColumn);                     # Column in source file containing ID (column numbering starts with 0)

if ($sourceIdColumn < 0) {
        die "Invalid --id_column\n";
}

my %idList = ();                # IDs of rows to extract or remove
my $row = 0;                    # Current line number in source file
my $inIdList = FALSE;   # Whether the ID for the current row is in the id list

# Read in ID list
print "Reading ID list...\n";
if ($fileIdList =~ /\.gz$/) {
        open(FILE_ID_LIST, "gunzip -c $fileIdList |") or die "Cannot open ".$fileIdList."\n";
} else {
        open(FILE_ID_LIST, $fileIdList) or die "Cannot open ".$fileIdList."\n";
}
while (<FILE_ID_LIST>){
        chomp;
        my $new_id = $_;
        $new_id =~ s/^\s+|\s+$//g;
        print "\n".$new_id;
        $idList{$new_id} = 1;
}
close FILE_ID_LIST;

# Process source file
print "Extracting rows...\n";
open(FILE_OUT, ">".$fileOut) or die "Cannot open ".$fileOut."\n";
if ($fileSource =~ /\.gz$/) {
        open(FILE_SOURCE, "gunzip -c $fileSource |") or die "Cannot open ".$fileSource."\n";
} else {
        open(FILE_SOURCE, $fileSource) or die "Cannot open ".$fileSource."\n";
}
while (<FILE_SOURCE>) {
        chomp;
        if ($row < $sourceHeaderRowCount) {
                print FILE_OUT $_."\n";
                $row++;
        } else {
                my @fields = split;
                if ($sourceIdColumn < @fields) {
                        my @id_array = split /:/, $fields[$sourceIdColumn];
                        $inIdList = exists $idList{$id_array[0]};
                        if (($inIdList && !$remove) || (!$inIdList && $remove)) {
                                print FILE_OUT $_."\n";
                                #print $_."\n";
                        }
                } else {
                        die "Invalid --id_column\n";
                }
        }
}
close FILE_SOURCE;
close FILE_OUT;

print "Done\n";
"""

# %% [markdown]
# rs3892467
# rs880724
# rs61784835
# rs6658111
# rs11205734
# rs74080735
# rs857036
# rs857035
# rs115028639
# rs12565436
# rs76934732
# rs1413429
# rs188619167
# rs140268532
# rs6537740
# rs6537741
# rs56267425
# rs2365715
# rs77417189
# rs2777915
# rs3795503
# rs1609829
# rs1044595
# rs149761542
# rs2821110
# rs6661330
# rs113204513
# rs60859709
# rs823152
# rs823154
# rs476557
# rs10494988
# rs72753964
# rs7533662
# rs6673695
# rs9435825
# rs4132509
# rs62127228
# rs11683719
# rs72772496
# rs72782351
# rs1902030
# rs62163240
# rs13003076
# rs146896516
# rs12713562
# rs62157567
# rs72973613
# rs115839356
# rs12615370
# rs62158166
# rs12616641
# rs60873293
# rs114201065
# rs2861351
# rs75006098
# rs62171443
# rs1427685
# rs2970932
# rs12617973
# rs62172372
# rs75288308
# rs6740926
# rs2882877
# rs12991409
# rs13029997
# rs4673854
# rs7589891
# rs76797769
# rs6714490
# rs9341187
# rs7574789
# rs77587532
# rs6437028
# rs952644
# rs7634782
# rs1433351
# rs1914333
# rs12496226
# rs6782597
# rs1472369
# rs7633500
# rs35124509
# rs2117137
# rs66499884
# rs7613412
# rs73154904
# rs79229380
# rs80197180
# rs4428180
# rs79987238
# rs9823162
# rs73004625
# rs2279829
# rs7620302
# rs149190516
# rs9880975
# rs56068001
# rs61500084
# rs1159211
# rs1159212
# rs147699550
# rs7617509
# rs143257179
# rs6599389
# rs2172442
# rs28675914
# rs28823384
# rs6830693
# rs4697414
# rs34221784
# rs55945499
# rs10003201
# rs9291456
# rs11932261
# rs141591500
# rs35547424
# rs4398584
# rs150639066
# rs1035006
# rs142457114
# rs148579079
# rs1481012
# rs55983748
# rs149979828
# rs6840385
# rs17247656
# rs149496329
# rs76062146
# rs17249745
# rs13105682
# rs17199964
# rs13136118
# rs6855246
# rs35225200
# rs35518360
# rs13107325
# rs13135092
# rs6827477
# rs1511305
# rs75778110
# rs4834152
# rs114858860
# rs72916308
# rs17287454
# rs813139
# rs80170323
# rs11937839
# rs149534466
# rs4862340
# rs10011933
# rs4862343
# rs1882327
# rs55884748
# rs35561057
# rs116309746
# rs293106
# rs506232
# rs1967289
# rs10471584
# rs4700391
# rs10939886
# rs2548774
# rs115105844
# rs17568237
# rs7714710
# rs6880566
# rs13160511
# rs33599
